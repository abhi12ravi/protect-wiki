# %%
import pandas as pd

df = pd.read_json('protectedPageData/25')

df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-5d5ed75fd551> in <module>
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_json('protectedPageData/25')
#       4
#       5 df
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     197                 else:
#     198                     kwargs[new_arg_name] = new_arg_value
# --> 199             return func(*args, **kwargs)
#     200
#     201         return cast(F, wrapper)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\json\_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression, nrows)
#     616         return json_reader
#     617
# --> 618     result = json_reader.read()
#     619     if should_close:
#     620         filepath_or_buffer.close()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\json\_json.py in read(self)
#     753                 obj = self._get_object_parser(self._combine_lines(data))
#     754         else:
# --> 755             obj = self._get_object_parser(self.data)
#     756         self.close()
#     757         return obj
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\json\_json.py in _get_object_parser(self, json)
#     775         obj = None
#     776         if typ == "frame":
# --> 777             obj = FrameParser(json, **kwargs).parse()
#     778
#     779         if typ == "series" or obj is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\json\_json.py in parse(self)
#     884
#     885         else:
# --> 886             self._parse_no_numpy()
#     887
#     888         if self.obj is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\json\_json.py in _parse_no_numpy(self)
#    1117         if orient == "columns":
#    1118             self.obj = DataFrame(
# -> 1119                 loads(json, precise_float=self.precise_float), dtype=None
#    1120             )
#    1121         elif orient == "split":
#
# ValueError: Expected object or value

# %%
import json
#data_file = 'protectedPageData/25'
#data = json.load('protectedPageData/25') 

with open('../protectedPageData/25') as data_file:    
    data = json.load(data_file)

# %%
data

# %%
from pandas import json_normalize
json_normalize(data)

# %%
def flatten_json(y):
    out = {}

    def flatten(x, name=''):
        if type(x) is dict:
            for a in x:
                flatten(x[a], name + a + '_')
        elif type(x) is list:
            i = 0
            for a in x:
                flatten(a, name + str(i) + '_')
                i += 1
        else:
            out[name[:-1]] = x

    flatten(y)
    return out

# %%
flat = flatten_json(data_file)
flat
#json_normalize(flat)

# %%
type(flat)

# %%
# Python program to read
# json file
  
  
import json
  
# Opening JSON file
f = open('../protectedPageData/25',)
  
# returns JSON object as 
# a dictionary
data = json.load(f)
  
# Iterating through the json
# list
for i in data:
    print(i)
  
# Closing file
f.close()

# %% [markdown]
# #### Getting URL from Wikipedia pageid
#
# #The pageid is the MediaWiki's internal article ID. You can use the action API's info property to get the full URL from pageid:
#
# https://en.wikipedia.org/w/api.php?action=query&prop=info&pageids=18630637&inprop=url

# %%
import os, csv

f=open("experiments/depp_dataset.csv",'r+')
w=csv.writer(f)
print(w)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-4364059864d9> in <module>
#       1 import os, csv
#       2
# ----> 3 f=open("experiments/depp_dataset.csv",'r+')
#       4 w=csv.writer(f)
#       5 print(w)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'experiments/depp_dataset.csv'

# %%
pip install git+https://github.com/Commonists/pageview-api.git
# Out:
# Collecting git+https://github.com/Commonists/pageview-api.git
#   Cloning https://github.com/Commonists/pageview-api.git to c:\users\abhi\appdata\local\temp\pip-req-build-r7m0s2rm
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from pageviewapi==0.4.0) (2.24.0)
# Requirement already satisfied: attrdict in c:\programdata\anaconda3\lib\site-packages (from pageviewapi==0.4.0) (2.0.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests->pageviewapi==0.4.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->pageviewapi==0.4.0) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->pageviewapi==0.4.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->pageviewapi==0.4.0) (2020.6.20)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from attrdict->pageviewapi==0.4.0) (1.15.0)
# Building wheels for collected packages: pageviewapi
#   Building wheel for pageviewapi (setup.py): started
#   Building wheel for pageviewapi (setup.py): finished with status 'done'
#   Created wheel for pageviewapi: filename=pageviewapi-0.4.0-py3-none-any.whl size=5302 sha256=1101243844bd4c843e9b1155152a3a074721a49a4bdcde1ddc3955519d7f9dde
#   Stored in directory: C:\Users\Abhi\AppData\Local\Temp\pip-ephem-wheel-cache-l3doh6w6\wheels\e8\3a\ac\a1a47ff2f5621ea13ecac16035f07c2c35ee2509404d828171
# Successfully built pageviewapi
# Installing collected packages: pageviewapi
#   Attempting uninstall: pageviewapi
#     Found existing installation: pageviewapi Undefined
#     Uninstalling pageviewapi-Undefined:
#       Successfully uninstalled pageviewapi-Undefined
# Successfully installed pageviewapi-0.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
## Page view counter from 07/01/2015 to 08/06/2021
import pageviewapi
page_views = pageviewapi.per_article('en.wikipedia', 'Autism', '20150107', '20210607',
                        access='all-access', agent='all-agents', granularity='daily')

view_counter = 0
for i in range (0, len(page_views['items'])):
    view_counter += page_views['items'][i]['views']

# %%
view_counter
# Out:
# 12307544

# %%
f=open("consolidated_data.csv",'a+')
w=csv.writer(f)
for path, dirs, files in os.walk("C:/Users/Amber/Creator"):
    for filename in files:
        w.writerow([filename])

# %%
#Write page id to output file
import csv   
import os, csv
import json



for path, dirs, files in os.walk('.\protectedPageData'):
    for filename in files:
        if (filename.startswith('.')):
            continue
        else:
            ##Add filename to the depp_dataset.csv file
            print ('Processing file...',filename)
            with open (path + "/" + filename,"r") as f:
                data = json.load(f)
            title = data['query']['pages'][filename]['title']
            print(title)
            
            protection_statuses = []
            protection_list_json = data['query']['pages'][filename]['protection']
            for i in range (0,len(protection_list_json)):
                protection_status = protection_list_json[i]['level']
                protection_statuses.append(protection_status)
                
            
            protection_statuses_str = ','.join(protection_statuses)
                
            print('Protection status:', protection_statuses_str)
                       
            filename_list = [filename, title,protection_statuses_str]
            print (filename_list)
            with open(r'hello.csv', 'a', encoding="utf-8") as f:
                writer = csv.writer(f)
                writer.writerow(filename_list)
# Out:
# Processing file... 100062
# Super Mario 64
# Protection status: autoconfirmed,autoconfirmed
# ['100062', 'Super Mario 64', 'autoconfirmed,autoconfirmed']
# Processing file... 1001251
# Robert Spencer (author)
# Protection status: autoconfirmed,autoconfirmed
# ['1001251', 'Robert Spencer (author)', 'autoconfirmed,autoconfirmed']
# Processing file... 100127
# Florence Nightingale
# Protection status: autoconfirmed,autoconfirmed
# ['100127', 'Florence Nightingale', 'autoconfirmed,autoconfirmed']
# Processing file... 10012799
# Barstow Harvey House
# Protection status: autoconfirmed,autoconfirmed
# ['10012799', 'Barstow Harvey House', 'autoconfirmed,autoconfirmed']
# Processing file... 1001666
# List of Dragon Ball characters
# Protection status: autoconfirmed,autoconfirmed
# ['1001666', 'List of Dragon Ball characters', 'autoconfirmed,autoconfirmed']
# Processing file... 1001707
# Jaffa Cakes
# Protection status: autoconfirmed,autoconfirmed
# ['1001707', 'Jaffa Cakes', 'autoconfirmed,autoconfirmed']
# Processing file... 100196
# Tim Westwood
# Protection status: autoconfirmed,autoconfirmed
# ['100196', 'Tim Westwood', 'autoconfirmed,autoconfirmed']
# Processing file... 10024
# MDMA
# Protection status: autoconfirmed,autoconfirmed
# ['10024', 'MDMA', 'autoconfirmed,autoconfirmed']
# Processing file... 10039332
# Consol Energy Center
# Protection status: autoconfirmed,autoconfirmed
# ['10039332', 'Consol Energy Center', 'autoconfirmed,autoconfirmed']
# Processing file... 1004706
# Dysarthria
# Protection status: autoconfirmed,autoconfirmed
# ['1004706', 'Dysarthria', 'autoconfirmed,autoconfirmed']
# Processing file... 100627
# Emo
# Protection status: autoconfirmed,sysop
# ['100627', 'Emo', 'autoconfirmed,sysop']
# Processing file... 10079827
# Max Blumenthal
# Protection status: autoconfirmed
# ['10079827', 'Max Blumenthal', 'autoconfirmed']
# Processing file... 1008436
# Eustace Mullins
# Protection status: autoconfirmed,autoconfirmed
# ['1008436', 'Eustace Mullins', 'autoconfirmed,autoconfirmed']
# Processing file... 10086685
# Chris Malkin
# Protection status: autoconfirmed,autoconfirmed
# ['10086685', 'Chris Malkin', 'autoconfirmed,autoconfirmed']
# Processing file... 10089424
# Kearnan Myall
# Protection status: autoconfirmed,autoconfirmed
# ['10089424', 'Kearnan Myall', 'autoconfirmed,autoconfirmed']
# Processing file... 1009259
# Macy's Thanksgiving Day Parade
# Protection status: autoconfirmed
# ['1009259', "Macy's Thanksgiving Day Parade", 'autoconfirmed']
# Processing file... 10099763
# Green Hills Engineering College
# Protection status: autoconfirmed
# ['10099763', 'Green Hills Engineering College', 'autoconfirmed']
# Processing file... 10101151
# IQ and Global Inequality
# Protection status: autoconfirmed
# ['10101151', 'IQ and Global Inequality', 'autoconfirmed']
# Processing file... 10106
# Earthquake
# Protection status: autoconfirmed,autoconfirmed
# ['10106', 'Earthquake', 'autoconfirmed,autoconfirmed']
# Processing file... 10111390
# Guild Wars 2
# Protection status: autoconfirmed,autoconfirmed
# ['10111390', 'Guild Wars 2', 'autoconfirmed,autoconfirmed']
# Processing file... 10128
# Elizabeth I of England
# Protection status: autoconfirmed,sysop
# ['10128', 'Elizabeth I of England', 'autoconfirmed,sysop']
# Processing file... 1014
# Alcohol
# Protection status: autoconfirmed,sysop
# ['1014', 'Alcohol', 'autoconfirmed,sysop']
# Processing file... 10157131
# Diego Costa
# Protection status: autoconfirmed,autoconfirmed
# ['10157131', 'Diego Costa', 'autoconfirmed,autoconfirmed']
# Processing file... 10160866
# List of Canadian inventions
# Protection status: autoconfirmed,autoconfirmed
# ['10160866', 'List of Canadian inventions', 'autoconfirmed,autoconfirmed']
# Processing file... 101679
# VRML
# Protection status: autoconfirmed,autoconfirmed
# ['101679', 'VRML', 'autoconfirmed,autoconfirmed']
# Processing file... 10172009
# Kulraj Randhawa
# Protection status: autoconfirmed,autoconfirmed
# ['10172009', 'Kulraj Randhawa', 'autoconfirmed,autoconfirmed']
# Processing file... 1017610
# Dido (disambiguation)
# Protection status: autoconfirmed,autoconfirmed
# ['1017610', 'Dido (disambiguation)', 'autoconfirmed,autoconfirmed']
# Processing file... 1018018
# Burzynski Clinic
# Protection status: autoconfirmed,autoconfirmed
# ['1018018', 'Burzynski Clinic', 'autoconfirmed,autoconfirmed']
# Processing file... 101942
# Child labour
# Protection status: autoconfirmed
# ['101942', 'Child labour', 'autoconfirmed']
# Processing file... 101970
# Tinnitus
# Protection status: autoconfirmed,autoconfirmed
# ['101970', 'Tinnitus', 'autoconfirmed,autoconfirmed']
# Processing file... 10200539
# Premier Basketball League
# Protection status: autoconfirmed
# ['10200539', 'Premier Basketball League', 'autoconfirmed']
# Processing file... 1021390
# Sebastián Vizcaíno
# Protection status: autoconfirmed,autoconfirmed
# ['1021390', 'Sebastián Vizcaíno', 'autoconfirmed,autoconfirmed']
# Processing file... 102210
# Arthur (TV series)
# Protection status: autoconfirmed,autoconfirmed
# ['102210', 'Arthur (TV series)', 'autoconfirmed,autoconfirmed']
# Processing file... 1022192
# Nokia 3310
# Protection status: autoconfirmed
# ['1022192', 'Nokia 3310', 'autoconfirmed']
# Processing file... 1024181
# Carlos Tevez
# Protection status: autoconfirmed,sysop
# ['1024181', 'Carlos Tevez', 'autoconfirmed,sysop']
# Processing file... 102490
# Dell
# Protection status: autoconfirmed,sysop
# ['102490', 'Dell', 'autoconfirmed,sysop']
# Processing file... 10255667
# The Biggest Loser Australia (season 1)
# Protection status: autoconfirmed,autoconfirmed
# ['10255667', 'The Biggest Loser Australia (season 1)', 'autoconfirmed,autoconfirmed']
# Processing file... 10256222
# The Biggest Loser Australia (season 2)
# Protection status: autoconfirmed,autoconfirmed
# ['10256222', 'The Biggest Loser Australia (season 2)', 'autoconfirmed,autoconfirmed']
# Processing file... 102567
# John Forbes Nash, Jr.
# Protection status: autoconfirmed,autoconfirmed
# ['102567', 'John Forbes Nash, Jr.', 'autoconfirmed,autoconfirmed']
# Processing file... 102690
# Adam Sandler
# Protection status: autoconfirmed,autoconfirmed
# ['102690', 'Adam Sandler', 'autoconfirmed,autoconfirmed']
# Processing file... 1027216
# Confraternity of Christian Doctrine
# Protection status: autoconfirmed,autoconfirmed
# ['1027216', 'Confraternity of Christian Doctrine', 'autoconfirmed,autoconfirmed']
# Processing file... 102724
# Kyrgyz people
# Protection status: autoconfirmed,autoconfirmed
# ['102724', 'Kyrgyz people', 'autoconfirmed,autoconfirmed']
# Processing file... 102745
# Abigail Adams
# Protection status: autoconfirmed,autoconfirmed
# ['102745', 'Abigail Adams', 'autoconfirmed,autoconfirmed']
# Processing file... 10276064
# Bill Nye
# Protection status: autoconfirmed
# ['10276064', 'Bill Nye', 'autoconfirmed']
# Processing file... 1027957
# Early Christianity
# Protection status: autoconfirmed,autoconfirmed
# ['1027957', 'Early Christianity', 'autoconfirmed,autoconfirmed']
# Processing file... 10284103
# House of Merode
# Protection status: autoconfirmed,autoconfirmed
# ['10284103', 'House of Merode', 'autoconfirmed,autoconfirmed']
# Processing file... 1028560
# Creighton Preparatory School
# Protection status: autoconfirmed,autoconfirmed
# ['1028560', 'Creighton Preparatory School', 'autoconfirmed,autoconfirmed']
# Processing file... 10291466
# Laura Marano
# Protection status: autoconfirmed
# ['10291466', 'Laura Marano', 'autoconfirmed']
# Processing file... 10292532
# ICarly
# Protection status: autoconfirmed,sysop
# ['10292532', 'ICarly', 'autoconfirmed,sysop']
# Processing file... 10303
# Evaporation
# Protection status: autoconfirmed
# ['10303', 'Evaporation', 'autoconfirmed']
# Processing file... 10304105
# Machete (film)
# Protection status: autoconfirmed
# ['10304105', 'Machete (film)', 'autoconfirmed']
# Processing file... 1030599
# Black History Month
# Protection status: autoconfirmed,autoconfirmed
# ['1030599', 'Black History Month', 'autoconfirmed,autoconfirmed']
# Processing file... 1030713
# Gabe Newell
# Protection status: autoconfirmed,autoconfirmed
# ['1030713', 'Gabe Newell', 'autoconfirmed,autoconfirmed']
# Processing file... 1031793
# Didier Drogba
# Protection status: autoconfirmed,autoconfirmed
# ['1031793', 'Didier Drogba', 'autoconfirmed,autoconfirmed']
# Processing file... 1033826
# Professional wrestling attacks
# Protection status: autoconfirmed,autoconfirmed
# ['1033826', 'Professional wrestling attacks', 'autoconfirmed,autoconfirmed']
# Processing file... 1033852
# Political views of Adolf Hitler
# Protection status: autoconfirmed
# ['1033852', 'Political views of Adolf Hitler', 'autoconfirmed']
# Processing file... 1033897
# Death of Adolf Hitler
# Protection status: autoconfirmed,autoconfirmed
# ['1033897', 'Death of Adolf Hitler', 'autoconfirmed,autoconfirmed']
# Processing file... 1033898
# Jim Norton (Irish actor)
# Protection status: autoconfirmed,autoconfirmed
# ['1033898', 'Jim Norton (Irish actor)', 'autoconfirmed,autoconfirmed']
# Processing file... 1034769
# Ugly
# Protection status: autoconfirmed,autoconfirmed
# ['1034769', 'Ugly', 'autoconfirmed,autoconfirmed']
# Processing file... 103695
# Master race
# Protection status: autoconfirmed
# ['103695', 'Master race', 'autoconfirmed']
# Processing file... 10374465
# Jordan Rhodes
# Protection status: autoconfirmed,autoconfirmed
# ['10374465', 'Jordan Rhodes', 'autoconfirmed,autoconfirmed']
# Processing file... 1038
# Aarhus
# Protection status: autoconfirmed,autoconfirmed
# ['1038', 'Aarhus', 'autoconfirmed,autoconfirmed']
# Processing file... 1038594
# Ameesha Patel
# Protection status: autoconfirmed,sysop
# ['1038594', 'Ameesha Patel', 'autoconfirmed,sysop']
# Processing file... 10391001
# Lil Wayne albums discography
# Protection status: autoconfirmed
# ['10391001', 'Lil Wayne albums discography', 'autoconfirmed']
# Processing file... 103930
# Soleil Moon Frye
# Protection status: autoconfirmed,autoconfirmed
# ['103930', 'Soleil Moon Frye', 'autoconfirmed,autoconfirmed']
# Processing file... 1039393
# Andrewsarchus
# Protection status: autoconfirmed
# ['1039393', 'Andrewsarchus', 'autoconfirmed']
# Processing file... 10396793
# The Holocaust
# Protection status: autoconfirmed,sysop
# ['10396793', 'The Holocaust', 'autoconfirmed,sysop']
# Processing file... 10403956
# Robert Garside
# Protection status: autoconfirmed,autoconfirmed
# ['10403956', 'Robert Garside', 'autoconfirmed,autoconfirmed']
# Processing file... 10404818
# Hindutash
# Protection status: autoconfirmed,autoconfirmed
# ['10404818', 'Hindutash', 'autoconfirmed,autoconfirmed']
# Processing file... 10407205
# Days of Our Lives cast members
# Protection status: autoconfirmed,autoconfirmed
# ['10407205', 'Days of Our Lives cast members', 'autoconfirmed,autoconfirmed']
# Processing file... 10410626
# John Adams
# Protection status: autoconfirmed,sysop
# ['10410626', 'John Adams', 'autoconfirmed,sysop']
# Processing file... 1041577
# Mark Henry
# Protection status: autoconfirmed
# ['1041577', 'Mark Henry', 'autoconfirmed']
# Processing file... 10419775
# Surana, Haryana
# Protection status: autoconfirmed,autoconfirmed
# ['10419775', 'Surana, Haryana', 'autoconfirmed,autoconfirmed']
# Processing file... 10422721
# Pacific Northwest tree octopus
# Protection status: autoconfirmed,autoconfirmed
# ['10422721', 'Pacific Northwest tree octopus', 'autoconfirmed,autoconfirmed']
# Processing file... 10442845
# Travel website
# Protection status: autoconfirmed,autoconfirmed
# ['10442845', 'Travel website', 'autoconfirmed,autoconfirmed']
# Processing file... 104444
# Dietary supplement
# Protection status: autoconfirmed,autoconfirmed
# ['104444', 'Dietary supplement', 'autoconfirmed,autoconfirmed']
# Processing file... 10445381
# Calvin Goddard (ballistics)
# Protection status: autoconfirmed,autoconfirmed
# ['10445381', 'Calvin Goddard (ballistics)', 'autoconfirmed,autoconfirmed']
# Processing file... 10449970
# List of TriStar Pictures films
# Protection status: autoconfirmed
# ['10449970', 'List of TriStar Pictures films', 'autoconfirmed']
# Processing file... 10468424
# Blah
# Protection status: autoconfirmed,autoconfirmed
# ['10468424', 'Blah', 'autoconfirmed,autoconfirmed']
# Processing file... 1047310
# Crosspool
# Protection status: autoconfirmed
# ['1047310', 'Crosspool', 'autoconfirmed']
# Processing file... 1047835
# Way of the Dragon
# Protection status: autoconfirmed
# ['1047835', 'Way of the Dragon', 'autoconfirmed']
# Processing file... 1047970
# Avenged Sevenfold
# Protection status: autoconfirmed,autoconfirmed
# ['1047970', 'Avenged Sevenfold', 'autoconfirmed,autoconfirmed']
# Processing file... 10483209
# Skilled Group
# Protection status: autoconfirmed
# ['10483209', 'Skilled Group', 'autoconfirmed']
# Processing file... 10485669
# Claire Holt
# Protection status: autoconfirmed,autoconfirmed
# ['10485669', 'Claire Holt', 'autoconfirmed,autoconfirmed']
# Processing file... 10494172
# Russell Kane
# Protection status: autoconfirmed,autoconfirmed
# ['10494172', 'Russell Kane', 'autoconfirmed,autoconfirmed']
# Processing file... 1050479
# BloodRayne 2
# Protection status: autoconfirmed
# ['1050479', 'BloodRayne 2', 'autoconfirmed']
# Processing file... 10509730
# Alec Butler
# Protection status: autoconfirmed,autoconfirmed
# ['10509730', 'Alec Butler', 'autoconfirmed,autoconfirmed']
# Processing file... 10515516
# Pooja Gandhi
# Protection status: autoconfirmed
# ['10515516', 'Pooja Gandhi', 'autoconfirmed']
# Processing file... 105219
# Cancer
# Protection status: autoconfirmed,sysop
# ['105219', 'Cancer', 'autoconfirmed,sysop']
# Processing file... 105390
# Pheromone
# Protection status: autoconfirmed,autoconfirmed
# ['105390', 'Pheromone', 'autoconfirmed,autoconfirmed']
# Processing file... 1056193
# Wendy Williams
# Protection status: autoconfirmed,autoconfirmed
# ['1056193', 'Wendy Williams', 'autoconfirmed,autoconfirmed']
# Processing file... 1056208
# Jure Francetić
# Protection status: autoconfirmed,autoconfirmed
# ['1056208', 'Jure Francetić', 'autoconfirmed,autoconfirmed']
# Processing file... 1056214
# Ljubo Miloš
# Protection status: autoconfirmed,autoconfirmed
# ['1056214', 'Ljubo Miloš', 'autoconfirmed,autoconfirmed']
# Processing file... 10567534
# Blake Griffin
# Protection status: autoconfirmed
# ['10567534', 'Blake Griffin', 'autoconfirmed']
# Processing file... 10568
# Association football
# Protection status: autoconfirmed,autoconfirmed
# ['10568', 'Association football', 'autoconfirmed,autoconfirmed']
# Processing file... 1057414
# Traumatic brain injury
# Protection status: autoconfirmed,autoconfirmed
# ['1057414', 'Traumatic brain injury', 'autoconfirmed,autoconfirmed']
# Processing file... 10579795
# Olga Fedori
# Protection status: autoconfirmed,autoconfirmed
# ['10579795', 'Olga Fedori', 'autoconfirmed,autoconfirmed']
# Processing file... 1058843
# Loge
# Protection status: autoconfirmed,autoconfirmed
# ['1058843', 'Loge', 'autoconfirmed,autoconfirmed']
# Processing file... 105922
# King David Hotel bombing
# Protection status: autoconfirmed
# ['105922', 'King David Hotel bombing', 'autoconfirmed']
# Processing file... 10595985
# Phil Nibbelink
# Protection status: autoconfirmed,autoconfirmed
# ['10595985', 'Phil Nibbelink', 'autoconfirmed,autoconfirmed']
# Processing file... 1059962
# KVIE
# Protection status: autoconfirmed,autoconfirmed
# ['1059962', 'KVIE', 'autoconfirmed,autoconfirmed']
# Processing file... 10605960
# Non-penetrative sex
# Protection status: autoconfirmed,sysop
# ['10605960', 'Non-penetrative sex', 'autoconfirmed,sysop']
# Processing file... 1061021
# List of secret police organizations
# Protection status: autoconfirmed,autoconfirmed
# ['1061021', 'List of secret police organizations', 'autoconfirmed,autoconfirmed']
# Processing file... 10624594
# Krypton
# Protection status: autoconfirmed,sysop
# ['10624594', 'Krypton', 'autoconfirmed,sysop']
# Processing file... 10636232
# The Pussycat Dolls
# Protection status: autoconfirmed,sysop
# ['10636232', 'The Pussycat Dolls', 'autoconfirmed,sysop']
# Processing file... 10646
# Food
# Protection status: autoconfirmed,sysop
# ['10646', 'Food', 'autoconfirmed,sysop']
# Processing file... 1066018
# Philip J. Kaplan
# Protection status: autoconfirmed,autoconfirmed
# ['1066018', 'Philip J. Kaplan', 'autoconfirmed,autoconfirmed']
# Processing file... 10667484
# Ilion Animation Studios
# Protection status: autoconfirmed
# ['10667484', 'Ilion Animation Studios', 'autoconfirmed']
# Processing file... 1068143
# The Young Turks
# Protection status: autoconfirmed
# ['1068143', 'The Young Turks', 'autoconfirmed']
# Processing file... 10682197
# List of Waterloo Road characters
# Protection status: autoconfirmed,autoconfirmed
# ['10682197', 'List of Waterloo Road characters', 'autoconfirmed,autoconfirmed']
# Processing file... 10693894
# Suicide Silence
# Protection status: autoconfirmed,autoconfirmed
# ['10693894', 'Suicide Silence', 'autoconfirmed,autoconfirmed']
# Processing file... 1070152
# Mugger crocodile
# Protection status: autoconfirmed,autoconfirmed
# ['1070152', 'Mugger crocodile', 'autoconfirmed,autoconfirmed']
# Processing file... 10711867
# Signal Mountain Middle High School
# Protection status: autoconfirmed,autoconfirmed
# ['10711867', 'Signal Mountain Middle High School', 'autoconfirmed,autoconfirmed']
# Processing file... 10721157
# Shirley Phelps-Roper
# Protection status: autoconfirmed,autoconfirmed
# ['10721157', 'Shirley Phelps-Roper', 'autoconfirmed,autoconfirmed']
# Processing file... 1075887
# John Key
# Protection status: autoconfirmed,autoconfirmed
# ['1075887', 'John Key', 'autoconfirmed,autoconfirmed']
# Processing file... 10771083
# Phan Đình Phùng
# Protection status: autoconfirmed,sysop
# ['10771083', 'Phan Đình Phùng', 'autoconfirmed,sysop']
# Processing file... 1077137
# 9/11 conspiracy theories
# Protection status: autoconfirmed,sysop
# ['1077137', '9/11 conspiracy theories', 'autoconfirmed,sysop']
# Processing file... 10772350
# History
# Protection status: autoconfirmed,sysop
# ['10772350', 'History', 'autoconfirmed,sysop']
# Processing file... 1078
# Antisemitism
# Protection status: autoconfirmed,sysop
# ['1078', 'Antisemitism', 'autoconfirmed,sysop']
# Processing file... 1078003
# Herbert Sandler
# Protection status: autoconfirmed,sysop
# ['1078003', 'Herbert Sandler', 'autoconfirmed,sysop']
# Processing file... 1078340
# Immortal Technique
# Protection status: autoconfirmed,autoconfirmed
# ['1078340', 'Immortal Technique', 'autoconfirmed,autoconfirmed']
# Processing file... 1079866
# Mantle (geology)
# Protection status: autoconfirmed,autoconfirmed
# ['1079866', 'Mantle (geology)', 'autoconfirmed,autoconfirmed']
# Processing file... 1081183
# Andrew Bolt
# Protection status: autoconfirmed,autoconfirmed
# ['1081183', 'Andrew Bolt', 'autoconfirmed,autoconfirmed']
# Processing file... 10816091
# BloodRayne (franchise)
# Protection status: autoconfirmed,autoconfirmed
# ['10816091', 'BloodRayne (franchise)', 'autoconfirmed,autoconfirmed']
# Processing file... 1081624
# Rise Against
# Protection status: autoconfirmed,autoconfirmed
# ['1081624', 'Rise Against', 'autoconfirmed,autoconfirmed']
# Processing file... 1082198
# Nicky Cruz
# Protection status: autoconfirmed,autoconfirmed
# ['1082198', 'Nicky Cruz', 'autoconfirmed,autoconfirmed']
# Processing file... 10823
# Frédéric Chopin
# Protection status: autoconfirmed,sysop
# ['10823', 'Frédéric Chopin', 'autoconfirmed,sysop']
# Processing file... 1082583
# Interstate Highways in Alaska
# Protection status: autoconfirmed
# ['1082583', 'Interstate Highways in Alaska', 'autoconfirmed']
# Processing file... 10841641
# Antonio Arnaiz-Villena
# Protection status: autoconfirmed,autoconfirmed
# ['10841641', 'Antonio Arnaiz-Villena', 'autoconfirmed,autoconfirmed']
# Processing file... 10843
# Fruit
# Protection status: autoconfirmed,sysop
# ['10843', 'Fruit', 'autoconfirmed,sysop']
# Processing file... 1084540
# Ian Somerhalder
# Protection status: autoconfirmed,autoconfirmed
# ['1084540', 'Ian Somerhalder', 'autoconfirmed,autoconfirmed']
# Processing file... 10851639
# List of male performers in gay porn films
# Protection status: autoconfirmed,autoconfirmed
# ['10851639', 'List of male performers in gay porn films', 'autoconfirmed,autoconfirmed']
# Processing file... 10884089
# List of The New Adventures of Winnie the Pooh episodes
# Protection status: autoconfirmed,autoconfirmed
# ['10884089', 'List of The New Adventures of Winnie the Pooh episodes', 'autoconfirmed,autoconfirmed']
# Processing file... 10891776
# Call of Duty 4: Modern Warfare
# Protection status: autoconfirmed,sysop
# ['10891776', 'Call of Duty 4: Modern Warfare', 'autoconfirmed,sysop']
# Processing file... 108956
# Washington, D.C.
# Protection status: autoconfirmed,sysop
# ['108956', 'Washington, D.C.', 'autoconfirmed,sysop']
# Processing file... 10906185
# Gurjar
# Protection status: autoconfirmed,sysop
# ['10906185', 'Gurjar', 'autoconfirmed,sysop']
# Processing file... 109179
# Bell, Florida
# Protection status: autoconfirmed,autoconfirmed
# ['109179', 'Bell, Florida', 'autoconfirmed,autoconfirmed']
# Processing file... 10919134
# Jozy Altidore
# Protection status: autoconfirmed,autoconfirmed
# ['10919134', 'Jozy Altidore', 'autoconfirmed,autoconfirmed']
# Processing file... 1092923
# Google
# Protection status: autoconfirmed,sysop
# ['1092923', 'Google', 'autoconfirmed,sysop']
# Processing file... 10951
# Fahrenheit 451
# Protection status: autoconfirmed,autoconfirmed
# ['10951', 'Fahrenheit 451', 'autoconfirmed,autoconfirmed']
# Processing file... 1095706
# Jesus
# Protection status: autoconfirmed,sysop
# ['1095706', 'Jesus', 'autoconfirmed,sysop']
# Processing file... 10958
# Fossil
# Protection status: autoconfirmed,sysop
# ['10958', 'Fossil', 'autoconfirmed,sysop']
# Processing file... 10960729
# Mike Harper
# Protection status: autoconfirmed,autoconfirmed
# ['10960729', 'Mike Harper', 'autoconfirmed,autoconfirmed']
# Processing file... 10964586
# Tottington High School
# Protection status: autoconfirmed,autoconfirmed
# ['10964586', 'Tottington High School', 'autoconfirmed,autoconfirmed']
# Processing file... 10972664
# Young Money Entertainment
# Protection status: autoconfirmed,autoconfirmed
# ['10972664', 'Young Money Entertainment', 'autoconfirmed,autoconfirmed']
# Processing file... 10979
# Franklin D. Roosevelt
# Protection status: autoconfirmed,sysop
# ['10979', 'Franklin D. Roosevelt', 'autoconfirmed,sysop']
# Processing file... 1098645
# Djedefre
# Protection status: autoconfirmed,autoconfirmed
# ['1098645', 'Djedefre', 'autoconfirmed,autoconfirmed']
# Processing file... 10999148
# Pierce the Veil
# Protection status: autoconfirmed
# ['10999148', 'Pierce the Veil', 'autoconfirmed']
# Processing file... 1100953
# Khachkar
# Protection status: autoconfirmed,sysop
# ['1100953', 'Khachkar', 'autoconfirmed,sysop']
# Processing file... 1101067
# KAPAP
# Protection status: autoconfirmed,autoconfirmed
# ['1101067', 'KAPAP', 'autoconfirmed,autoconfirmed']
# Processing file... 11014515
# List of ethnic slurs
# Protection status: autoconfirmed,sysop
# ['11014515', 'List of ethnic slurs', 'autoconfirmed,sysop']
# Processing file... 11015252
# Vladimir Lenin
# Protection status: autoconfirmed,sysop
# ['11015252', 'Vladimir Lenin', 'autoconfirmed,sysop']
# Processing file... 1102136
# Sambandar
# Protection status: autoconfirmed
# ['1102136', 'Sambandar', 'autoconfirmed']
# Processing file... 1102585
# New Brunswick general election, 1987
# Protection status: autoconfirmed,autoconfirmed
# ['1102585', 'New Brunswick general election, 1987', 'autoconfirmed,autoconfirmed']
# Processing file... 11026242
# Traumatic insemination
# Protection status: autoconfirmed,autoconfirmed
# ['11026242', 'Traumatic insemination', 'autoconfirmed,autoconfirmed']
# Processing file... 11030872
# God Made Me Funky
# Protection status: autoconfirmed,autoconfirmed
# ['11030872', 'God Made Me Funky', 'autoconfirmed,autoconfirmed']
# Processing file... 11033
# Frederick Douglass
# Protection status: autoconfirmed
# ['11033', 'Frederick Douglass', 'autoconfirmed']
# Processing file... 11038318
# Methamphetamine
# Protection status: autoconfirmed,sysop
# ['11038318', 'Methamphetamine', 'autoconfirmed,sysop']
# Processing file... 1103839
# List of Freemasons
# Protection status: autoconfirmed,autoconfirmed
# ['1103839', 'List of Freemasons', 'autoconfirmed,autoconfirmed']
# Processing file... 11039790
# Animal
# Protection status: autoconfirmed,sysop
# ['11039790', 'Animal', 'autoconfirmed,sysop']
# Processing file... 1104035
# Boob
# Protection status: autoconfirmed,autoconfirmed
# ['1104035', 'Boob', 'autoconfirmed,autoconfirmed']
# Processing file... 11042
# Fat
# Protection status: autoconfirmed,sysop
# ['11042', 'Fat', 'autoconfirmed,sysop']
# Processing file... 1104310
# James L. Dolan
# Protection status: autoconfirmed,autoconfirmed
# ['1104310', 'James L. Dolan', 'autoconfirmed,autoconfirmed']
# Processing file... 11044005
# Satellite Spies
# Protection status: autoconfirmed,autoconfirmed
# ['11044005', 'Satellite Spies', 'autoconfirmed,autoconfirmed']
# Processing file... 1105029
# Nair
# Protection status: extendedconfirmed
# ['1105029', 'Nair', 'extendedconfirmed']
# Processing file... 11053801
# Maz Jobrani
# Protection status: autoconfirmed,autoconfirmed
# ['11053801', 'Maz Jobrani', 'autoconfirmed,autoconfirmed']
# Processing file... 11054586
# North View Secondary School
# Protection status: autoconfirmed,autoconfirmed
# ['11054586', 'North View Secondary School', 'autoconfirmed,autoconfirmed']
# Processing file... 1105480
# Mushroomhead
# Protection status: autoconfirmed
# ['1105480', 'Mushroomhead', 'autoconfirmed']
# Processing file... 11058016
# Mohammad Asghar
# Protection status: autoconfirmed,autoconfirmed
# ['11058016', 'Mohammad Asghar', 'autoconfirmed,autoconfirmed']
# Processing file... 11059
# Five Pillars of Islam
# Protection status: autoconfirmed,autoconfirmed
# ['11059', 'Five Pillars of Islam', 'autoconfirmed,autoconfirmed']
# Processing file... 11059398
# Adult diaper
# Protection status: autoconfirmed,autoconfirmed
# ['11059398', 'Adult diaper', 'autoconfirmed,autoconfirmed']
# Processing file... 1106026
# Beth Ostrosky Stern
# Protection status: autoconfirmed,autoconfirmed
# ['1106026', 'Beth Ostrosky Stern', 'autoconfirmed,autoconfirmed']
# Processing file... 11062
# Friction
# Protection status: autoconfirmed
# ['11062', 'Friction', 'autoconfirmed']
# Processing file... 11069849
# Disappearance of Madeleine McCann
# Protection status: autoconfirmed,sysop
# ['11069849', 'Disappearance of Madeleine McCann', 'autoconfirmed,sysop']
# Processing file... 11079079
# Mongolian barbecue
# Protection status: autoconfirmed,autoconfirmed
# ['11079079', 'Mongolian barbecue', 'autoconfirmed,autoconfirmed']
# Processing file... 1108159
# Carcharodontosaurus
# Protection status: autoconfirmed,autoconfirmed
# ['1108159', 'Carcharodontosaurus', 'autoconfirmed,autoconfirmed']
# Processing file... 11089416
# Test
# Protection status: autoconfirmed,sysop
# ['11089416', 'Test', 'autoconfirmed,sysop']
# Processing file... 1109104
# Ray Comfort
# Protection status: autoconfirmed,autoconfirmed
# ['1109104', 'Ray Comfort', 'autoconfirmed,autoconfirmed']
# Processing file... 11091078
# Dragon Ball
# Protection status: autoconfirmed,sysop
# ['11091078', 'Dragon Ball', 'autoconfirmed,sysop']
# Processing file... 1109945
# Turkish Naval Forces
# Protection status: autoconfirmed,autoconfirmed
# ['1109945', 'Turkish Naval Forces', 'autoconfirmed,autoconfirmed']
# Processing file... 11100573
# Nguyen Tu Quang
# Protection status: autoconfirmed,autoconfirmed
# ['11100573', 'Nguyen Tu Quang', 'autoconfirmed,autoconfirmed']
# Processing file... 11115779
# George Runner
# Protection status: autoconfirmed,autoconfirmed
# ['11115779', 'George Runner', 'autoconfirmed,autoconfirmed']
# Processing file... 11121
# Fox News Channel
# Protection status: autoconfirmed,sysop
# ['11121', 'Fox News Channel', 'autoconfirmed,sysop']
# Processing file... 11123648
# Canterbury University (Seychelles)
# Protection status: autoconfirmed,autoconfirmed
# ['11123648', 'Canterbury University (Seychelles)', 'autoconfirmed,autoconfirmed']
# Processing file... 11125639
# Turkey
# Protection status: autoconfirmed,sysop
# ['11125639', 'Turkey', 'autoconfirmed,sysop']
# Processing file... 11127
# Federal Bureau of Investigation
# Protection status: autoconfirmed,sysop
# ['11127', 'Federal Bureau of Investigation', 'autoconfirmed,sysop']
# Processing file... 11137057
# BlueWare
# Protection status: autoconfirmed,autoconfirmed
# ['11137057', 'BlueWare', 'autoconfirmed,autoconfirmed']
# Processing file... 1113854
# .ru
# Protection status: autoconfirmed
# ['1113854', '.ru', 'autoconfirmed']
# Processing file... 11145
# Fire
# Protection status: autoconfirmed,sysop
# ['11145', 'Fire', 'autoconfirmed,sysop']
# Processing file... 1114570
# John O'Shea
# Protection status: autoconfirmed,autoconfirmed
# ['1114570', "John O'Shea", 'autoconfirmed,autoconfirmed']
# Processing file... 11146900
# Barney in Outer Space
# Protection status: autoconfirmed
# ['11146900', 'Barney in Outer Space', 'autoconfirmed']
# Processing file... 1114732
# Palestine (region)
# Protection status: autoconfirmed,sysop
# ['1114732', 'Palestine (region)', 'autoconfirmed,sysop']
# Processing file... 1116006
# Histeria!
# Protection status: autoconfirmed
# ['1116006', 'Histeria!', 'autoconfirmed']
# Processing file... 1116229
# Genesis creation narrative
# Protection status: autoconfirmed,sysop
# ['1116229', 'Genesis creation narrative', 'autoconfirmed,sysop']
# Processing file... 1116804
# Guard dog
# Protection status: autoconfirmed,autoconfirmed
# ['1116804', 'Guard dog', 'autoconfirmed,autoconfirmed']
# Processing file... 1117328
# Pickaxe
# Protection status: autoconfirmed,autoconfirmed
# ['1117328', 'Pickaxe', 'autoconfirmed,autoconfirmed']
# Processing file... 11177519
# Bajót
# Protection status: autoconfirmed,autoconfirmed
# ['11177519', 'Bajót', 'autoconfirmed,autoconfirmed']
# Processing file... 1117939
# Fernando Torres
# Protection status: autoconfirmed,sysop
# ['1117939', 'Fernando Torres', 'autoconfirmed,sysop']
# Processing file... 1118379
# Online shopping
# Protection status: autoconfirmed,autoconfirmed
# ['1118379', 'Online shopping', 'autoconfirmed,autoconfirmed']
# Processing file... 11185
# Feminism
# Protection status: autoconfirmed,sysop
# ['11185', 'Feminism', 'autoconfirmed,sysop']
# Processing file... 11185534
# Babu Antony
# Protection status: autoconfirmed,autoconfirmed
# ['11185534', 'Babu Antony', 'autoconfirmed,autoconfirmed']
# Processing file... 11188
# French Revolution
# Protection status: autoconfirmed,sysop
# ['11188', 'French Revolution', 'autoconfirmed,sysop']
# Processing file... 1118915
# Sheeple
# Protection status: autoconfirmed,autoconfirmed
# ['1118915', 'Sheeple', 'autoconfirmed,autoconfirmed']
# Processing file... 1119701
# Physical medicine and rehabilitation
# Protection status: autoconfirmed,autoconfirmed
# ['1119701', 'Physical medicine and rehabilitation', 'autoconfirmed,autoconfirmed']
# Processing file... 11206371
# List of Animals of Farthing Wood characters
# Protection status: autoconfirmed,sysop
# ['11206371', 'List of Animals of Farthing Wood characters', 'autoconfirmed,sysop']
# Processing file... 11217925
# Paris Hilton
# Protection status: autoconfirmed,sysop
# ['11217925', 'Paris Hilton', 'autoconfirmed,sysop']
# Processing file... 11223317
# Prince Devitt
# Protection status: autoconfirmed,autoconfirmed
# ['11223317', 'Prince Devitt', 'autoconfirmed,autoconfirmed']
# Processing file... 11223633
# Aiglon College
# Protection status: autoconfirmed,autoconfirmed
# ['11223633', 'Aiglon College', 'autoconfirmed,autoconfirmed']
# Processing file... 11227
# Freemasonry
# Protection status: autoconfirmed,autoconfirmed
# ['11227', 'Freemasonry', 'autoconfirmed,autoconfirmed']
# Processing file... 112274
# The Blitz
# Protection status: autoconfirmed,sysop
# ['112274', 'The Blitz', 'autoconfirmed,sysop']
# Processing file... 1123327
# 1998 San Marino Grand Prix
# Protection status: autoconfirmed,autoconfirmed
# ['1123327', '1998 San Marino Grand Prix', 'autoconfirmed,autoconfirmed']
# Processing file... 1123369
# Historiography of the fall of the Western Roman Empire
# Protection status: autoconfirmed,autoconfirmed
# ['1123369', 'Historiography of the fall of the Western Roman Empire', 'autoconfirmed,autoconfirmed']
# Processing file... 11236
# Fart
# Protection status: autoconfirmed,sysop
# ['11236', 'Fart', 'autoconfirmed,sysop']
# Processing file... 11237896
# Kalya
# Protection status: autoconfirmed,autoconfirmed
# ['11237896', 'Kalya', 'autoconfirmed,autoconfirmed']
# Processing file... 11240
# Flatulence
# Protection status: autoconfirmed,sysop
# ['11240', 'Flatulence', 'autoconfirmed,sysop']
# Processing file... 11247682
# The Devil Wears Prada (band)
# Protection status: autoconfirmed,autoconfirmed
# ['11247682', 'The Devil Wears Prada (band)', 'autoconfirmed,autoconfirmed']
# Processing file... 11250
# Premier League
# Protection status: autoconfirmed,sysop
# ['11250', 'Premier League', 'autoconfirmed,sysop']
# Processing file... 11258
# Fellatio
# Protection status: autoconfirmed
# ['11258', 'Fellatio', 'autoconfirmed']
# Processing file... 11260
# Relax (song)
# Protection status: autoconfirmed,autoconfirmed
# ['11260', 'Relax (song)', 'autoconfirmed,autoconfirmed']
# Processing file... 11260577
# Ann Romney
# Protection status: autoconfirmed,autoconfirmed
# ['11260577', 'Ann Romney', 'autoconfirmed,autoconfirmed']
# Processing file... 11263766
# Diary of a Wimpy Kid
# Protection status: autoconfirmed,autoconfirmed
# ['11263766', 'Diary of a Wimpy Kid', 'autoconfirmed,autoconfirmed']
# Processing file... 1126490
# Yard of ale
# Protection status: autoconfirmed,autoconfirmed
# ['1126490', 'Yard of ale', 'autoconfirmed,autoconfirmed']
# Processing file... 1126578
# Ciara
# Protection status: autoconfirmed,autoconfirmed
# ['1126578', 'Ciara', 'autoconfirmed,autoconfirmed']
# Processing file... 1127442
# Mohammed Burhanuddin
# Protection status: autoconfirmed,sysop
# ['1127442', 'Mohammed Burhanuddin', 'autoconfirmed,sysop']
# Processing file... 11276293
# Gargamel
# Protection status: autoconfirmed
# ['11276293', 'Gargamel', 'autoconfirmed']
# Processing file... 11286472
# Renee Alway
# Protection status: autoconfirmed,autoconfirmed
# ['11286472', 'Renee Alway', 'autoconfirmed,autoconfirmed']
# Processing file... 11288250
# Martin Hirsch
# Protection status: autoconfirmed,autoconfirmed
# ['11288250', 'Martin Hirsch', 'autoconfirmed,autoconfirmed']
# Processing file... 11291
# Floccinaucinihilipilification
# Protection status: autoconfirmed,autoconfirmed
# ['11291', 'Floccinaucinihilipilification', 'autoconfirmed,autoconfirmed']
# Processing file... 1129182
# Leonardo Araújo
# Protection status: autoconfirmed,autoconfirmed
# ['1129182', 'Leonardo Araújo', 'autoconfirmed,autoconfirmed']
# Processing file... 1129697
# Paper plane
# Protection status: autoconfirmed
# ['1129697', 'Paper plane', 'autoconfirmed']
# Processing file... 11299
# Fox
# Protection status: autoconfirmed,sysop
# ['11299', 'Fox', 'autoconfirmed,sysop']
# Processing file... 1130104
# New Brunswick general election, 1982
# Protection status: autoconfirmed,autoconfirmed
# ['1130104', 'New Brunswick general election, 1982', 'autoconfirmed,autoconfirmed']
# Processing file... 113055
# Temperament
# Protection status: autoconfirmed,autoconfirmed
# ['113055', 'Temperament', 'autoconfirmed,autoconfirmed']
# Processing file... 1130636
# Master Chief (Halo)
# Protection status: autoconfirmed,autoconfirmed
# ['1130636', 'Master Chief (Halo)', 'autoconfirmed,autoconfirmed']
# Processing file... 11315
# Friends
# Protection status: autoconfirmed,sysop
# ['11315', 'Friends', 'autoconfirmed,sysop']
# Processing file... 113180
# Pussy
# Protection status: autoconfirmed,sysop
# ['113180', 'Pussy', 'autoconfirmed,sysop']
# Processing file... 11330163
# List of dubstep musicians
# Protection status: autoconfirmed,autoconfirmed
# ['11330163', 'List of dubstep musicians', 'autoconfirmed,autoconfirmed']
# Processing file... 11345507
# List of Tak and the Power of Juju episodes
# Protection status: autoconfirmed
# ['11345507', 'List of Tak and the Power of Juju episodes', 'autoconfirmed']
# Processing file... 11347320
# Saint Thomas More High School (Milwaukee)
# Protection status: autoconfirmed,autoconfirmed
# ['11347320', 'Saint Thomas More High School (Milwaukee)', 'autoconfirmed,autoconfirmed']
# Processing file... 113525
# Dick
# Protection status: autoconfirmed,sysop
# ['113525', 'Dick', 'autoconfirmed,sysop']
# Processing file... 11366634
# Katie Hopkins
# Protection status: autoconfirmed,autoconfirmed
# ['11366634', 'Katie Hopkins', 'autoconfirmed,autoconfirmed']
# Processing file... 1136832
# Duran Duran discography
# Protection status: autoconfirmed,autoconfirmed
# ['1136832', 'Duran Duran discography', 'autoconfirmed,autoconfirmed']
# Processing file... 11370
# FIFA World Cup
# Protection status: autoconfirmed
# ['11370', 'FIFA World Cup', 'autoconfirmed']
# Processing file... 11371144
# WRFF
# Protection status: autoconfirmed,autoconfirmed
# ['11371144', 'WRFF', 'autoconfirmed,autoconfirmed']
# Processing file... 113728
# Geothermal energy
# Protection status: autoconfirmed,autoconfirmed
# ['113728', 'Geothermal energy', 'autoconfirmed,autoconfirmed']
# Processing file... 113746
# Sean Penn
# Protection status: autoconfirmed,sysop
# ['113746', 'Sean Penn', 'autoconfirmed,sysop']
# Processing file... 11392263
# Sacramento County Jail
# Protection status: autoconfirmed,autoconfirmed
# ['11392263', 'Sacramento County Jail', 'autoconfirmed,autoconfirmed']
# Processing file... 11403316
# Compressed sensing
# Protection status: autoconfirmed,autoconfirmed
# ['11403316', 'Compressed sensing', 'autoconfirmed,autoconfirmed']
# Processing file... 11408
# Female genital mutilation
# Protection status: autoconfirmed,autoconfirmed
# ['11408', 'Female genital mutilation', 'autoconfirmed,autoconfirmed']
# Processing file... 11411461
# Ola Toivonen
# Protection status: autoconfirmed,autoconfirmed
# ['11411461', 'Ola Toivonen', 'autoconfirmed,autoconfirmed']
# Processing file... 1141314
# California Miramar University
# Protection status: autoconfirmed,autoconfirmed
# ['1141314', 'California Miramar University', 'autoconfirmed,autoconfirmed']
# Processing file... 1141494
# Salif Diao
# Protection status: autoconfirmed,autoconfirmed
# ['1141494', 'Salif Diao', 'autoconfirmed,autoconfirmed']
# Processing file... 11415141
# Masturbation
# Protection status: autoconfirmed,sysop
# ['11415141', 'Masturbation', 'autoconfirmed,sysop']
# Processing file... 1142195
# Onogurs
# Protection status: autoconfirmed,autoconfirmed
# ['1142195', 'Onogurs', 'autoconfirmed,autoconfirmed']
# Processing file... 1143036
# Chelmsley Wood
# Protection status: autoconfirmed,autoconfirmed
# ['1143036', 'Chelmsley Wood', 'autoconfirmed,autoconfirmed']
# Processing file... 1143659
# Ruby Bridges
# Protection status: autoconfirmed,autoconfirmed
# ['1143659', 'Ruby Bridges', 'autoconfirmed,autoconfirmed']
# Processing file... 1143923
# Honolulu University
# Protection status: autoconfirmed,autoconfirmed
# ['1143923', 'Honolulu University', 'autoconfirmed,autoconfirmed']
# Processing file... 11447
# Flag of the United States
# Protection status: autoconfirmed,autoconfirmed
# ['11447', 'Flag of the United States', 'autoconfirmed,autoconfirmed']
# Processing file... 11461
# Francis Crick
# Protection status: autoconfirmed,autoconfirmed
# ['11461', 'Francis Crick', 'autoconfirmed,autoconfirmed']
# Processing file... 11470826
# Jake T. Austin
# Protection status: autoconfirmed,autoconfirmed
# ['11470826', 'Jake T. Austin', 'autoconfirmed,autoconfirmed']
# Processing file... 11473533
# Adam and Eve
# Protection status: autoconfirmed,autoconfirmed
# ['11473533', 'Adam and Eve', 'autoconfirmed,autoconfirmed']
# Processing file... 11481790
# Nancy Grace
# Protection status: autoconfirmed,autoconfirmed
# ['11481790', 'Nancy Grace', 'autoconfirmed,autoconfirmed']
# Processing file... 11485528
# Dan O'Halloran
# Protection status: autoconfirmed,autoconfirmed
# ['11485528', "Dan O'Halloran", 'autoconfirmed,autoconfirmed']
# Processing file... 11492
# Foot
# Protection status: autoconfirmed,sysop
# ['11492', 'Foot', 'autoconfirmed,sysop']
# Processing file... 11495370
# Pershing Map
# Protection status: autoconfirmed
# ['11495370', 'Pershing Map', 'autoconfirmed']
# Processing file... 11504
# Fandom
# Protection status: autoconfirmed,autoconfirmed
# ['11504', 'Fandom', 'autoconfirmed,autoconfirmed']
# Processing file... 1150748
# Bhagat Singh
# Protection status: autoconfirmed,autoconfirmed
# ['1150748', 'Bhagat Singh', 'autoconfirmed,autoconfirmed']
# Processing file... 11508
# Francis Drake
# Protection status: autoconfirmed,sysop
# ['11508', 'Francis Drake', 'autoconfirmed,sysop']
# Processing file... 11511282
# YouPorn
# Protection status: autoconfirmed,sysop
# ['11511282', 'YouPorn', 'autoconfirmed,sysop']
# Processing file... 11521084
# Cassandra Clare
# Protection status: autoconfirmed,autoconfirmed
# ['11521084', 'Cassandra Clare', 'autoconfirmed,autoconfirmed']
# Processing file... 11546879
# Google Street View
# Protection status: autoconfirmed,autoconfirmed
# ['11546879', 'Google Street View', 'autoconfirmed,autoconfirmed']
# Processing file... 11548323
# List of gay, lesbian or bisexual people: C
# Protection status: autoconfirmed,autoconfirmed
# ['11548323', 'List of gay, lesbian or bisexual people: C', 'autoconfirmed,autoconfirmed']
# Processing file... 11554502
# Lester Coleman
# Protection status: autoconfirmed,autoconfirmed
# ['11554502', 'Lester Coleman', 'autoconfirmed,autoconfirmed']
# Processing file... 11556927
# Mediacorp HD5
# Protection status: autoconfirmed,autoconfirmed
# ['11556927', 'Mediacorp HD5', 'autoconfirmed,autoconfirmed']
# Processing file... 11557106
# Batman in film
# Protection status: autoconfirmed,autoconfirmed
# ['11557106', 'Batman in film', 'autoconfirmed,autoconfirmed']
# Processing file... 11567096
# Murdoch Mysteries
# Protection status: autoconfirmed,autoconfirmed
# ['11567096', 'Murdoch Mysteries', 'autoconfirmed,autoconfirmed']
# Processing file... 11567670
# List of The Cosby Show characters
# Protection status: autoconfirmed,autoconfirmed
# ['11567670', 'List of The Cosby Show characters', 'autoconfirmed,autoconfirmed']
# Processing file... 1157014
# Pauly Shore
# Protection status: autoconfirmed,autoconfirmed
# ['1157014', 'Pauly Shore', 'autoconfirmed,autoconfirmed']
# Processing file... 11578887
# General Hospital cast members
# Protection status: autoconfirmed,autoconfirmed
# ['11578887', 'General Hospital cast members', 'autoconfirmed,autoconfirmed']
# Processing file... 1157910
# Jimmy Conrad
# Protection status: autoconfirmed,autoconfirmed
# ['1157910', 'Jimmy Conrad', 'autoconfirmed,autoconfirmed']
# Processing file... 11593017
# Burn Notice
# Protection status: autoconfirmed,autoconfirmed
# ['11593017', 'Burn Notice', 'autoconfirmed,autoconfirmed']
# Processing file... 1160865
# Samy Vellu
# Protection status: autoconfirmed,autoconfirmed
# ['1160865', 'Samy Vellu', 'autoconfirmed,autoconfirmed']
# Processing file... 11619883
# Blumpkin
# Protection status: sysop,sysop
# ['11619883', 'Blumpkin', 'sysop,sysop']
# Processing file... 1162481
# Modi'in Illit
# Protection status: autoconfirmed,sysop
# ['1162481', "Modi'in Illit", 'autoconfirmed,sysop']
# Processing file... 1162486
# Giv'at Ze'ev
# Protection status: autoconfirmed
# ['1162486', "Giv'at Ze'ev", 'autoconfirmed']
# Processing file... 11631288
# Abilene High School (Texas)
# Protection status: autoconfirmed,autoconfirmed
# ['11631288', 'Abilene High School (Texas)', 'autoconfirmed,autoconfirmed']
# Processing file... 11638
# Francis of Assisi
# Protection status: autoconfirmed,sysop
# ['11638', 'Francis of Assisi', 'autoconfirmed,sysop']
# Processing file... 1164274
# Claremont Graduate University
# Protection status: autoconfirmed,autoconfirmed
# ['1164274', 'Claremont Graduate University', 'autoconfirmed,autoconfirmed']
# Processing file... 11650319
# Xiaxue
# Protection status: autoconfirmed,autoconfirmed
# ['11650319', 'Xiaxue', 'autoconfirmed,autoconfirmed']
# Processing file... 11663591
# The Contractor (2007 film)
# Protection status: autoconfirmed
# ['11663591', 'The Contractor (2007 film)', 'autoconfirmed']
# Processing file... 11665
# Filtration
# Protection status: autoconfirmed,autoconfirmed
# ['11665', 'Filtration', 'autoconfirmed,autoconfirmed']
# Processing file... 1168295
# Merneptah
# Protection status: autoconfirmed,autoconfirmed
# ['1168295', 'Merneptah', 'autoconfirmed,autoconfirmed']
# Processing file... 11700559
# List of scientists opposing the mainstream scientific assessment of global warming
# Protection status: autoconfirmed,autoconfirmed
# ['11700559', 'List of scientists opposing the mainstream scientific assessment of global warming', 'autoconfirmed,autoconfirmed']
# Processing file... 11712287
# Riaz Ahmed Gohar Shahi
# Protection status: autoconfirmed,autoconfirmed
# ['11712287', 'Riaz Ahmed Gohar Shahi', 'autoconfirmed,autoconfirmed']
# Processing file... 1172299
# Damon Dash
# Protection status: autoconfirmed,autoconfirmed
# ['1172299', 'Damon Dash', 'autoconfirmed,autoconfirmed']
# Processing file... 1174
# Aphrodite
# Protection status: autoconfirmed,autoconfirmed
# ['1174', 'Aphrodite', 'autoconfirmed,autoconfirmed']
# Processing file... 1174295
# Civil Disobedience (Thoreau)
# Protection status: autoconfirmed,autoconfirmed
# ['1174295', 'Civil Disobedience (Thoreau)', 'autoconfirmed,autoconfirmed']
# Processing file... 11747574
# Nicole Alexander
# Protection status: autoconfirmed,autoconfirmed
# ['11747574', 'Nicole Alexander', 'autoconfirmed,autoconfirmed']
# Processing file... 1174943
# David Hager
# Protection status: autoconfirmed,autoconfirmed
# ['1174943', 'David Hager', 'autoconfirmed,autoconfirmed']
# Processing file... 11749910
# Cheese
# Protection status: autoconfirmed,sysop
# ['11749910', 'Cheese', 'autoconfirmed,sysop']
# Processing file... 1175987
# List of Nobel laureates
# Protection status: autoconfirmed,autoconfirmed
# ['1175987', 'List of Nobel laureates', 'autoconfirmed,autoconfirmed']
# Processing file... 11766333
# Online quiz
# Protection status: autoconfirmed,autoconfirmed
# ['11766333', 'Online quiz', 'autoconfirmed,autoconfirmed']
# Processing file... 11768984
# Surveen Chawla
# Protection status: autoconfirmed,autoconfirmed
# ['11768984', 'Surveen Chawla', 'autoconfirmed,autoconfirmed']
# Processing file... 11776556
# Ripe Digital Entertainment
# Protection status: autoconfirmed,autoconfirmed
# ['11776556', 'Ripe Digital Entertainment', 'autoconfirmed,autoconfirmed']
# Processing file... 11778948
# Atomic bombings of Hiroshima and Nagasaki
# Protection status: autoconfirmed,sysop
# ['11778948', 'Atomic bombings of Hiroshima and Nagasaki', 'autoconfirmed,sysop']
# Processing file... 1178
# Afterlife
# Protection status: autoconfirmed,autoconfirmed
# ['1178', 'Afterlife', 'autoconfirmed,autoconfirmed']
# Processing file... 11805756
# Greg Plitt
# Protection status: autoconfirmed,autoconfirmed
# ['11805756', 'Greg Plitt', 'autoconfirmed,autoconfirmed']
# Processing file... 11808592
# México en la Piel (album)
# Protection status: autoconfirmed
# ['11808592', 'México en la Piel (album)', 'autoconfirmed']
# Processing file... 1181010
# Logan Lerman
# Protection status: autoconfirmed,sysop
# ['1181010', 'Logan Lerman', 'autoconfirmed,sysop']
# Processing file... 1181487
# Halo 3
# Protection status: autoconfirmed,autoconfirmed
# ['1181487', 'Halo 3', 'autoconfirmed,autoconfirmed']
# Processing file... 11815465
# List of Who Wants to Be a Millionaire? top prize winners
# Protection status: autoconfirmed
# ['11815465', 'List of Who Wants to Be a Millionaire? top prize winners', 'autoconfirmed']
# Processing file... 1181646
# War on Drugs
# Protection status: autoconfirmed,autoconfirmed
# ['1181646', 'War on Drugs', 'autoconfirmed,autoconfirmed']
# Processing file... 1181663
# Comic book collecting
# Protection status: autoconfirmed,autoconfirmed
# ['1181663', 'Comic book collecting', 'autoconfirmed,autoconfirmed']
# Processing file... 11824669
# Amit Singhal
# Protection status: autoconfirmed,autoconfirmed
# ['11824669', 'Amit Singhal', 'autoconfirmed,autoconfirmed']
# Processing file... 11826154
# Wang Leehom
# Protection status: autoconfirmed,autoconfirmed
# ['11826154', 'Wang Leehom', 'autoconfirmed,autoconfirmed']
# Processing file... 11835861
# Yucaipa High School
# Protection status: autoconfirmed,autoconfirmed
# ['11835861', 'Yucaipa High School', 'autoconfirmed,autoconfirmed']
# Processing file... 11846
# Guitar
# Protection status: autoconfirmed,sysop
# ['11846', 'Guitar', 'autoconfirmed,sysop']
# Processing file... 11850610
# Jeffree Star
# Protection status: autoconfirmed,autoconfirmed
# ['11850610', 'Jeffree Star', 'autoconfirmed,autoconfirmed']
# Processing file... 1185646
# Mentuhotep II
# Protection status: autoconfirmed
# ['1185646', 'Mentuhotep II', 'autoconfirmed']
# Processing file... 11857
# George Lucas
# Protection status: autoconfirmed,autoconfirmed
# ['11857', 'George Lucas', 'autoconfirmed,autoconfirmed']
# Processing file... 1186115
# Islam in India
# Protection status: autoconfirmed,autoconfirmed
# ['1186115', 'Islam in India', 'autoconfirmed,autoconfirmed']
# Processing file... 11862690
# Juno (film)
# Protection status: autoconfirmed,autoconfirmed
# ['11862690', 'Juno (film)', 'autoconfirmed,autoconfirmed']
# Processing file... 11867
# Germany
# Protection status: autoconfirmed,sysop
# ['11867', 'Germany', 'autoconfirmed,sysop']
# Processing file... 11876731
# The Mystery of the Druids
# Protection status: autoconfirmed,autoconfirmed
# ['11876731', 'The Mystery of the Druids', 'autoconfirmed,autoconfirmed']
# Processing file... 1187948
# Gary Paulsen
# Protection status: autoconfirmed
# ['1187948', 'Gary Paulsen', 'autoconfirmed']
# Processing file... 11889949
# Rob Dyrdek
# Protection status: autoconfirmed
# ['11889949', 'Rob Dyrdek', 'autoconfirmed']
# Processing file... 1189614
# The Perfect Score
# Protection status: autoconfirmed,autoconfirmed
# ['1189614', 'The Perfect Score', 'autoconfirmed,autoconfirmed']
# Processing file... 1190582
# ...
# ['9457470', 'Edward Cullen', 'autoconfirmed,autoconfirmed']
# Processing file... 9467
# Longest word in English
# Protection status: autoconfirmed,autoconfirmed
# ['9467', 'Longest word in English', 'autoconfirmed,autoconfirmed']
# Processing file... 9489004
# Jimtown High School (Elkhart, Indiana)
# Protection status: autoconfirmed,autoconfirmed
# ['9489004', 'Jimtown High School (Elkhart, Indiana)', 'autoconfirmed,autoconfirmed']
# Processing file... 9504983
# Fenzi
# Protection status: autoconfirmed,autoconfirmed
# ['9504983', 'Fenzi', 'autoconfirmed,autoconfirmed']
# Processing file... 9532
# Electromagnetism
# Protection status: autoconfirmed,autoconfirmed
# ['9532', 'Electromagnetism', 'autoconfirmed,autoconfirmed']
# Processing file... 9545969
# Ilana Mercer
# Protection status: autoconfirmed,autoconfirmed
# ['9545969', 'Ilana Mercer', 'autoconfirmed,autoconfirmed']
# Processing file... 9549
# Edgar Allan Poe
# Protection status: autoconfirmed,sysop
# ['9549', 'Edgar Allan Poe', 'autoconfirmed,sysop']
# Processing file... 9550
# Electricity
# Protection status: autoconfirmed,autoconfirmed
# ['9550', 'Electricity', 'autoconfirmed,autoconfirmed']
# Processing file... 9554131
# List of members of the Irish Republican Army
# Protection status: autoconfirmed,autoconfirmed
# ['9554131', 'List of members of the Irish Republican Army', 'autoconfirmed,autoconfirmed']
# Processing file... 95618
# John Vincent Atanasoff
# Protection status: autoconfirmed,autoconfirmed
# ['95618', 'John Vincent Atanasoff', 'autoconfirmed,autoconfirmed']
# Processing file... 956210
# Michigan J. Frog
# Protection status: autoconfirmed,autoconfirmed
# ['956210', 'Michigan J. Frog', 'autoconfirmed,autoconfirmed']
# Processing file... 956689
# Kura–Araxes culture
# Protection status: autoconfirmed,autoconfirmed
# ['956689', 'Kura–Araxes culture', 'autoconfirmed,autoconfirmed']
# Processing file... 9571601
# Dumbass
# Protection status: sysop,sysop
# ['9571601', 'Dumbass', 'sysop,sysop']
# Processing file... 957276
# Raveena Tandon
# Protection status: autoconfirmed
# ['957276', 'Raveena Tandon', 'autoconfirmed']
# Processing file... 957684
# Cesc Fàbregas
# Protection status: autoconfirmed,sysop
# ['957684', 'Cesc Fàbregas', 'autoconfirmed,sysop']
# Processing file... 9578734
# Go-go boot
# Protection status: autoconfirmed,autoconfirmed
# ['9578734', 'Go-go boot', 'autoconfirmed,autoconfirmed']
# Processing file... 9584577
# McAlester News-Capital
# Protection status: autoconfirmed,autoconfirmed
# ['9584577', 'McAlester News-Capital', 'autoconfirmed,autoconfirmed']
# Processing file... 9587
# Euthanasia
# Protection status: autoconfirmed,autoconfirmed
# ['9587', 'Euthanasia', 'autoconfirmed,autoconfirmed']
# Processing file... 958866
# Tony Attwood
# Protection status: autoconfirmed
# ['958866', 'Tony Attwood', 'autoconfirmed']
# Processing file... 9603
# Ernest Rutherford
# Protection status: autoconfirmed,sysop
# ['9603', 'Ernest Rutherford', 'autoconfirmed,sysop']
# Processing file... 961110
# Ashlyn Gere
# Protection status: autoconfirmed,autoconfirmed
# ['961110', 'Ashlyn Gere', 'autoconfirmed,autoconfirmed']
# Processing file... 96149
# Slipknot (band)
# Protection status: autoconfirmed,sysop
# ['96149', 'Slipknot (band)', 'autoconfirmed,sysop']
# Processing file... 9630
# Ecology
# Protection status: autoconfirmed,autoconfirmed
# ['9630', 'Ecology', 'autoconfirmed,autoconfirmed']
# Processing file... 963152
# Spaniards
# Protection status: autoconfirmed,autoconfirmed
# ['963152', 'Spaniards', 'autoconfirmed,autoconfirmed']
# Processing file... 9636145
# Gregory Paul Martin
# Protection status: autoconfirmed,autoconfirmed
# ['9636145', 'Gregory Paul Martin', 'autoconfirmed,autoconfirmed']
# Processing file... 964077
# Lamar S. Smith
# Protection status: autoconfirmed,sysop
# ['964077', 'Lamar S. Smith', 'autoconfirmed,sysop']
# Processing file... 9644294
# List of Ice Age characters
# Protection status: autoconfirmed
# ['9644294', 'List of Ice Age characters', 'autoconfirmed']
# Processing file... 9649
# Energy
# Protection status: autoconfirmed,sysop
# ['9649', 'Energy', 'autoconfirmed,sysop']
# Processing file... 964985
# List of city nicknames in the United States
# Protection status: autoconfirmed,autoconfirmed
# ['964985', 'List of city nicknames in the United States', 'autoconfirmed,autoconfirmed']
# Processing file... 96603
# Memphis, Egypt
# Protection status: autoconfirmed,autoconfirmed
# ['96603', 'Memphis, Egypt', 'autoconfirmed,autoconfirmed']
# Processing file... 966195
# Erzurum
# Protection status: autoconfirmed,autoconfirmed
# ['966195', 'Erzurum', 'autoconfirmed,autoconfirmed']
# Processing file... 966465
# Paul Steed
# Protection status: autoconfirmed,autoconfirmed
# ['966465', 'Paul Steed', 'autoconfirmed,autoconfirmed']
# Processing file... 96652
# Seahorse
# Protection status: autoconfirmed,autoconfirmed
# ['96652', 'Seahorse', 'autoconfirmed,autoconfirmed']
# Processing file... 9666124
# Raai Laxmi
# Protection status: autoconfirmed,autoconfirmed
# ['9666124', 'Raai Laxmi', 'autoconfirmed,autoconfirmed']
# Processing file... 967176
# Eye of Horus
# Protection status: autoconfirmed,autoconfirmed
# ['967176', 'Eye of Horus', 'autoconfirmed,autoconfirmed']
# Processing file... 9674182
# Glenn Grothman
# Protection status: autoconfirmed,autoconfirmed
# ['9674182', 'Glenn Grothman', 'autoconfirmed,autoconfirmed']
# Processing file... 9675071
# Ezhava
# Protection status: autoconfirmed,autoconfirmed
# ['9675071', 'Ezhava', 'autoconfirmed,autoconfirmed']
# Processing file... 9679918
# Norwegian Police Service
# Protection status: autoconfirmed,autoconfirmed
# ['9679918', 'Norwegian Police Service', 'autoconfirmed,autoconfirmed']
# Processing file... 970386
# The SpongeBob SquarePants Movie
# Protection status: autoconfirmed,autoconfirmed
# ['970386', 'The SpongeBob SquarePants Movie', 'autoconfirmed,autoconfirmed']
# Processing file... 97044
# Khepri
# Protection status: autoconfirmed,autoconfirmed
# ['97044', 'Khepri', 'autoconfirmed,autoconfirmed']
# Processing file... 97046
# Atum
# Protection status: autoconfirmed
# ['97046', 'Atum', 'autoconfirmed']
# Processing file... 97096
# Nu (mythology)
# Protection status: autoconfirmed
# ['97096', 'Nu (mythology)', 'autoconfirmed']
# Processing file... 97125
# Ptah
# Protection status: autoconfirmed
# ['97125', 'Ptah', 'autoconfirmed']
# Processing file... 9717
# Excalibur
# Protection status: autoconfirmed,autoconfirmed
# ['9717', 'Excalibur', 'autoconfirmed,autoconfirmed']
# Processing file... 97187
# Ennead
# Protection status: autoconfirmed
# ['97187', 'Ennead', 'autoconfirmed']
# Processing file... 971896
# Frank Wu (artist)
# Protection status: autoconfirmed,sysop
# ['971896', 'Frank Wu (artist)', 'autoconfirmed,sysop']
# Processing file... 972036
# Evan Solomon
# Protection status: autoconfirmed,autoconfirmed
# ['972036', 'Evan Solomon', 'autoconfirmed,autoconfirmed']
# Processing file... 97236
# Maat
# Protection status: autoconfirmed,autoconfirmed
# ['97236', 'Maat', 'autoconfirmed,autoconfirmed']
# Processing file... 972591
# Delta FM
# Protection status: autoconfirmed,autoconfirmed
# ['972591', 'Delta FM', 'autoconfirmed,autoconfirmed']
# Processing file... 972683
# Kyle
# Protection status: autoconfirmed,sysop
# ['972683', 'Kyle', 'autoconfirmed,sysop']
# Processing file... 9729299
# Jonas Brothers
# Protection status: autoconfirmed,sysop
# ['9729299', 'Jonas Brothers', 'autoconfirmed,sysop']
# Processing file... 97317
# Hathor
# Protection status: autoconfirmed,autoconfirmed
# ['97317', 'Hathor', 'autoconfirmed,autoconfirmed']
# Processing file... 9732
# Eli Whitney
# Protection status: autoconfirmed
# ['9732', 'Eli Whitney', 'autoconfirmed']
# Processing file... 97404
# Cluj-Napoca
# Protection status: autoconfirmed,autoconfirmed
# ['97404', 'Cluj-Napoca', 'autoconfirmed,autoconfirmed']
# Processing file... 9754606
# Dingleberry
# Protection status: autoconfirmed,autoconfirmed
# ['9754606', 'Dingleberry', 'autoconfirmed,autoconfirmed']
# Processing file... 9762025
# Laurel Springs School
# Protection status: autoconfirmed,autoconfirmed
# ['9762025', 'Laurel Springs School', 'autoconfirmed,autoconfirmed']
# Processing file... 9764
# Emma Goldman
# Protection status: autoconfirmed,sysop
# ['9764', 'Emma Goldman', 'autoconfirmed,sysop']
# Processing file... 9769596
# John Riccitiello
# Protection status: autoconfirmed
# ['9769596', 'John Riccitiello', 'autoconfirmed']
# Processing file... 976970
# Tibetan Mastiff
# Protection status: autoconfirmed,autoconfirmed
# ['976970', 'Tibetan Mastiff', 'autoconfirmed,autoconfirmed']
# Processing file... 9771922
# Paul Mounet
# Protection status: autoconfirmed,autoconfirmed
# ['9771922', 'Paul Mounet', 'autoconfirmed,autoconfirmed']
# Processing file... 9773333
# Peter Brookesmith
# Protection status: autoconfirmed,autoconfirmed
# ['9773333', 'Peter Brookesmith', 'autoconfirmed,autoconfirmed']
# Processing file... 97771
# Family tree of the Greek gods
# Protection status: autoconfirmed,autoconfirmed
# ['97771', 'Family tree of the Greek gods', 'autoconfirmed,autoconfirmed']
# Processing file... 978203
# Flag of India
# Protection status: autoconfirmed,autoconfirmed
# ['978203', 'Flag of India', 'autoconfirmed,autoconfirmed']
# Processing file... 979165
# Guy Fawkes Night
# Protection status: autoconfirmed,autoconfirmed
# ['979165', 'Guy Fawkes Night', 'autoconfirmed,autoconfirmed']
# Processing file... 979320
# Gippsland Grammar School
# Protection status: autoconfirmed
# ['979320', 'Gippsland Grammar School', 'autoconfirmed']
# Processing file... 9809619
# PlayStation Home
# Protection status: autoconfirmed,autoconfirmed
# ['9809619', 'PlayStation Home', 'autoconfirmed,autoconfirmed']
# Processing file... 9810476
# Zombie
# Protection status: autoconfirmed,autoconfirmed
# ['9810476', 'Zombie', 'autoconfirmed,autoconfirmed']
# Processing file... 9814346
# Alex Pierson
# Protection status: autoconfirmed,autoconfirmed
# ['9814346', 'Alex Pierson', 'autoconfirmed,autoconfirmed']
# Processing file... 98176
# Ancient Egyptian concept of the soul
# Protection status: autoconfirmed,autoconfirmed
# ['98176', 'Ancient Egyptian concept of the soul', 'autoconfirmed,autoconfirmed']
# Processing file... 982180
# Robin Hood (1973 film)
# Protection status: autoconfirmed,autoconfirmed
# ['982180', 'Robin Hood (1973 film)', 'autoconfirmed,autoconfirmed']
# Processing file... 982199
# Peter Pan (1953 film)
# Protection status: autoconfirmed,autoconfirmed
# ['982199', 'Peter Pan (1953 film)', 'autoconfirmed,autoconfirmed']
# Processing file... 98301
# Joker (comics)
# Protection status: autoconfirmed,sysop
# ['98301', 'Joker (comics)', 'autoconfirmed,sysop']
# Processing file... 98351
# Elmo
# Protection status: autoconfirmed,sysop
# ['98351', 'Elmo', 'autoconfirmed,sysop']
# Processing file... 984106
# Antonio Paoli
# Protection status: autoconfirmed,autoconfirmed
# ['984106', 'Antonio Paoli', 'autoconfirmed,autoconfirmed']
# Processing file... 984639
# Karan Johar
# Protection status: autoconfirmed,autoconfirmed
# ['984639', 'Karan Johar', 'autoconfirmed,autoconfirmed']
# Processing file... 9846732
# Dale L. Walker
# Protection status: autoconfirmed,autoconfirmed
# ['9846732', 'Dale L. Walker', 'autoconfirmed,autoconfirmed']
# Processing file... 984827
# Martock
# Protection status: autoconfirmed,autoconfirmed
# ['984827', 'Martock', 'autoconfirmed,autoconfirmed']
# Processing file... 9853806
# Kanyakubja Brahmins
# Protection status: autoconfirmed,autoconfirmed
# ['9853806', 'Kanyakubja Brahmins', 'autoconfirmed,autoconfirmed']
# Processing file... 985535
# World Tag Team Championship (WWE)
# Protection status: autoconfirmed,autoconfirmed
# ['985535', 'World Tag Team Championship (WWE)', 'autoconfirmed,autoconfirmed']
# Processing file... 98650
# Chartres
# Protection status: autoconfirmed,autoconfirmed
# ['98650', 'Chartres', 'autoconfirmed,autoconfirmed']
# Processing file... 9866040
# List of National Basketball Association single-season scoring leaders
# Protection status: autoconfirmed,autoconfirmed
# ['9866040', 'List of National Basketball Association single-season scoring leaders', 'autoconfirmed,autoconfirmed']
# Processing file... 9877706
# Emanuel School
# Protection status: autoconfirmed,autoconfirmed
# ['9877706', 'Emanuel School', 'autoconfirmed,autoconfirmed']
# Processing file... 9878372
# Login
# Protection status: autoconfirmed,autoconfirmed
# ['9878372', 'Login', 'autoconfirmed,autoconfirmed']
# Processing file... 988583
# Chitral District
# Protection status: autoconfirmed,sysop
# ['988583', 'Chitral District', 'autoconfirmed,sysop']
# Processing file... 9886374
# List of Epiphone players
# Protection status: autoconfirmed,autoconfirmed
# ['9886374', 'List of Epiphone players', 'autoconfirmed,autoconfirmed']
# Processing file... 989460
# Sam Katz
# Protection status: autoconfirmed,autoconfirmed
# ['989460', 'Sam Katz', 'autoconfirmed,autoconfirmed']
# Processing file... 9896
# Elf
# Protection status: autoconfirmed,autoconfirmed
# ['9896', 'Elf', 'autoconfirmed,autoconfirmed']
# Processing file... 9896564
# ResellerRatings
# Protection status: autoconfirmed,autoconfirmed
# ['9896564', 'ResellerRatings', 'autoconfirmed,autoconfirmed']
# Processing file... 990501
# Nanyang Polytechnic
# Protection status: autoconfirmed,autoconfirmed
# ['990501', 'Nanyang Polytechnic', 'autoconfirmed,autoconfirmed']
# Processing file... 9906294
# Johann Sebastian Bach
# Protection status: autoconfirmed,autoconfirmed
# ['9906294', 'Johann Sebastian Bach', 'autoconfirmed,autoconfirmed']
# Processing file... 99063
# Isaac Brock
# Protection status: autoconfirmed,autoconfirmed
# ['99063', 'Isaac Brock', 'autoconfirmed,autoconfirmed']
# Processing file... 990764
# The Wild Thornberrys Movie
# Protection status: autoconfirmed
# ['990764', 'The Wild Thornberrys Movie', 'autoconfirmed']
# Processing file... 9908504
# Gambling for resurrection
# Protection status: autoconfirmed,autoconfirmed
# ['9908504', 'Gambling for resurrection', 'autoconfirmed,autoconfirmed']
# Processing file... 9909905
# Ninja Theory
# Protection status: autoconfirmed,autoconfirmed
# ['9909905', 'Ninja Theory', 'autoconfirmed,autoconfirmed']
# Processing file... 9911223
# Flux (software)
# Protection status: autoconfirmed,autoconfirmed
# ['9911223', 'Flux (software)', 'autoconfirmed,autoconfirmed']
# Processing file... 991143
# Frank Sinatra, Jr.
# Protection status: autoconfirmed
# ['991143', 'Frank Sinatra, Jr.', 'autoconfirmed']
# Processing file... 991210
# Divisibility rule
# Protection status: autoconfirmed,autoconfirmed
# ['991210', 'Divisibility rule', 'autoconfirmed,autoconfirmed']
# Processing file... 9918415
# Matt Sanchez
# Protection status: autoconfirmed,autoconfirmed
# ['9918415', 'Matt Sanchez', 'autoconfirmed,autoconfirmed']
# Processing file... 991985
# Pitbull (rapper)
# Protection status: autoconfirmed
# ['991985', 'Pitbull (rapper)', 'autoconfirmed']
# Processing file... 992332
# Bob Larson
# Protection status: autoconfirmed
# ['992332', 'Bob Larson', 'autoconfirmed']
# Processing file... 9924355
# Peggle
# Protection status: autoconfirmed,autoconfirmed
# ['9924355', 'Peggle', 'autoconfirmed,autoconfirmed']
# Processing file... 993558
# Treehouse TV
# Protection status: autoconfirmed
# ['993558', 'Treehouse TV', 'autoconfirmed']
# Processing file... 9935632
# List of tallest buildings in Karachi
# Protection status: autoconfirmed,autoconfirmed
# ['9935632', 'List of tallest buildings in Karachi', 'autoconfirmed,autoconfirmed']
# Processing file... 993655
# Asif Ali Zardari
# Protection status: autoconfirmed,sysop
# ['993655', 'Asif Ali Zardari', 'autoconfirmed,sysop']
# Processing file... 99372
# Robin (comics)
# Protection status: autoconfirmed,autoconfirmed
# ['99372', 'Robin (comics)', 'autoconfirmed,autoconfirmed']
# Processing file... 9940234
# Tomato
# Protection status: autoconfirmed,sysop
# ['9940234', 'Tomato', 'autoconfirmed,sysop']
# Processing file... 994160
# Samoa Joe
# Protection status: autoconfirmed
# ['994160', 'Samoa Joe', 'autoconfirmed']
# Processing file... 9942
# Erwin Schrödinger
# Protection status: autoconfirmed,autoconfirmed
# ['9942', 'Erwin Schrödinger', 'autoconfirmed,autoconfirmed']
# Processing file... 9963622
# I Come in Peace
# Protection status: autoconfirmed
# ['9963622', 'I Come in Peace', 'autoconfirmed']
# Processing file... 99645
# Homo sapiens
# Protection status: autoconfirmed,autoconfirmed
# ['99645', 'Homo sapiens', 'autoconfirmed,autoconfirmed']
# Processing file... 9987564
# A Day to Remember
# Protection status: autoconfirmed,sysop
# ['9987564', 'A Day to Remember', 'autoconfirmed,sysop']
# Processing file... 9988187
# Twitter
# Protection status: autoconfirmed,sysop
# ['9988187', 'Twitter', 'autoconfirmed,sysop']

# %%
data['query']['pages']['protection']
# Out:
# {'batchcomplete': '',
#  'query': {'logevents': [{'comment': 'Persistent [[WP:Vandalism|vandalism]]',
#     'pageid': 100062,
#     'title': 'Super Mario 64',
#     'timestamp': '2011-04-20T00:55:46Z',
#     'tags': [],
#     'logid': 35707351,
#     'logpage': 100062,
#     'user': 'Andrevan',
#     'action': 'protect',
#     'params': {'description': '[edit=autoconfirmed] (indefinite) [move=autoconfirmed] (indefinite)'},
#     'ns': 0,
#     'type': 'protect'},
#    {'comment': 'inbound nonsense',
#     'pageid': 100062,
#     'title': 'Super Mario 64',
#     'timestamp': '2011-03-18T20:21:14Z',
#     'tags': [],
#     'logid': 35212925,
#     'logpage': 100062,
#     'user': 'Gfoley4',
#     'action': 'protect',
#     'params': {'description': '[edit=autoconfirmed] (expires 20:21, 19 March 2011 (UTC)) [move=autoconfirmed] (expires 20:21, 19 March 2011 (UTC))'},
#     'ns': 0,
#     'type': 'protect'},
#    {'comment': 'Excessive [[WP:VANDALISM|vandalism]]',
#     'pageid': 100062,
#     'title': 'Super Mario 64',
#     'timestamp': '2009-10-20T22:24:07Z',
#     'tags': [],
#     'logid': 25314836,
#     'logpage': 100062,
#     'user': 'Tedder',
#     'action': 'protect',
#     'params': {'description': '[edit=autoconfirmed] (expires 22:24, 23 October 2009 (UTC)) [move=autoconfirmed] (expires 22:24, 23 October 2009 (UTC))'},
#     'ns': 0,
#     'type': 'protect'}],
#   'pages': {'100062': {'lastrevid': 713791609,
#     'pagelanguagedir': 'ltr',
#     'pageid': 100062,
#     'protection': [{'expiry': 'infinity',
#       'type': 'edit',
#       'level': 'autoconfirmed'},
#      {'expiry': 'infinity', 'type': 'move', 'level': 'autoconfirmed'}],
#     'title': 'Super Mario 64',
#     'pagelanguagehtmlcode': 'en',
#     'watchers': 190,
#     'length': 53038,
#     'contentmodel': 'wikitext',
#     'pagelanguage': 'en',
#     'touched': '2016-04-23T15:27:01Z',
#     'ns': 0,
#     'restrictiontypes': ['edit', 'move'],
#     'categories': [{'timestamp': '2010-10-04T17:15:37Z',
#       'ns': 14,
#       'title': 'Category:1996 video games'},
#      {'timestamp': '2010-10-04T17:15:37Z',
#       'ns': 14,
#       'title': 'Category:3D platform games'},
#      {'timestamp': '2013-09-09T20:08:21Z',
#       'ns': 14,
#       'title': 'Category:Album infoboxes lacking a cover'},
#      {'timestamp': '2013-06-20T00:40:07Z',
#       'ns': 14,
#       'title': 'Category:Articles containing Japanese-language text'},
#      {'timestamp': '2015-05-28T02:36:04Z',
#       'ns': 14,
#       'title': 'Category:Articles using Video game reviews template in single platform mode'},
#      {'timestamp': '2012-08-16T01:20:10Z',
#       'ns': 14,
#       'title': 'Category:Articles with hAudio microformats'},
#      {'timestamp': '2011-07-19T10:35:06Z',
#       'ns': 14,
#       'title': 'Category:Featured articles'},
#      {'timestamp': '2010-10-04T17:15:37Z',
#       'ns': 14,
#       'title': 'Category:History of video games'},
#      {'timestamp': '2010-10-04T17:15:37Z',
#       'ns': 14,
#       'title': 'Category:IQue games'},
#      {'timestamp': '2010-10-04T17:15:37Z',
#       'ns': 14,
#       'title': 'Category:Mario Universe games'},
#      {'timestamp': '2010-10-04T17:15:37Z',
#       'ns': 14,
#       'title': 'Category:Mario platform games'},
#      {'timestamp': '2015-04-12T06:33:06Z',
#       'ns': 14,
#       'title': 'Category:Nintendo 64 games'},
#      {'timestamp': '2010-10-04T17:15:37Z',
#       'ns': 14,
#       'title': 'Category:Nintendo 64 platform games'},
#      {'timestamp': '2010-10-04T17:15:37Z',
#       'ns': 14,
#       'title': 'Category:Nintendo Entertainment Analysis and Development games'},
#      {'timestamp': '2013-04-02T19:12:13Z',
#       'ns': 14,
#       'title': 'Category:Single-player-only video games'},
#      {'timestamp': '2012-05-13T10:52:53Z',
#       'ns': 14,
#       'title': 'Category:Use mdy dates from May 2012'},
#      {'timestamp': '2015-10-27T11:45:13Z',
#       'ns': 14,
#       'title': 'Category:Video games composed by Koji Kondo'},
#      {'timestamp': '2016-01-26T22:48:37Z',
#       'ns': 14,
#       'title': 'Category:Video games directed by Shigeru Miyamoto'},
#      {'timestamp': '2010-10-04T17:15:37Z',
#       'ns': 14,
#       'title': 'Category:Virtual Console games'},
#      {'timestamp': '2015-04-02T16:17:37Z',
#       'ns': 14,
#       'title': 'Category:Virtual Console games for Wii U'},
#      {'timestamp': '2015-05-19T21:10:12Z',
#       'ns': 14,
#       'title': 'Category:Wikipedia articles with GND identifiers'},
#      {'timestamp': '2011-04-20T19:10:48Z',
#       'ns': 14,
#       'title': 'Category:Wikipedia indefinitely semi-protected pages'}],
#     'revisions': [{'comment': 'Protected Super Mario 64: Persistent [[WP:Vandalism|vandalism]] ([edit=autoconfirmed] (indefinite) [move=autoconfirmed] (indefinite))',
#       'tags': [],
#       'timestamp': '2011-04-20T00:55:46Z',
#       'revid': 424948393,
#       'user': 'Andrevan',
#       'parentid': 424948355,
#       'minor': '',
#       'size': 41824},
#      {'comment': '[[Help:Reverting|Reverted]] edits by [[Special:Contributions/174.57.208.202|174.57.208.202]] ([[User talk:174.57.208.202|talk]]) to last version by SUPER DREW 64',
#       'tags': [],
#       'timestamp': '2011-04-20T00:55:23Z',
#       'revid': 424948355,
#       'user': 'Andrevan',
#       'parentid': 424940337,
#       'minor': '',
#       'size': 41824},
#      {'comment': 'i named a famous glitch in the game',
#       'tags': [],
#       'timestamp': '2011-04-19T23:47:10Z',
#       'revid': 424940337,
#       'anon': '',
#       'user': '174.57.208.202',
#       'parentid': 424939303,
#       'size': 43053},
#      {'comment': 'i have added a fun fact that im sure many people did not know, i named the factual place in history of what place super mario 64 is in for best video games.',
#       'tags': [],
#       'timestamp': '2011-04-19T23:39:14Z',
#       'revid': 424939303,
#       'anon': '',
#       'user': '174.57.208.202',
#       'parentid': 424768757,
#       'size': 42481},
#      {'comment': '',
#       'tags': ['Section blanking'],
#       'timestamp': '2011-04-18T23:31:26Z',
#       'revid': 424768757,
#       'user': 'SUPER DREW 64',
#       'parentid': 424768646,
#       'size': 41824},
#      {'comment': "making artical of luigi's new game",
#       'tags': [],
#       'timestamp': '2011-04-18T23:30:33Z',
#       'revid': 424768646,
#       'user': 'SUPER DREW 64',
#       'parentid': 424767968,
#       'size': 41870},
#      {'comment': 'Undid revision 424767808 by [[Special:Contributions/SUPER DREW 64|SUPER DREW 64]] ([[User talk:SUPER DREW 64|talk]]) Nobody cares',
#       'tags': [],
#       'timestamp': '2011-04-18T23:25:16Z',
#       'revid': 424767968,
#       'user': 'Blake',
#       'parentid': 424767808,
#       'size': 41824},
#      {'comment': 'THIS IS ABOUT THE NEW ROM SUPER LUIGI 64',
#       'tags': [],
#       'timestamp': '2011-04-18T23:23:57Z',
#       'revid': 424767808,
#       'user': 'SUPER DREW 64',
#       'parentid': 424763398,
#       'size': 42064},
#      {'comment': 'Reverted to revision 423468663 by Fæ; This is not appropriate. ([[WP:TW|TW]])',
#       'tags': [],
#       'timestamp': '2011-04-18T22:50:02Z',
#       'revid': 424763398,
#       'user': 'Lord Psyko Jo',
#       'parentid': 424763194,
#       'size': 41824},
#      {'comment': '/* Super Luigi 64 (ROM) */',
#       'tags': [],
#       'timestamp': '2011-04-18T22:48:31Z',
#       'revid': 424763194,
#       'anon': '',
#       'user': '72.221.71.250',
#       'parentid': 424763089,
#       'size': 42433},
#      {'comment': '/* Super Luigi 64 (ROM) */',
#       'tags': [],
#       'timestamp': '2011-04-18T22:47:38Z',
#       'revid': 424763089,
#       'anon': '',
#       'user': '72.221.71.250',
#       'parentid': 424762941,
#       'size': 42431},
#      {'comment': 'Have added a thing of my new rom that I will be released called Super Luigi 64',
#       'tags': [],
#       'timestamp': '2011-04-18T22:46:36Z',
#       'revid': 424762941,
#       'anon': '',
#       'user': '72.221.71.250',
#       'parentid': 423468663,
#       'size': 42437},
#      {'comment': 'Reverted edits by [[Special:Contributions/Ebin1212|Ebin1212]] to last version by Lord Psyko Jo ([[User:Ale_jrb/Scripts/igloo|GLOO]])',
#       'tags': [],
#       'timestamp': '2011-04-11T06:21:18Z',
#       'revid': 423468663,
#       'user': 'Fæ',
#       'parentid': 423468632,
#       'minor': '',
#       'size': 41824},
#      {'comment': '',
#       'tags': [],
#       'timestamp': '2011-04-11T06:20:51Z',
#       'revid': 423468632,
#       'user': 'Ebin1212',
#       'parentid': 422865867,
#       'size': 40585},
#      {'comment': 'Reverted to revision 422725232 by ThomasO1989; "Several" is better here because it includes bonus stages, hub areas, etc. ([[WP:TW|TW]])',
#       'tags': [],
#       'timestamp': '2011-04-07T14:46:37Z',
#       'revid': 422865867,
#       'user': 'Lord Psyko Jo',
#       'parentid': 422863485,
#       'size': 41824},
#      {'comment': '/* Gameplay */',
#       'tags': [],
#       'timestamp': '2011-04-07T14:28:15Z',
#       'revid': 422863485,
#       'anon': '',
#       'user': '72.204.250.130',
#       'parentid': 422725232,
#       'size': 41824},
#      {'comment': 'rv source?',
#       'tags': [],
#       'timestamp': '2011-04-06T17:40:34Z',
#       'revid': 422725232,
#       'user': 'ThomasO1989',
#       'parentid': 422724117,
#       'size': 41824},
#      {'comment': '/* Remakes and sequels */',
#       'tags': [],
#       'timestamp': '2011-04-06T17:32:56Z',
#       'revid': 422724117,
#       'user': 'Axon64',
#       'parentid': 422724006,
#       'size': 41953},
#      {'comment': '/* Remakes and sequels */',
#       'tags': [],
#       'timestamp': '2011-04-06T17:32:13Z',
#       'revid': 422724006,
#       'user': 'Axon64',
#       'parentid': 422382335,
#       'size': 41952},
#      {'comment': '/* Development */',
#       'tags': [],
#       'timestamp': '2011-04-04T20:44:07Z',
#       'revid': 422382335,
#       'user': 'MarioLOA',
#       'parentid': 421879632,
#       'size': 41824},
#      {'comment': '[[Help:Reverting|Reverted]] edits by [[Special:Contributions/97.114.39.91|97.114.39.91]] ([[User talk:97.114.39.91|talk]]) to last version by WikitanvirBot',
#       'tags': [],
#       'timestamp': '2011-04-01T20:54:04Z',
#       'revid': 421879632,
#       'user': 'Andrevan',
#       'parentid': 421873900,
#       'minor': '',
#       'size': 41734},
#      {'comment': '',
#       'tags': [],
#       'timestamp': '2011-04-01T20:17:25Z',
#       'revid': 421873900,
#       'anon': '',
#       'user': '97.114.39.91',
#       'parentid': 421873678,
#       'size': 41940},
#      {'comment': '',
#       'tags': [],
#       'timestamp': '2011-04-01T20:15:44Z',
#       'revid': 421873678,
#       'anon': '',
#       'user': '97.114.39.91',
#       'parentid': 421732779,
#       'size': 41940},
#      {'comment': 'r2.7.1) (robot Removing: [[be:Super Mario 64]]',
#       'tags': [],
#       'timestamp': '2011-03-31T23:32:47Z',
#       'revid': 421732779,
#       'user': 'WikitanvirBot',
#       'parentid': 421513670,
#       'minor': '',
#       'size': 41734},
#      {'comment': 'r2.7.1) (robot Adding: [[be:Super Mario 64]]',
#       'tags': [],
#       'timestamp': '2011-03-30T17:30:58Z',
#       'revid': 421513670,
#       'user': 'Luckas-bot',
#       'parentid': 419516278,
#       'minor': '',
#       'size': 41756},
#      {'comment': 'Revert to revision 418962821 dated 2011-03-15 15:10:47 by ThomasO1989 using [[:en:Wikipedia:Tools/Navigation_popups|popups]]',
#       'tags': [],
#       'timestamp': '2011-03-18T20:21:55Z',
#       'revid': 419516278,
#       'user': 'Gfoley4',
#       'parentid': 419516167,
#       'size': 41734},
#      {'comment': 'Protected Super Mario 64: inbound nonsense  ([edit=autoconfirmed] (expires 20:21, 19 March 2011 (UTC)) [move=autoconfirmed] (expires 20:21, 19 March 2011 (UTC)))',
#       'tags': [],
#       'timestamp': '2011-03-18T20:21:14Z',
#       'revid': 419516167,
#       'user': 'Gfoley4',
#       'parentid': 419516148,
#       'minor': '',
#       'size': 41734}]}}},
#  'startTimeCollected': '2011-04-20T00:55:46Z',
#  'endTimeCollected': '2011-03-18T20:21:14Z'}

# %%
type(filename)
# Out:
# str

# %%
f
# Out:
# <_io.TextIOWrapper name='depp_dataset.csv' mode='r+' encoding='cp1252'>

# %%
import csv
with open(r'hello.csv', 'a', encoding="utf-8") as f:
                writer = csv.writer(f)
                writer.writerow(['0','1'])

# %%
str1
# Out:
# '1,2,3'

# %%
#Get Page views
import csv   
import os, csv
import json
import pageviewapi

file_processing_counter = 0
retry_count = 0
MAX_TRIES = 10
for path, dirs, files in os.walk('.\protectedPageData'):
    for filename in files:
        #file_processing_counter +=1
        #if(file_processing_counter)
        if (filename.startswith('.')):
            continue
        else:
            ##Add filename to the depp_dataset.csv file
            print ('Processing file...',filename)
            with open (path + "/" + filename,"r") as f:
                data = json.load(f)
            
            title = data['query']['pages'][filename]['title']
            print(title)
            ## Page view counter from 07/01/2015 to 08/06/2021
            
            try:
                page_views = pageviewapi.per_article('en.wikipedia', title, '20150701', '20210607', access='all-access', agent='all-agents', granularity='daily')
            except ConectionResetError as e:
                if (retry_count == MAX_RETRIES):
                    raise e
                time.sleep(5)
                retry_count +=1
                page_views = pageviewapi.per_article('en.wikipedia', title, '20150701', '20210607', access='all-access', agent='all-agents', granularity='daily')

            
            view_counter = 0
            for i in range (0, len(page_views['items'])):
                view_counter += page_views['items'][i]['views']

            print('Tilte:', title, 'View Count:',view_counter)
            
            #filename = 20
            #view_counter = 100
            filename_list = [filename, view_counter]
            import csv
            with open(r'hello.csv', 'a', encoding="utf-8") as f:
                writer = csv.writer(f)
                writer.writerow(filename_list)
# Out:
# Processing file... 100062
# Super Mario 64
# Tilte: Super Mario 64 View Count: 2126780
# ['100062', 'Super Mario 64', 2126780]
# Processing file... 1001251
# Robert Spencer (author)
# Tilte: Robert Spencer (author) View Count: 532302
# ['1001251', 'Robert Spencer (author)', 532302]
# Processing file... 100127
# Florence Nightingale
# Tilte: Florence Nightingale View Count: 8121102
# ['100127', 'Florence Nightingale', 8121102]
# Processing file... 10012799
# Barstow Harvey House
# Tilte: Barstow Harvey House View Count: 62963
# ['10012799', 'Barstow Harvey House', 62963]
# Processing file... 1001666
# List of Dragon Ball characters
# Tilte: List of Dragon Ball characters View Count: 5051287
# ['1001666', 'List of Dragon Ball characters', 5051287]
# Processing file... 1001707
# Jaffa Cakes
# Tilte: Jaffa Cakes View Count: 1298825
# ['1001707', 'Jaffa Cakes', 1298825]
# Processing file... 100196
# Tim Westwood
# Tilte: Tim Westwood View Count: 1115033
# ['100196', 'Tim Westwood', 1115033]
# Processing file... 10024
# MDMA
# Tilte: MDMA View Count: 14237182
# ['10024', 'MDMA', 14237182]
# Processing file... 10039332
# Consol Energy Center
# Tilte: Consol Energy Center View Count: 219824
# ['10039332', 'Consol Energy Center', 219824]
# Processing file... 1004706
# Dysarthria
# Tilte: Dysarthria View Count: 1590426
# ['1004706', 'Dysarthria', 1590426]
# Processing file... 100627
# Emo
# Tilte: Emo View Count: 4064083
# ['100627', 'Emo', 4064083]
# Processing file... 10079827
# Max Blumenthal
# Tilte: Max Blumenthal View Count: 706742
# ['10079827', 'Max Blumenthal', 706742]
# Processing file... 1008436
# Eustace Mullins
# Tilte: Eustace Mullins View Count: 272189
# ['1008436', 'Eustace Mullins', 272189]
# Processing file... 10086685
# Chris Malkin
# Tilte: Chris Malkin View Count: 19956
# ['10086685', 'Chris Malkin', 19956]
# Processing file... 10089424
# Kearnan Myall
# Tilte: Kearnan Myall View Count: 23833
# ['10089424', 'Kearnan Myall', 23833]
# Processing file... 1009259
# Macy's Thanksgiving Day Parade
# Tilte: Macy's Thanksgiving Day Parade View Count: 2198960
# ['1009259', "Macy's Thanksgiving Day Parade", 2198960]
# Processing file... 10099763
# Green Hills Engineering College
# Tilte: Green Hills Engineering College View Count: 20048
# ['10099763', 'Green Hills Engineering College', 20048]
# Processing file... 10101151
# IQ and Global Inequality
# Tilte: IQ and Global Inequality View Count: 228056
# ['10101151', 'IQ and Global Inequality', 228056]
# Processing file... 10106
# Earthquake
# Tilte: Earthquake View Count: 11557598
# ['10106', 'Earthquake', 11557598]
# Processing file... 10111390
# Guild Wars 2
# Tilte: Guild Wars 2 View Count: 1218436
# ['10111390', 'Guild Wars 2', 1218436]
# Processing file... 10128
# Elizabeth I of England
# Tilte: Elizabeth I of England View Count: 27703236
# ['10128', 'Elizabeth I of England', 27703236]
# Processing file... 1014
# Alcohol
# Tilte: Alcohol View Count: 5796741
# ['1014', 'Alcohol', 5796741]
# Processing file... 10157131
# Diego Costa
# Tilte: Diego Costa View Count: 7371353
# ['10157131', 'Diego Costa', 7371353]
# Processing file... 10160866
# List of Canadian inventions
# Tilte: List of Canadian inventions View Count: 504283
# ['10160866', 'List of Canadian inventions', 504283]
# Processing file... 101679
# VRML
# Tilte: VRML View Count: 442784
# ['101679', 'VRML', 442784]
# Processing file... 10172009
# Kulraj Randhawa
# Tilte: Kulraj Randhawa View Count: 876561
# ['10172009', 'Kulraj Randhawa', 876561]
# Processing file... 1017610
# Dido (disambiguation)
# Tilte: Dido (disambiguation) View Count: 84719
# ['1017610', 'Dido (disambiguation)', 84719]
# Processing file... 1018018
# Burzynski Clinic
# Tilte: Burzynski Clinic View Count: 1279103
# ['1018018', 'Burzynski Clinic', 1279103]
# Processing file... 101942
# Child labour
# Tilte: Child labour View Count: 5902428
# ['101942', 'Child labour', 5902428]
# Processing file... 101970
# Tinnitus
# Tilte: Tinnitus View Count: 7352884
# ['101970', 'Tinnitus', 7352884]
# Processing file... 10200539
# Premier Basketball League
# Tilte: Premier Basketball League View Count: 203961
# ['10200539', 'Premier Basketball League', 203961]
# Processing file... 1021390
# Sebastián Vizcaíno
# Tilte: Sebastián Vizcaíno View Count: 206776
# ['1021390', 'Sebastián Vizcaíno', 206776]
# Processing file... 102210
# Arthur (TV series)
# Tilte: Arthur (TV series) View Count: 4124129
# ['102210', 'Arthur (TV series)', 4124129]
# Processing file... 1022192
# Nokia 3310
# Tilte: Nokia 3310 View Count: 2204481
# ['1022192', 'Nokia 3310', 2204481]
# Processing file... 1024181
# Carlos Tevez
# Tilte: Carlos Tevez View Count: 6061062
# ['1024181', 'Carlos Tevez', 6061062]
# Processing file... 102490
# Dell
# Tilte: Dell View Count: 8882397
# ['102490', 'Dell', 8882397]
# Processing file... 10255667
# The Biggest Loser Australia (season 1)
# Tilte: The Biggest Loser Australia (season 1) View Count: 99699
# ['10255667', 'The Biggest Loser Australia (season 1)', 99699]
# Processing file... 10256222
# The Biggest Loser Australia (season 2)
# Tilte: The Biggest Loser Australia (season 2) View Count: 40998
# ['10256222', 'The Biggest Loser Australia (season 2)', 40998]
# Processing file... 102567
# John Forbes Nash, Jr.
# Tilte: John Forbes Nash, Jr. View Count: 2284937
# ['102567', 'John Forbes Nash, Jr.', 2284937]
# Processing file... 102690
# Adam Sandler
# Tilte: Adam Sandler View Count: 24993509
# ['102690', 'Adam Sandler', 24993509]
# Processing file... 1027216
# Confraternity of Christian Doctrine
# Tilte: Confraternity of Christian Doctrine View Count: 283075
# ['1027216', 'Confraternity of Christian Doctrine', 283075]
# Processing file... 102724
# Kyrgyz people
# Tilte: Kyrgyz people View Count: 883195
# ['102724', 'Kyrgyz people', 883195]
# Processing file... 102745
# Abigail Adams
# Tilte: Abigail Adams View Count: 2981984
# ['102745', 'Abigail Adams', 2981984]
# Processing file... 10276064
# Bill Nye
# Tilte: Bill Nye View Count: 9994129
# ['10276064', 'Bill Nye', 9994129]
# Processing file... 1027957
# Early Christianity
# Tilte: Early Christianity View Count: 1658050
# ['1027957', 'Early Christianity', 1658050]
# Processing file... 10284103
# House of Merode
# Tilte: House of Merode View Count: 92358
# ['10284103', 'House of Merode', 92358]
# Processing file... 1028560
# Creighton Preparatory School
# Tilte: Creighton Preparatory School View Count: 118967
# ['1028560', 'Creighton Preparatory School', 118967]
# Processing file... 10291466
# Laura Marano
# Tilte: Laura Marano View Count: 3931093
# ['10291466', 'Laura Marano', 3931093]
# Processing file... 10292532
# ICarly
# Tilte: ICarly View Count: 5772522
# ['10292532', 'ICarly', 5772522]
# Processing file... 10303
# Evaporation
# Tilte: Evaporation View Count: 2474667
# ['10303', 'Evaporation', 2474667]
# Processing file... 10304105
# Machete (film)
# Tilte: Machete (film) View Count: 965522
# ['10304105', 'Machete (film)', 965522]
# Processing file... 1030599
# Black History Month
# Tilte: Black History Month View Count: 2816859
# ['1030599', 'Black History Month', 2816859]
# Processing file... 1030713
# Gabe Newell
# Tilte: Gabe Newell View Count: 3357279
# ['1030713', 'Gabe Newell', 3357279]
# Processing file... 1031793
# Didier Drogba
# Tilte: Didier Drogba View Count: 8161330
# ['1031793', 'Didier Drogba', 8161330]
# Processing file... 1033826
# Professional wrestling attacks
# Tilte: Professional wrestling attacks View Count: 2967525
# ['1033826', 'Professional wrestling attacks', 2967525]
# Processing file... 1033852
# Political views of Adolf Hitler
# Tilte: Political views of Adolf Hitler View Count: 1187680
# ['1033852', 'Political views of Adolf Hitler', 1187680]
# Processing file... 1033897
# Death of Adolf Hitler
# Tilte: Death of Adolf Hitler View Count: 8960514
# ['1033897', 'Death of Adolf Hitler', 8960514]
# Processing file... 1033898
# Jim Norton (Irish actor)
# Tilte: Jim Norton (Irish actor) View Count: 550054
# ['1033898', 'Jim Norton (Irish actor)', 550054]
# Processing file... 1034769
# Ugly
# Tilte: Ugly View Count: 146342
# ['1034769', 'Ugly', 146342]
# Processing file... 103695
# Master race
# Tilte: Master race View Count: 2071642
# ['103695', 'Master race', 2071642]
# Processing file... 10374465
# Jordan Rhodes
# Tilte: Jordan Rhodes View Count: 1267744
# ['10374465', 'Jordan Rhodes', 1267744]
# Processing file... 1038
# Aarhus
# Tilte: Aarhus View Count: 1592884
# ['1038', 'Aarhus', 1592884]
# Processing file... 1038594
# Ameesha Patel
# Tilte: Ameesha Patel View Count: 4546163
# ['1038594', 'Ameesha Patel', 4546163]
# Processing file... 10391001
# Lil Wayne albums discography
# Tilte: Lil Wayne albums discography View Count: 1452032
# ['10391001', 'Lil Wayne albums discography', 1452032]
# Processing file... 103930
# Soleil Moon Frye
# Tilte: Soleil Moon Frye View Count: 4730519
# ['103930', 'Soleil Moon Frye', 4730519]
# Processing file... 1039393
# Andrewsarchus
# Tilte: Andrewsarchus View Count: 520695
# ['1039393', 'Andrewsarchus', 520695]
# Processing file... 10396793
# The Holocaust
# Tilte: The Holocaust View Count: 23659748
# ['10396793', 'The Holocaust', 23659748]
# Processing file... 10403956
# Robert Garside
# Tilte: Robert Garside View Count: 52630
# ['10403956', 'Robert Garside', 52630]
# Processing file... 10404818
# Hindutash
# Tilte: Hindutash View Count: 35002
# ['10404818', 'Hindutash', 35002]
# Processing file... 10407205
# Days of Our Lives cast members
# Tilte: Days of Our Lives cast members View Count: 2356364
# ['10407205', 'Days of Our Lives cast members', 2356364]
# Processing file... 10410626
# John Adams
# Tilte: John Adams View Count: 14860198
# ['10410626', 'John Adams', 14860198]
# Processing file... 1041577
# Mark Henry
# Tilte: Mark Henry View Count: 4262082
# ['1041577', 'Mark Henry', 4262082]
# Processing file... 10419775
# Surana, Haryana
# Tilte: Surana, Haryana View Count: 3706
# ['10419775', 'Surana, Haryana', 3706]
# Processing file... 10422721
# Pacific Northwest tree octopus
# Tilte: Pacific Northwest tree octopus View Count: 789589
# ['10422721', 'Pacific Northwest tree octopus', 789589]
# Processing file... 10442845
# Travel website
# Tilte: Travel website View Count: 522147
# ['10442845', 'Travel website', 522147]
# Processing file... 104444
# Dietary supplement
# Tilte: Dietary supplement View Count: 1830065
# ['104444', 'Dietary supplement', 1830065]
# Processing file... 10445381
# Calvin Goddard (ballistics)
# Tilte: Calvin Goddard (ballistics) View Count: 53002
# ['10445381', 'Calvin Goddard (ballistics)', 53002]
# Processing file... 10449970
# List of TriStar Pictures films
# Tilte: List of TriStar Pictures films View Count: 669910
# ['10449970', 'List of TriStar Pictures films', 669910]
# Processing file... 10468424
# Blah
# Tilte: Blah View Count: 101717
# ['10468424', 'Blah', 101717]
# Processing file... 1047310
# Crosspool
# Tilte: Crosspool View Count: 36063
# ['1047310', 'Crosspool', 36063]
# Processing file... 1047835
# Way of the Dragon
# Tilte: Way of the Dragon View Count: 1257399
# ['1047835', 'Way of the Dragon', 1257399]
# Processing file... 1047970
# Avenged Sevenfold
# Tilte: Avenged Sevenfold View Count: 6539452
# ['1047970', 'Avenged Sevenfold', 6539452]
# Processing file... 10483209
# Skilled Group
# Tilte: Skilled Group View Count: 30320
# ['10483209', 'Skilled Group', 30320]
# Processing file... 10485669
# Claire Holt
# Tilte: Claire Holt View Count: 4516117
# ['10485669', 'Claire Holt', 4516117]
# Processing file... 10494172
# Russell Kane
# Tilte: Russell Kane View Count: 940877
# ['10494172', 'Russell Kane', 940877]
# Processing file... 1050479
# BloodRayne 2
# Tilte: BloodRayne 2 View Count: 211863
# ['1050479', 'BloodRayne 2', 211863]
# Processing file... 10509730
# Alec Butler
# Tilte: Alec Butler View Count: 82560
# ['10509730', 'Alec Butler', 82560]
# Processing file... 10515516
# Pooja Gandhi
# Tilte: Pooja Gandhi View Count: 1031457
# ['10515516', 'Pooja Gandhi', 1031457]
# Processing file... 105219
# Cancer
# Tilte: Cancer View Count: 11479660
# ['105219', 'Cancer', 11479660]
# Processing file... 105390
# Pheromone
# Tilte: Pheromone View Count: 2486429
# ['105390', 'Pheromone', 2486429]
# Processing file... 1056193
# Wendy Williams
# Tilte: Wendy Williams View Count: 7360817
# ['1056193', 'Wendy Williams', 7360817]
# Processing file... 1056208
# Jure Francetić
# Tilte: Jure Francetić View Count: 101212
# ['1056208', 'Jure Francetić', 101212]
# Processing file... 1056214
# Ljubo Miloš
# Tilte: Ljubo Miloš View Count: 69231
# ['1056214', 'Ljubo Miloš', 69231]
# Processing file... 10567534
# Blake Griffin
# Tilte: Blake Griffin View Count: 8233943
# ['10567534', 'Blake Griffin', 8233943]
# Processing file... 10568
# Association football
# Tilte: Association football View Count: 14845120
# ['10568', 'Association football', 14845120]
# Processing file... 1057414
# Traumatic brain injury
# Tilte: Traumatic brain injury View Count: 2058135
# ['1057414', 'Traumatic brain injury', 2058135]
# Processing file... 10579795
# Olga Fedori
# Tilte: Olga Fedori View Count: 194750
# ['10579795', 'Olga Fedori', 194750]
# Processing file... 1058843
# Loge
# Tilte: Loge View Count: 38318
# ['1058843', 'Loge', 38318]
# Processing file... 105922
# King David Hotel bombing
# Tilte: King David Hotel bombing View Count: 825267
# ['105922', 'King David Hotel bombing', 825267]
# Processing file... 10595985
# Phil Nibbelink
# Tilte: Phil Nibbelink View Count: 54442
# ['10595985', 'Phil Nibbelink', 54442]
# Processing file... 1059962
# KVIE
# Tilte: KVIE View Count: 54603
# ['1059962', 'KVIE', 54603]
# Processing file... 10605960
# Non-penetrative sex
# Tilte: Non-penetrative sex View Count: 8122043
# ['10605960', 'Non-penetrative sex', 8122043]
# Processing file... 1061021
# List of secret police organizations
# Tilte: List of secret police organizations View Count: 319210
# ['1061021', 'List of secret police organizations', 319210]
# Processing file... 10624594
# Krypton
# Tilte: Krypton View Count: 2632543
# ['10624594', 'Krypton', 2632543]
# Processing file... 10636232
# The Pussycat Dolls
# Tilte: The Pussycat Dolls View Count: 6069596
# ['10636232', 'The Pussycat Dolls', 6069596]
# Processing file... 10646
# Food
# Tilte: Food View Count: 7233617
# ['10646', 'Food', 7233617]
# Processing file... 1066018
# Philip J. Kaplan
# Tilte: Philip J. Kaplan View Count: 89092
# ['1066018', 'Philip J. Kaplan', 89092]
# Processing file... 10667484
# Ilion Animation Studios
# Tilte: Ilion Animation Studios View Count: 167022
# ['10667484', 'Ilion Animation Studios', 167022]
# Processing file... 1068143
# The Young Turks
# Tilte: The Young Turks View Count: 3798781
# ['1068143', 'The Young Turks', 3798781]
# Processing file... 10682197
# List of Waterloo Road characters
# Tilte: List of Waterloo Road characters View Count: 605493
# ['10682197', 'List of Waterloo Road characters', 605493]
# Processing file... 10693894
# Suicide Silence
# Tilte: Suicide Silence View Count: 1353387
# ['10693894', 'Suicide Silence', 1353387]
# Processing file... 1070152
# Mugger crocodile
# Tilte: Mugger crocodile View Count: 1046078
# ['1070152', 'Mugger crocodile', 1046078]
# Processing file... 10711867
# Signal Mountain Middle High School
# Tilte: Signal Mountain Middle High School View Count: 16273
# ['10711867', 'Signal Mountain Middle High School', 16273]
# Processing file... 10721157
# Shirley Phelps-Roper
# Tilte: Shirley Phelps-Roper View Count: 1046975
# ['10721157', 'Shirley Phelps-Roper', 1046975]
# Processing file... 1075887
# John Key
# Tilte: John Key View Count: 1206133
# ['1075887', 'John Key', 1206133]
# Processing file... 10771083
# Phan Đình Phùng
# Tilte: Phan Đình Phùng View Count: 74767
# ['10771083', 'Phan Đình Phùng', 74767]
# Processing file... 10772350
# History
# Tilte: History View Count: 6784519
# ['10772350', 'History', 6784519]
# Processing file... 1078
# Antisemitism
# Tilte: Antisemitism View Count: 8863293
# ['1078', 'Antisemitism', 8863293]
# Processing file... 1078003
# Herbert Sandler
# Tilte: Herbert Sandler View Count: 92976
# ['1078003', 'Herbert Sandler', 92976]
# Processing file... 1078340
# Immortal Technique
# Tilte: Immortal Technique View Count: 2044228
# ['1078340', 'Immortal Technique', 2044228]
# Processing file... 1079866
# Mantle (geology)
# Tilte: Mantle (geology) View Count: 1959765
# ['1079866', 'Mantle (geology)', 1959765]
# Processing file... 1081183
# Andrew Bolt
# Tilte: Andrew Bolt View Count: 498571
# ['1081183', 'Andrew Bolt', 498571]
# Processing file... 10816091
# BloodRayne (franchise)
# Tilte: BloodRayne (franchise) View Count: 78732
# ['10816091', 'BloodRayne (franchise)', 78732]
# Processing file... 1081624
# Rise Against
# Tilte: Rise Against View Count: 2304110
# ['1081624', 'Rise Against', 2304110]
# Processing file... 1082198
# Nicky Cruz
# Tilte: Nicky Cruz View Count: 569073
# ['1082198', 'Nicky Cruz', 569073]
# Processing file... 10823
# Frédéric Chopin
# Tilte: Frédéric Chopin View Count: 6970088
# ['10823', 'Frédéric Chopin', 6970088]
# Processing file... 1082583
# Interstate Highways in Alaska
# Tilte: Interstate Highways in Alaska View Count: 87954
# ['1082583', 'Interstate Highways in Alaska', 87954]
# Processing file... 10841641
# Antonio Arnaiz-Villena
# Tilte: Antonio Arnaiz-Villena View Count: 18865
# ['10841641', 'Antonio Arnaiz-Villena', 18865]
# Processing file... 10843
# Fruit
# Tilte: Fruit View Count: 6609451
# ['10843', 'Fruit', 6609451]
# Processing file... 1084540
# Ian Somerhalder
# Tilte: Ian Somerhalder View Count: 12497506
# ['1084540', 'Ian Somerhalder', 12497506]
# Processing file... 10851639
# List of male performers in gay porn films
# Tilte: List of male performers in gay porn films View Count: 3105444
# ['10851639', 'List of male performers in gay porn films', 3105444]
# Processing file... 10884089
# List of The New Adventures of Winnie the Pooh episodes
# Tilte: List of The New Adventures of Winnie the Pooh episodes View Count: 279617
# ['10884089', 'List of The New Adventures of Winnie the Pooh episodes', 279617]
# Processing file... 10891776
# Call of Duty 4: Modern Warfare
# Tilte: Call of Duty 4: Modern Warfare View Count: 4174816
# ['10891776', 'Call of Duty 4: Modern Warfare', 4174816]
# Processing file... 108956
# Washington, D.C.
# Tilte: Washington, D.C. View Count: 23289612
# ['108956', 'Washington, D.C.', 23289612]
# Processing file... 10906185
# Gurjar
# Tilte: Gurjar View Count: 1587865
# ['10906185', 'Gurjar', 1587865]
# Processing file... 109179
# Bell, Florida
# Tilte: Bell, Florida View Count: 63513
# ['109179', 'Bell, Florida', 63513]
# Processing file... 10919134
# Jozy Altidore
# Tilte: Jozy Altidore View Count: 2537261
# ['10919134', 'Jozy Altidore', 2537261]
# Processing file... 1092923
# Google
# Tilte: Google View Count: 77682904
# ['1092923', 'Google', 77682904]
# Processing file... 10951
# Fahrenheit 451
# Tilte: Fahrenheit 451 View Count: 8341080
# ['10951', 'Fahrenheit 451', 8341080]
# Processing file... 1095706
# Jesus
# Tilte: Jesus View Count: 25835526
# ['1095706', 'Jesus', 25835526]
# Processing file... 10958
# Fossil
# Tilte: Fossil View Count: 3283177
# ['10958', 'Fossil', 3283177]
# Processing file... 10960729
# Mike Harper
# Tilte: Mike Harper View Count: 7808
# ['10960729', 'Mike Harper', 7808]
# Processing file... 10964586
# Tottington High School
# Tilte: Tottington High School View Count: 13481
# ['10964586', 'Tottington High School', 13481]
# Processing file... 10972664
# Young Money Entertainment
# Tilte: Young Money Entertainment View Count: 3199524
# ['10972664', 'Young Money Entertainment', 3199524]
# Processing file... 10979
# Franklin D. Roosevelt
# Tilte: Franklin D. Roosevelt View Count: 33774785
# ['10979', 'Franklin D. Roosevelt', 33774785]
# Processing file... 1098645
# Djedefre
# Tilte: Djedefre View Count: 213740
# ['1098645', 'Djedefre', 213740]
# Processing file... 10999148
# Pierce the Veil
# Tilte: Pierce the Veil View Count: 1444229
# ['10999148', 'Pierce the Veil', 1444229]
# Processing file... 1100953
# Khachkar
# Tilte: Khachkar View Count: 193942
# ['1100953', 'Khachkar', 193942]
# Processing file... 1101067
# KAPAP
# Tilte: KAPAP View Count: 97025
# ['1101067', 'KAPAP', 97025]
# Processing file... 11014515
# List of ethnic slurs
# Tilte: List of ethnic slurs View Count: 12172990
# ['11014515', 'List of ethnic slurs', 12172990]
# Processing file... 11015252
# Vladimir Lenin
# Tilte: Vladimir Lenin View Count: 15715202
# ['11015252', 'Vladimir Lenin', 15715202]
# Processing file... 1102136
# Sambandar
# Tilte: Sambandar View Count: 213773
# ['1102136', 'Sambandar', 213773]
# Processing file... 1102585
# New Brunswick general election, 1987
# Tilte: New Brunswick general election, 1987 View Count: 32897
# ['1102585', 'New Brunswick general election, 1987', 32897]
# Processing file... 11026242
# Traumatic insemination
# Tilte: Traumatic insemination View Count: 948886
# ['11026242', 'Traumatic insemination', 948886]
# Processing file... 11030872
# God Made Me Funky
# Tilte: God Made Me Funky View Count: 18773
# ['11030872', 'God Made Me Funky', 18773]
# Processing file... 11033
# Frederick Douglass
# Tilte: Frederick Douglass View Count: 11595924
# ['11033', 'Frederick Douglass', 11595924]
# Processing file... 11038318
# Methamphetamine
# Tilte: Methamphetamine View Count: 12550508
# ['11038318', 'Methamphetamine', 12550508]
# Processing file... 1103839
# List of Freemasons
# Tilte: List of Freemasons View Count: 1671146
# ['1103839', 'List of Freemasons', 1671146]
# Processing file... 11039790
# Animal
# Tilte: Animal View Count: 16162934
# ['11039790', 'Animal', 16162934]
# Processing file... 1104035
# Boob
# Tilte: Boob View Count: 611925
# ['1104035', 'Boob', 611925]
# Processing file... 11042
# Fat
# Tilte: Fat View Count: 3373256
# ['11042', 'Fat', 3373256]
# Processing file... 1104310
# James L. Dolan
# Tilte: James L. Dolan View Count: 2287418
# ['1104310', 'James L. Dolan', 2287418]
# Processing file... 11044005
# Satellite Spies
# Tilte: Satellite Spies View Count: 17392
# ['11044005', 'Satellite Spies', 17392]
# Processing file... 1105029
# Nair
# Tilte: Nair View Count: 1279895
# ['1105029', 'Nair', 1279895]
# Processing file... 11053801
# Maz Jobrani
# Tilte: Maz Jobrani View Count: 995097
# ['11053801', 'Maz Jobrani', 995097]
# Processing file... 11054586
# North View Secondary School
# Tilte: North View Secondary School View Count: 20745
# ['11054586', 'North View Secondary School', 20745]
# Processing file... 1105480
# Mushroomhead
# Tilte: Mushroomhead View Count: 1795128
# ['1105480', 'Mushroomhead', 1795128]
# Processing file... 11058016
# Mohammad Asghar
# Tilte: Mohammad Asghar View Count: 53629
# ['11058016', 'Mohammad Asghar', 53629]
# Processing file... 11059
# Five Pillars of Islam
# Tilte: Five Pillars of Islam View Count: 5210880
# ['11059', 'Five Pillars of Islam', 5210880]
# Processing file... 11059398
# Adult diaper
# Tilte: Adult diaper View Count: 508182
# ['11059398', 'Adult diaper', 508182]
# Processing file... 1106026
# Beth Ostrosky Stern
# Tilte: Beth Ostrosky Stern View Count: 2484625
# ['1106026', 'Beth Ostrosky Stern', 2484625]
# Processing file... 11062
# Friction
# Tilte: Friction View Count: 4128877
# ['11062', 'Friction', 4128877]
# Processing file... 11069849
# Disappearance of Madeleine McCann
# Tilte: Disappearance of Madeleine McCann View Count: 15604902
# ['11069849', 'Disappearance of Madeleine McCann', 15604902]
# Processing file... 11079079
# Mongolian barbecue
# Tilte: Mongolian barbecue View Count: 397328
# ['11079079', 'Mongolian barbecue', 397328]
# Processing file... 1108159
# Carcharodontosaurus
# Tilte: Carcharodontosaurus View Count: 845294
# ['1108159', 'Carcharodontosaurus', 845294]
# Processing file... 11089416
# Test
# Tilte: Test View Count: 46190476
# ['11089416', 'Test', 46190476]
# Processing file... 1109104
# Ray Comfort
# Tilte: Ray Comfort View Count: 585896
# ['1109104', 'Ray Comfort', 585896]
# Processing file... 11091078
# Dragon Ball
# Tilte: Dragon Ball View Count: 8815357
# ['11091078', 'Dragon Ball', 8815357]
# Processing file... 1109945
# Turkish Naval Forces
# Tilte: Turkish Naval Forces View Count: 768371
# ['1109945', 'Turkish Naval Forces', 768371]
# Processing file... 11100573
# Nguyen Tu Quang
# Tilte: Nguyen Tu Quang View Count: 4250
# ['11100573', 'Nguyen Tu Quang', 4250]
# Processing file... 11115779
# George Runner
# Tilte: George Runner View Count: 36892
# ['11115779', 'George Runner', 36892]
# Processing file... 11121
# Fox News Channel
# Tilte: Fox News Channel View Count: 2451914
# ['11121', 'Fox News Channel', 2451914]
# Processing file... 11123648
# Canterbury University (Seychelles)
# Tilte: Canterbury University (Seychelles) View Count: 39615
# ['11123648', 'Canterbury University (Seychelles)', 39615]
# Processing file... 11125639
# Turkey
# Tilte: Turkey View Count: 27534434
# ['11125639', 'Turkey', 27534434]
# Processing file... 11127
# Federal Bureau of Investigation
# Tilte: Federal Bureau of Investigation View Count: 8977583
# ['11127', 'Federal Bureau of Investigation', 8977583]
# Processing file... 11137057
# BlueWare
# Tilte: BlueWare View Count: 14764
# ['11137057', 'BlueWare', 14764]
# Processing file... 1113854
# .ru
# Tilte: .ru View Count: 632313
# ['1113854', '.ru', 632313]
# Processing file... 11145
# Fire
# Tilte: Fire View Count: 4523535
# ['11145', 'Fire', 4523535]
# Processing file... 1114570
# John O'Shea
# Tilte: John O'Shea View Count: 1593669
# ['1114570', "John O'Shea", 1593669]
# Processing file... 11146900
# Barney in Outer Space
# Tilte: Barney in Outer Space View Count: 40748
# ['11146900', 'Barney in Outer Space', 40748]
# Processing file... 1114732
# Palestine (region)
# Tilte: Palestine (region) View Count: 3191399
# ['1114732', 'Palestine (region)', 3191399]
# Processing file... 1116006
# Histeria!
# Tilte: Histeria! View Count: 331609
# ['1116006', 'Histeria!', 331609]
# Processing file... 1116229
# Genesis creation narrative
# Tilte: Genesis creation narrative View Count: 2323800
# ['1116229', 'Genesis creation narrative', 2323800]
# Processing file... 1116804
# Guard dog
# Tilte: Guard dog View Count: 867871
# ['1116804', 'Guard dog', 867871]
# Processing file... 1117328
# Pickaxe
# Tilte: Pickaxe View Count: 680230
# ['1117328', 'Pickaxe', 680230]
# Processing file... 11177519
# Bajót
# Tilte: Bajót View Count: 9719
# ['11177519', 'Bajót', 9719]
# Processing file... 1117939
# Fernando Torres
# Tilte: Fernando Torres View Count: 9325370
# ['1117939', 'Fernando Torres', 9325370]
# Processing file... 1118379
# Online shopping
# Tilte: Online shopping View Count: 4235308
# ['1118379', 'Online shopping', 4235308]
# Processing file... 11185
# Feminism
# Tilte: Feminism View Count: 10416233
# ['11185', 'Feminism', 10416233]
# Processing file... 11185534
# Babu Antony
# Tilte: Babu Antony View Count: 809465
# ['11185534', 'Babu Antony', 809465]
# Processing file... 11188
# French Revolution
# Tilte: French Revolution View Count: 18209513
# ['11188', 'French Revolution', 18209513]
# Processing file... 1118915
# Sheeple
# Tilte: Sheeple View Count: 282475
# ['1118915', 'Sheeple', 282475]
# Processing file... 1119701
# Physical medicine and rehabilitation
# Tilte: Physical medicine and rehabilitation View Count: 846410
# ['1119701', 'Physical medicine and rehabilitation', 846410]
# Processing file... 11206371
# List of Animals of Farthing Wood characters
# Tilte: List of Animals of Farthing Wood characters View Count: 139594
# ['11206371', 'List of Animals of Farthing Wood characters', 139594]
# Processing file... 11217925
# Paris Hilton
# Tilte: Paris Hilton View Count: 17034004
# ['11217925', 'Paris Hilton', 17034004]
# Processing file... 11223317
# Prince Devitt
# Tilte: Prince Devitt View Count: 1481075
# ['11223317', 'Prince Devitt', 1481075]
# Processing file... 11223633
# Aiglon College
# Tilte: Aiglon College View Count: 194179
# ['11223633', 'Aiglon College', 194179]
# Processing file... 11227
# Freemasonry
# Tilte: Freemasonry View Count: 21052427
# ['11227', 'Freemasonry', 21052427]
# Processing file... 112274
# The Blitz
# Tilte: The Blitz View Count: 4361501
# ['112274', 'The Blitz', 4361501]
# Processing file... 1123327
# 1998 San Marino Grand Prix
# Tilte: 1998 San Marino Grand Prix View Count: 50965
# ['1123327', '1998 San Marino Grand Prix', 50965]
# Processing file... 1123369
# Historiography of the fall of the Western Roman Empire
# Tilte: Historiography of the fall of the Western Roman Empire View Count: 440768
# ['1123369', 'Historiography of the fall of the Western Roman Empire', 440768]
# Processing file... 11236
# Fart
# Tilte: Fart View Count: 825646
# ['11236', 'Fart', 825646]
# Processing file... 11237896
# Kalya
# Tilte: Kalya View Count: 73579
# ['11237896', 'Kalya', 73579]
# Processing file... 11240
# Flatulence
# Tilte: Flatulence View Count: 3129578
# ['11240', 'Flatulence', 3129578]
# Processing file... 11247682
# The Devil Wears Prada (band)
# Tilte: The Devil Wears Prada (band) View Count: 996588
# ['11247682', 'The Devil Wears Prada (band)', 996588]
# Processing file... 11250
# Premier League
# Tilte: Premier League View Count: 27553446
# ['11250', 'Premier League', 27553446]
# Processing file... 11258
# Fellatio
# Tilte: Fellatio View Count: 14886523
# ['11258', 'Fellatio', 14886523]
# Processing file... 11260
# Relax (song)
# Tilte: Relax (song) View Count: 1211124
# ['11260', 'Relax (song)', 1211124]
# Processing file... 11260577
# Ann Romney
# Tilte: Ann Romney View Count: 944178
# ['11260577', 'Ann Romney', 944178]
# Processing file... 11263766
# Diary of a Wimpy Kid
# Tilte: Diary of a Wimpy Kid View Count: 3412649
# ['11263766', 'Diary of a Wimpy Kid', 3412649]
# Processing file... 1126490
# Yard of ale
# Tilte: Yard of ale View Count: 590917
# ['1126490', 'Yard of ale', 590917]
# Processing file... 1126578
# Ciara
# Tilte: Ciara View Count: 10491786
# ['1126578', 'Ciara', 10491786]
# Processing file... 1127442
# Mohammed Burhanuddin
# Tilte: Mohammed Burhanuddin View Count: 377526
# ['1127442', 'Mohammed Burhanuddin', 377526]
# Processing file... 11276293
# Gargamel
# Tilte: Gargamel View Count: 1168284
# ['11276293', 'Gargamel', 1168284]
# Processing file... 11286472
# Renee Alway
# Tilte: Renee Alway View Count: 561163
# ['11286472', 'Renee Alway', 561163]
# Processing file... 11288250
# Martin Hirsch
# Tilte: Martin Hirsch View Count: 27257
# ['11288250', 'Martin Hirsch', 27257]
# Processing file... 11291
# Floccinaucinihilipilification
# Tilte: Floccinaucinihilipilification View Count: 160037
# ['11291', 'Floccinaucinihilipilification', 160037]
# Processing file... 1129182
# Leonardo Araújo
# Tilte: Leonardo Araújo View Count: 756744
# ['1129182', 'Leonardo Araújo', 756744]
# Processing file... 1129697
# Paper plane
# Tilte: Paper plane View Count: 1027496
# ['1129697', 'Paper plane', 1027496]
# Processing file... 11299
# Fox
# Tilte: Fox View Count: 6654314
# ['11299', 'Fox', 6654314]
# Processing file... 1130104
# New Brunswick general election, 1982
# Tilte: New Brunswick general election, 1982 View Count: 11733
# ['1130104', 'New Brunswick general election, 1982', 11733]
# Processing file... 113055
# Temperament
# Tilte: Temperament View Count: 1011476
# ['113055', 'Temperament', 1011476]
# Processing file... 1130636
# Master Chief (Halo)
# Tilte: Master Chief (Halo) View Count: 2089689
# ['1130636', 'Master Chief (Halo)', 2089689]
# Processing file... 11315
# Friends
# Tilte: Friends View Count: 29533499
# ['11315', 'Friends', 29533499]
# Processing file... 113180
# Pussy
# Tilte: Pussy View Count: 6633566
# ['113180', 'Pussy', 6633566]
# Processing file... 11330163
# List of dubstep musicians
# Tilte: List of dubstep musicians View Count: 323522
# ['11330163', 'List of dubstep musicians', 323522]
# Processing file... 11345507
# List of Tak and the Power of Juju episodes
# Tilte: List of Tak and the Power of Juju episodes View Count: 15954
# ['11345507', 'List of Tak and the Power of Juju episodes', 15954]
# Processing file... 11347320
# Saint Thomas More High School (Milwaukee)
# Tilte: Saint Thomas More High School (Milwaukee) View Count: 20364
# ['11347320', 'Saint Thomas More High School (Milwaukee)', 20364]
# Processing file... 113525
# Dick
# Tilte: Dick View Count: 806461
# ['113525', 'Dick', 806461]
# Processing file... 11366634
# Katie Hopkins
# Tilte: Katie Hopkins View Count: 5596522
# ['11366634', 'Katie Hopkins', 5596522]
# Processing file... 1136832
# Duran Duran discography
# Tilte: Duran Duran discography View Count: 1047144
# ['1136832', 'Duran Duran discography', 1047144]
# Processing file... 11370
# FIFA World Cup
# Tilte: FIFA World Cup View Count: 24249720
# ['11370', 'FIFA World Cup', 24249720]
# Processing file... 11371144
# WRFF
# Tilte: WRFF View Count: 70484
# ['11371144', 'WRFF', 70484]
# Processing file... 113728
# Geothermal energy
# Tilte: Geothermal energy View Count: 3170434
# ['113728', 'Geothermal energy', 3170434]
# Processing file... 113746
# Sean Penn
# Tilte: Sean Penn View Count: 16640308
# ['113746', 'Sean Penn', 16640308]
# Processing file... 11392263
# Sacramento County Jail
# Tilte: Sacramento County Jail View Count: 59319
# ['11392263', 'Sacramento County Jail', 59319]
# Processing file... 11403316
# Compressed sensing
# Tilte: Compressed sensing View Count: 554989
# ['11403316', 'Compressed sensing', 554989]
# Processing file... 11408
# Female genital mutilation
# Tilte: Female genital mutilation View Count: 10468369
# ['11408', 'Female genital mutilation', 10468369]
# Processing file... 11411461
# Ola Toivonen
# Tilte: Ola Toivonen View Count: 698469
# ['11411461', 'Ola Toivonen', 698469]
# Processing file... 1141314
# California Miramar University
# Tilte: California Miramar University View Count: 196766
# ['1141314', 'California Miramar University', 196766]
# Processing file... 1141494
# Salif Diao
# Tilte: Salif Diao View Count: 193387
# ['1141494', 'Salif Diao', 193387]
# Processing file... 11415141
# Masturbation
# Tilte: Masturbation View Count: 18762374
# ['11415141', 'Masturbation', 18762374]
# Processing file... 1142195
# Onogurs
# Tilte: Onogurs View Count: 145060
# ['1142195', 'Onogurs', 145060]
# Processing file... 1143036
# Chelmsley Wood
# Tilte: Chelmsley Wood View Count: 106391
# ['1143036', 'Chelmsley Wood', 106391]
# Processing file... 1143659
# Ruby Bridges
# Tilte: Ruby Bridges View Count: 4675419
# ['1143659', 'Ruby Bridges', 4675419]
# Processing file... 1143923
# Honolulu University
# Tilte: Honolulu University View Count: 41519
# ['1143923', 'Honolulu University', 41519]
# Processing file... 11447
# Flag of the United States
# Tilte: Flag of the United States View Count: 13086559
# ['11447', 'Flag of the United States', 13086559]
# Processing file... 11461
# Francis Crick
# Tilte: Francis Crick View Count: 1933933
# ['11461', 'Francis Crick', 1933933]
# Processing file... 11470826
# Jake T. Austin
# Tilte: Jake T. Austin View Count: 4176999
# ['11470826', 'Jake T. Austin', 4176999]
# Processing file... 11473533
# Adam and Eve
# Tilte: Adam and Eve View Count: 8420295
# ['11473533', 'Adam and Eve', 8420295]
# Processing file... 11481790
# Nancy Grace
# Tilte: Nancy Grace View Count: 3099898
# ['11481790', 'Nancy Grace', 3099898]
# Processing file... 11485528
# Dan O'Halloran
# Tilte: Dan O'Halloran View Count: 43858
# ['11485528', "Dan O'Halloran", 43858]
# Processing file... 11492
# Foot
# Tilte: Foot View Count: 2247848
# ['11492', 'Foot', 2247848]
# Processing file... 11495370
# Pershing Map
# Tilte: Pershing Map View Count: 78208
# ['11495370', 'Pershing Map', 78208]
# Processing file... 11504
# Fandom
# Tilte: Fandom View Count: 1019279
# ['11504', 'Fandom', 1019279]
# Processing file... 1150748
# Bhagat Singh
# Tilte: Bhagat Singh View Count: 11610637
# ['1150748', 'Bhagat Singh', 11610637]
# Processing file... 11508
# Francis Drake
# Tilte: Francis Drake View Count: 5427619
# ['11508', 'Francis Drake', 5427619]
# Processing file... 11511282
# YouPorn
# Tilte: YouPorn View Count: 4908376
# ['11511282', 'YouPorn', 4908376]
# Processing file... 11521084
# Cassandra Clare
# Tilte: Cassandra Clare View Count: 1738452
# ['11521084', 'Cassandra Clare', 1738452]
# Processing file... 11546879
# Google Street View
# Tilte: Google Street View View Count: 5695914
# ['11546879', 'Google Street View', 5695914]
# Processing file... 11548323
# List of gay, lesbian or bisexual people: C
# Tilte: List of gay, lesbian or bisexual people: C View Count: 572234
# ['11548323', 'List of gay, lesbian or bisexual people: C', 572234]
# Processing file... 11554502
# Lester Coleman
# Tilte: Lester Coleman View Count: 21196
# ['11554502', 'Lester Coleman', 21196]
# Processing file... 11556927
# Mediacorp HD5
# Tilte: Mediacorp HD5 View Count: 16971
# ['11556927', 'Mediacorp HD5', 16971]
# Processing file... 11557106
# Batman in film
# Tilte: Batman in film View Count: 9490155
# ['11557106', 'Batman in film', 9490155]
# Processing file... 11567096
# Murdoch Mysteries
# Tilte: Murdoch Mysteries View Count: 4524856
# ['11567096', 'Murdoch Mysteries', 4524856]
# Processing file... 11567670
# List of The Cosby Show characters
# Tilte: List of The Cosby Show characters View Count: 1178088
# ['11567670', 'List of The Cosby Show characters', 1178088]
# Processing file... 1157014
# Pauly Shore
# Tilte: Pauly Shore View Count: 4372534
# ['1157014', 'Pauly Shore', 4372534]
# Processing file... 11578887
# General Hospital cast members
# Tilte: General Hospital cast members View Count: 1564023
# ['11578887', 'General Hospital cast members', 1564023]
# Processing file... 1157910
# Jimmy Conrad
# Tilte: Jimmy Conrad View Count: 444862
# ['1157910', 'Jimmy Conrad', 444862]
# Processing file... 11593017
# Burn Notice
# Tilte: Burn Notice View Count: 2946176
# ['11593017', 'Burn Notice', 2946176]
# Processing file... 1160865
# Samy Vellu
# Tilte: Samy Vellu View Count: 208303
# ['1160865', 'Samy Vellu', 208303]
# Processing file... 11619883
# Blumpkin
# Tilte: Blumpkin View Count: 59064
# ['11619883', 'Blumpkin', 59064]
# Processing file... 1162481
# Modi'in Illit
# Tilte: Modi'in Illit View Count: 164637
# ['1162481', "Modi'in Illit", 164637]
# Processing file... 1162486
# Giv'at Ze'ev
# Tilte: Giv'at Ze'ev View Count: 61461
# ['1162486', "Giv'at Ze'ev", 61461]
# Processing file... 11631288
# Abilene High School (Texas)
# Tilte: Abilene High School (Texas) View Count: 50350
# ['11631288', 'Abilene High School (Texas)', 50350]
# Processing file... 11638
# Francis of Assisi
# Tilte: Francis of Assisi View Count: 5991275
# ['11638', 'Francis of Assisi', 5991275]
# Processing file... 1164274
# Claremont Graduate University
# Tilte: Claremont Graduate University View Count: 401824
# ['1164274', 'Claremont Graduate University', 401824]
# Processing file... 11650319
# Xiaxue
# Tilte: Xiaxue View Count: 237120
# ['11650319', 'Xiaxue', 237120]
# Processing file... 11663591
# The Contractor (2007 film)
# Tilte: The Contractor (2007 film) View Count: 234392
# ['11663591', 'The Contractor (2007 film)', 234392]
# Processing file... 11665
# Filtration
# Tilte: Filtration View Count: 1679990
# ['11665', 'Filtration', 1679990]
# Processing file... 1168295
# Merneptah
# Tilte: Merneptah View Count: 607538
# ['1168295', 'Merneptah', 607538]
# Processing file... 11700559
# List of scientists opposing the mainstream scientific assessment of global warming
# Tilte: List of scientists opposing the mainstream scientific assessment of global warming View Count: 733040
# ['11700559', 'List of scientists opposing the mainstream scientific assessment of global warming', 733040]
# Processing file... 11712287
# Riaz Ahmed Gohar Shahi
# Tilte: Riaz Ahmed Gohar Shahi View Count: 298266
# ['11712287', 'Riaz Ahmed Gohar Shahi', 298266]
# Processing file... 1172299
# Damon Dash
# Tilte: Damon Dash View Count: 4842120
# ['1172299', 'Damon Dash', 4842120]
# Processing file... 1174
# Aphrodite
# Tilte: Aphrodite View Count: 9500591
# ['1174', 'Aphrodite', 9500591]
# Processing file... 1174295
# Civil Disobedience (Thoreau)
# Tilte: Civil Disobedience (Thoreau) View Count: 1154022
# ['1174295', 'Civil Disobedience (Thoreau)', 1154022]
# Processing file... 11747574
# Nicole Alexander
# Tilte: Nicole Alexander View Count: 1845754
# ['11747574', 'Nicole Alexander', 1845754]
# Processing file... 1174943
# David Hager
# Tilte: David Hager View Count: 20616
# ['1174943', 'David Hager', 20616]
# Processing file... 11749910
# Cheese
# Tilte: Cheese View Count: 5908249
# ['11749910', 'Cheese', 5908249]
# Processing file... 1175987
# List of Nobel laureates
# Tilte: List of Nobel laureates View Count: 3837216
# ['1175987', 'List of Nobel laureates', 3837216]
# Processing file... 11766333
# Online quiz
# Tilte: Online quiz View Count: 49620
# ['11766333', 'Online quiz', 49620]
# Processing file... 11768984
# Surveen Chawla
# Tilte: Surveen Chawla View Count: 2694319
# ['11768984', 'Surveen Chawla', 2694319]
# Processing file... 11776556
# Ripe Digital Entertainment
# Tilte: Ripe Digital Entertainment View Count: 9316
# ['11776556', 'Ripe Digital Entertainment', 9316]
# Processing file... 11778948
# Atomic bombings of Hiroshima and Nagasaki
# Tilte: Atomic bombings of Hiroshima and Nagasaki View Count: 24709784
# ['11778948', 'Atomic bombings of Hiroshima and Nagasaki', 24709784]
# Processing file... 1178
# Afterlife
# Tilte: Afterlife View Count: 3722726
# ['1178', 'Afterlife', 3722726]
# Processing file... 11805756
# Greg Plitt
# Tilte: Greg Plitt View Count: 1514780
# ['11805756', 'Greg Plitt', 1514780]
# Processing file... 11808592
# México en la Piel (album)
# Tilte: México en la Piel (album) View Count: 74321
# ['11808592', 'México en la Piel (album)', 74321]
# Processing file... 1181010
# Logan Lerman
# Tilte: Logan Lerman View Count: 7448729
# ['1181010', 'Logan Lerman', 7448729]
# Processing file... 1181487
# Halo 3
# Tilte: Halo 3 View Count: 1973593
# ['1181487', 'Halo 3', 1973593]
# Processing file... 1181646
# War on Drugs
# Tilte: War on Drugs View Count: 2032269
# ['1181646', 'War on Drugs', 2032269]
# Processing file... 1181663
# Comic book collecting
# Tilte: Comic book collecting View Count: 156937
# ['1181663', 'Comic book collecting', 156937]
# Processing file... 11824669
# Amit Singhal
# Tilte: Amit Singhal View Count: 588231
# ['11824669', 'Amit Singhal', 588231]
# Processing file... 11826154
# Wang Leehom
# Tilte: Wang Leehom View Count: 1016058
# ['11826154', 'Wang Leehom', 1016058]
# Processing file... 11835861
# Yucaipa High School
# Tilte: Yucaipa High School View Count: 29378
# ['11835861', 'Yucaipa High School', 29378]
# Processing file... 11846
# Guitar
# Tilte: Guitar View Count: 6142381
# ['11846', 'Guitar', 6142381]
# Processing file... 11850610
# Jeffree Star
# Tilte: Jeffree Star View Count: 9954898
# ['11850610', 'Jeffree Star', 9954898]
# Processing file... 1185646
# Mentuhotep II
# Tilte: Mentuhotep II View Count: 313834
# ['1185646', 'Mentuhotep II', 313834]
# Processing file... 11857
# George Lucas
# Tilte: George Lucas View Count: 12546697
# ['11857', 'George Lucas', 12546697]
# Processing file... 1186115
# Islam in India
# Tilte: Islam in India View Count: 5342710
# ['1186115', 'Islam in India', 5342710]
# Processing file... 11862690
# Juno (film)
# Tilte: Juno (film) View Count: 4832018
# ['11862690', 'Juno (film)', 4832018]
# Processing file... 11867
# Germany
# Tilte: Germany View Count: 37429930
# ['11867', 'Germany', 37429930]
# Processing file... 11876731
# The Mystery of the Druids
# Tilte: The Mystery of the Druids View Count: 110589
# ['11876731', 'The Mystery of the Druids', 110589]
# Processing file... 1187948
# Gary Paulsen
# Tilte: Gary Paulsen View Count: 927248
# ['1187948', 'Gary Paulsen', 927248]
# Processing file... 11889949
# Rob Dyrdek
# Tilte: Rob Dyrdek View Count: 5532413
# ['11889949', 'Rob Dyrdek', 5532413]
# Processing file... 1189614
# The Perfect Score
# Tilte: The Perfect Score View Count: 832327
# ['1189614', 'The Perfect Score', 832327]
# Processing file... 1190582
# George Gollin
# Tilte: George Gollin View Count: 12782
# ['1190582', 'George Gollin', 12782]
# Processing file... 11914121
# Rand Paul
# Tilte: Rand Paul View Count: 7329629
# ['11914121', 'Rand Paul', 7329629]
# Processing file... 1191676
# Geert Wilders
# Tilte: Geert Wilders View Count: 2264197
# ['1191676', 'Geert Wilders', 2264197]
# Processing file... 11921
# Gambling
# Tilte: Gambling View Count: 2599146
# ['11921', 'Gambling', 2599146]
# Processing file... 11926916
# Portland Pride
# Tilte: Portland Pride View Count: 14357
# ['11926916', 'Portland Pride', 14357]
# Processing file... 11932269
# List of management consulting firms
# Tilte: List of management consulting firms View Count: 822605
# ['11932269', 'List of management consulting firms', 822605]
# Processing file... 11933433
# Daniel A. McGowan
# Tilte: Daniel A. McGowan View Count: 9244
# ['11933433', 'Daniel A. McGowan', 9244]
# Processing file... 1193390
# The Order (2001 film)
# Tilte: The Order (2001 film) View Count: 200699
# ['1193390', 'The Order (2001 film)', 200699]
# Processing file... 1195328
# Erotic asphyxiation
# Tilte: Erotic asphyxiation View Count: 3376747
# ['1195328', 'Erotic asphyxiation', 3376747]
# Processing file... 11955
# George H. W. Bush
# Tilte: George H. W. Bush View Count: 36811676
# ['11955', 'George H. W. Bush', 36811676]
# Processing file... 1195649
# Michael Klonsky
# Tilte: Michael Klonsky View Count: 24325
# ['1195649', 'Michael Klonsky', 24325]
# Processing file... 11968
# George Washington
# Tilte: George Washington View Count: 31908836
# ['11968', 'George Washington', 31908836]
# Processing file... 1197010
# Hwang Jang-lee
# Tilte: Hwang Jang-lee View Count: 205922
# ['1197010', 'Hwang Jang-lee', 205922]
# Processing file... 1197173
# Joe Pasquale
# Tilte: Joe Pasquale View Count: 798069
# ['1197173', 'Joe Pasquale', 798069]
# Processing file... 11973
# Generation X
# Tilte: Generation X View Count: 23408299
# ['11973', 'Generation X', 23408299]
# Processing file... 11976936
# Numpty
# Tilte: Numpty View Count: 9277
# ['11976936', 'Numpty', 9277]
# Processing file... 11985
# Graffiti
# Tilte: Graffiti View Count: 3256104
# ['11985', 'Graffiti', 3256104]
# Processing file... 11986
# Godzilla
# Tilte: Godzilla View Count: 7839586
# ['11986', 'Godzilla', 7839586]
# Processing file... 1199328
# English Mastiff
# Tilte: English Mastiff View Count: 3492458
# ['1199328', 'English Mastiff', 3492458]
# Processing file... 11996885
# Electronic cigarette
# Tilte: Electronic cigarette View Count: 6283907
# ['11996885', 'Electronic cigarette', 6283907]
# Processing file... 1200987
# Afghanistan national football team
# Tilte: Afghanistan national football team View Count: 738025
# ['1200987', 'Afghanistan national football team', 738025]
# Processing file... 1203316
# Fred Trump
# Tilte: Fred Trump View Count: 16975646
# ['1203316', 'Fred Trump', 16975646]
# Processing file... 12035677
# Ahnenpass
# Tilte: Ahnenpass View Count: 134887
# ['12035677', 'Ahnenpass', 134887]
# Processing file... 1204033
# Astrid Muñoz
# Tilte: Astrid Muñoz View Count: 34970
# ['1204033', 'Astrid Muñoz', 34970]
# Processing file... 1204377
# MapleStory
# Tilte: MapleStory View Count: 1073979
# ['1204377', 'MapleStory', 1073979]
# Processing file... 1204559
# Jewish Voice for Peace
# Tilte: Jewish Voice for Peace View Count: 191281
# ['1204559', 'Jewish Voice for Peace', 191281]
# Processing file... 1204666
# Cuteness
# Tilte: Cuteness View Count: 666522
# ['1204666', 'Cuteness', 666522]
# Processing file... 1205872
# Halo (series)
# Tilte: Halo (series) View Count: 4345535
# ['1205872', 'Halo (series)', 4345535]
# Processing file... 1206861
# Wack Pack
# Tilte: Wack Pack View Count: 1395194
# ['1206861', 'Wack Pack', 1395194]
# Processing file... 12069270
# A Day in the Park with Barney
# Tilte: A Day in the Park with Barney View Count: 116832
# ['12069270', 'A Day in the Park with Barney', 116832]
# Processing file... 12079268
# List of Kannada-language poets
# Tilte: List of Kannada-language poets View Count: 501677
# ['12079268', 'List of Kannada-language poets', 501677]
# Processing file... 12082612
# Jennings Dog
# Tilte: Jennings Dog View Count: 90976
# ['12082612', 'Jennings Dog', 90976]
# Processing file... 12089954
# Wherever We May Roam Tour
# Tilte: Wherever We May Roam Tour View Count: 158247
# ['12089954', 'Wherever We May Roam Tour', 158247]
# Processing file... 1209075
# Melania Trump
# Tilte: Melania Trump View Count: 54783312
# ['1209075', 'Melania Trump', 54783312]
# Processing file... 12107644
# Owned-and-operated television stations in the United States
# Tilte: Owned-and-operated television stations in the United States View Count: 144724
# ['12107644', 'Owned-and-operated television stations in the United States', 144724]
# Processing file... 12108
# Greece
# Tilte: Greece View Count: 17257618
# ['12108', 'Greece', 17257618]
# Processing file... 12115130
# List of programmes broadcast by Mediacorp HD5
# Tilte: List of programmes broadcast by Mediacorp HD5 View Count: 5168
# ['12115130', 'List of programmes broadcast by Mediacorp HD5', 5168]
# Processing file... 12120000
# 27 Club
# Tilte: 27 Club View Count: 16910160
# ['12120000', '27 Club', 16910160]
# Processing file... 1212256
# Homeward Bound: The Incredible Journey
# Tilte: Homeward Bound: The Incredible Journey View Count: 1856976
# ['1212256', 'Homeward Bound: The Incredible Journey', 1856976]
# Processing file... 12137890
# Human penis
# Tilte: Human penis View Count: 13468335
# ['12137890', 'Human penis', 13468335]
# Processing file... 12153654
# Elizabeth II
# Tilte: Elizabeth II View Count: 118210630
# ['12153654', 'Elizabeth II', 118210630]
# Processing file... 12155332
# Pioneer Court
# Tilte: Pioneer Court View Count: 44498
# ['12155332', 'Pioneer Court', 44498]
# Processing file... 1216855
# Puerto Rican Campaign
# Tilte: Puerto Rican Campaign View Count: 174218
# ['1216855', 'Puerto Rican Campaign', 174218]
# Processing file... 12174108
# Jérôme Boateng
# Tilte: Jérôme Boateng View Count: 3539740
# ['12174108', 'Jérôme Boateng', 3539740]
# Processing file... 12176866
# List of The Wiggles episodes
# Tilte: List of The Wiggles episodes View Count: 200357
# ['12176866', 'List of The Wiggles episodes', 200357]
# Processing file... 1218122
# Shaun White
# Tilte: Shaun White View Count: 5276525
# ['1218122', 'Shaun White', 5276525]
# Processing file... 1220214
# American lion
# Tilte: American lion View Count: 1293802
# ['1220214', 'American lion', 1293802]
# Processing file... 12209728
# Thom Loverro
# Tilte: Thom Loverro View Count: 25499
# ['12209728', 'Thom Loverro', 25499]
# Processing file... 1221227
# The Mountain Goats
# Tilte: The Mountain Goats View Count: 1119981
# ...
# Interstate 74
# Tilte: Interstate 74 View Count: 251491
# ['93589', 'Interstate 74', 251491]
# Processing file... 93791
# Roseanne Barr
# Tilte: Roseanne Barr View Count: 8728495
# ['93791', 'Roseanne Barr', 8728495]
# Processing file... 9379281
# Andrew Thomas (American politician)
# Tilte: Andrew Thomas (American politician) View Count: 42598
# ['9379281', 'Andrew Thomas (American politician)', 42598]
# Processing file... 938202
# Markus Buchart
# Tilte: Markus Buchart View Count: 8369
# ['938202', 'Markus Buchart', 8369]
# Processing file... 93824
# Interstate 82
# Tilte: Interstate 82 View Count: 137295
# ['93824', 'Interstate 82', 137295]
# Processing file... 93828
# Interstate 85
# Tilte: Interstate 85 View Count: 470190
# ['93828', 'Interstate 85', 470190]
# Processing file... 93830
# Interstate 87
# Tilte: Interstate 87 View Count: 206883
# ['93830', 'Interstate 87', 206883]
# Processing file... 93832
# Interstate 89
# Tilte: Interstate 89 View Count: 192337
# ['93832', 'Interstate 89', 192337]
# Processing file... 939263
# Red Storm Entertainment
# Tilte: Red Storm Entertainment View Count: 269803
# ['939263', 'Red Storm Entertainment', 269803]
# Processing file... 939583
# Amy Winehouse
# Tilte: Amy Winehouse View Count: 22614539
# ['939583', 'Amy Winehouse', 22614539]
# Processing file... 9405039
# Sajeeb Wazed
# Tilte: Sajeeb Wazed View Count: 451954
# ['9405039', 'Sajeeb Wazed', 451954]
# Processing file... 941270
# Giganotosaurus
# Tilte: Giganotosaurus View Count: 1998924
# ['941270', 'Giganotosaurus', 1998924]
# Processing file... 9428
# Ernest Hemingway
# Tilte: Ernest Hemingway View Count: 21627879
# ['9428', 'Ernest Hemingway', 21627879]
# Processing file... 94289
# Sally Ride
# Tilte: Sally Ride View Count: 3762644
# ['94289', 'Sally Ride', 3762644]
# Processing file... 9430058
# Sami Khedira
# Tilte: Sami Khedira View Count: 2927861
# ['9430058', 'Sami Khedira', 2927861]
# Processing file... 9432075
# Guitar Hero
# Tilte: Guitar Hero View Count: 2057978
# ['9432075', 'Guitar Hero', 2057978]
# Processing file... 9445849
# Gok Wan
# Tilte: Gok Wan View Count: 1389814
# ['9445849', 'Gok Wan', 1389814]
# Processing file... 9450836
# Thornton High School (Colorado)
# Tilte: Thornton High School (Colorado) View Count: 25304
# ['9450836', 'Thornton High School (Colorado)', 25304]
# Processing file... 9457470
# Edward Cullen
# Tilte: Edward Cullen View Count: 1572567
# ['9457470', 'Edward Cullen', 1572567]
# Processing file... 9467
# Longest word in English
# Tilte: Longest word in English View Count: 11195136
# ['9467', 'Longest word in English', 11195136]
# Processing file... 9489004
# Jimtown High School (Elkhart, Indiana)
# Tilte: Jimtown High School (Elkhart, Indiana) View Count: 7333
# ['9489004', 'Jimtown High School (Elkhart, Indiana)', 7333]
# Processing file... 9504983
# Fenzi
# Tilte: Fenzi View Count: 13892
# ['9504983', 'Fenzi', 13892]
# Processing file... 9532
# Electromagnetism
# Tilte: Electromagnetism View Count: 3499131
# ['9532', 'Electromagnetism', 3499131]
# Processing file... 9545969
# Ilana Mercer
# Tilte: Ilana Mercer View Count: 52644
# ['9545969', 'Ilana Mercer', 52644]
# Processing file... 9549
# Edgar Allan Poe
# Tilte: Edgar Allan Poe View Count: 13717347
# ['9549', 'Edgar Allan Poe', 13717347]
# Processing file... 9550
# Electricity
# Tilte: Electricity View Count: 7173404
# ['9550', 'Electricity', 7173404]
# Processing file... 9554131
# List of members of the Irish Republican Army
# Tilte: List of members of the Irish Republican Army View Count: 486990
# ['9554131', 'List of members of the Irish Republican Army', 486990]
# Processing file... 95618
# John Vincent Atanasoff
# Tilte: John Vincent Atanasoff View Count: 500082
# ['95618', 'John Vincent Atanasoff', 500082]
# Processing file... 956210
# Michigan J. Frog
# Tilte: Michigan J. Frog View Count: 610288
# ['956210', 'Michigan J. Frog', 610288]
# Processing file... 956689
# Kura–Araxes culture
# Tilte: Kura–Araxes culture View Count: 146128
# ['956689', 'Kura–Araxes culture', 146128]
# Processing file... 9571601
# Dumbass
# Tilte: Dumbass View Count: 48328
# ['9571601', 'Dumbass', 48328]
# Processing file... 957276
# Raveena Tandon
# Tilte: Raveena Tandon View Count: 6802352
# ['957276', 'Raveena Tandon', 6802352]
# Processing file... 957684
# Cesc Fàbregas
# Tilte: Cesc Fàbregas View Count: 6015185
# ['957684', 'Cesc Fàbregas', 6015185]
# Processing file... 9578734
# Go-go boot
# Tilte: Go-go boot View Count: 238876
# ['9578734', 'Go-go boot', 238876]
# Processing file... 9584577
# McAlester News-Capital
# Tilte: McAlester News-Capital View Count: 20507
# ['9584577', 'McAlester News-Capital', 20507]
# Processing file... 9587
# Euthanasia
# Tilte: Euthanasia View Count: 6478157
# ['9587', 'Euthanasia', 6478157]
# Processing file... 958866
# Tony Attwood
# Tilte: Tony Attwood View Count: 108918
# ['958866', 'Tony Attwood', 108918]
# Processing file... 9603
# Ernest Rutherford
# Tilte: Ernest Rutherford View Count: 3756201
# ['9603', 'Ernest Rutherford', 3756201]
# Processing file... 961110
# Ashlyn Gere
# Tilte: Ashlyn Gere View Count: 882664
# ['961110', 'Ashlyn Gere', 882664]
# Processing file... 96149
# Slipknot (band)
# Tilte: Slipknot (band) View Count: 11098679
# ['96149', 'Slipknot (band)', 11098679]
# Processing file... 9630
# Ecology
# Tilte: Ecology View Count: 4217447
# ['9630', 'Ecology', 4217447]
# Processing file... 963152
# Spaniards
# Tilte: Spaniards View Count: 1774897
# ['963152', 'Spaniards', 1774897]
# Processing file... 9636145
# Gregory Paul Martin
# Tilte: Gregory Paul Martin View Count: 90905
# ['9636145', 'Gregory Paul Martin', 90905]
# Processing file... 964077
# Lamar S. Smith
# Tilte: Lamar S. Smith View Count: 277745
# ['964077', 'Lamar S. Smith', 277745]
# Processing file... 9644294
# List of Ice Age characters
# Tilte: List of Ice Age characters View Count: 2207190
# ['9644294', 'List of Ice Age characters', 2207190]
# Processing file... 9649
# Energy
# Tilte: Energy View Count: 6545526
# ['9649', 'Energy', 6545526]
# Processing file... 964985
# List of city nicknames in the United States
# Tilte: List of city nicknames in the United States View Count: 1052668
# ['964985', 'List of city nicknames in the United States', 1052668]
# Processing file... 96603
# Memphis, Egypt
# Tilte: Memphis, Egypt View Count: 1906938
# ['96603', 'Memphis, Egypt', 1906938]
# Processing file... 966195
# Erzurum
# Tilte: Erzurum View Count: 646793
# ['966195', 'Erzurum', 646793]
# Processing file... 966465
# Paul Steed
# Tilte: Paul Steed View Count: 36360
# ['966465', 'Paul Steed', 36360]
# Processing file... 96652
# Seahorse
# Tilte: Seahorse View Count: 3796414
# ['96652', 'Seahorse', 3796414]
# Processing file... 9666124
# Raai Laxmi
# Tilte: Raai Laxmi View Count: 2437376
# ['9666124', 'Raai Laxmi', 2437376]
# Processing file... 967176
# Eye of Horus
# Tilte: Eye of Horus View Count: 3856827
# ['967176', 'Eye of Horus', 3856827]
# Processing file... 9674182
# Glenn Grothman
# Tilte: Glenn Grothman View Count: 229200
# ['9674182', 'Glenn Grothman', 229200]
# Processing file... 9675071
# Ezhava
# Tilte: Ezhava View Count: 664000
# ['9675071', 'Ezhava', 664000]
# Processing file... 9679918
# Norwegian Police Service
# Tilte: Norwegian Police Service View Count: 271041
# ['9679918', 'Norwegian Police Service', 271041]
# Processing file... 970386
# The SpongeBob SquarePants Movie
# Tilte: The SpongeBob SquarePants Movie View Count: 2413892
# ['970386', 'The SpongeBob SquarePants Movie', 2413892]
# Processing file... 97044
# Khepri
# Tilte: Khepri View Count: 683329
# ['97044', 'Khepri', 683329]
# Processing file... 97046
# Atum
# Tilte: Atum View Count: 1143974
# ['97046', 'Atum', 1143974]
# Processing file... 97096
# Nu (mythology)
# Tilte: Nu (mythology) View Count: 471350
# ['97096', 'Nu (mythology)', 471350]
# Processing file... 97125
# Ptah
# Tilte: Ptah View Count: 1069192
# ['97125', 'Ptah', 1069192]
# Processing file... 9717
# Excalibur
# Tilte: Excalibur View Count: 4306590
# ['9717', 'Excalibur', 4306590]
# Processing file... 97187
# Ennead
# Tilte: Ennead View Count: 551083
# ['97187', 'Ennead', 551083]
# Processing file... 971896
# Frank Wu (artist)
# Tilte: Frank Wu (artist) View Count: 199571
# ['971896', 'Frank Wu (artist)', 199571]
# Processing file... 972036
# Evan Solomon
# Tilte: Evan Solomon View Count: 186990
# ['972036', 'Evan Solomon', 186990]
# Processing file... 97236
# Maat
# Tilte: Maat View Count: 1850717
# ['97236', 'Maat', 1850717]
# Processing file... 972591
# Delta FM
# Tilte: Delta FM View Count: 15879
# ['972591', 'Delta FM', 15879]
# Processing file... 972683
# Kyle
# Tilte: Kyle View Count: 235235
# ['972683', 'Kyle', 235235]
# Processing file... 9729299
# Jonas Brothers
# Tilte: Jonas Brothers View Count: 11200862
# ['9729299', 'Jonas Brothers', 11200862]
# Processing file... 97317
# Hathor
# Tilte: Hathor View Count: 2944336
# ['97317', 'Hathor', 2944336]
# Processing file... 9732
# Eli Whitney
# Tilte: Eli Whitney View Count: 1679492
# ['9732', 'Eli Whitney', 1679492]
# Processing file... 97404
# Cluj-Napoca
# Tilte: Cluj-Napoca View Count: 1663100
# ['97404', 'Cluj-Napoca', 1663100]
# Processing file... 9754606
# Dingleberry
# Tilte: Dingleberry View Count: 118341
# ['9754606', 'Dingleberry', 118341]
# Processing file... 9762025
# Laurel Springs School
# Tilte: Laurel Springs School View Count: 479712
# ['9762025', 'Laurel Springs School', 479712]
# Processing file... 9764
# Emma Goldman
# Tilte: Emma Goldman View Count: 2734859
# ['9764', 'Emma Goldman', 2734859]
# Processing file... 9769596
# John Riccitiello
# Tilte: John Riccitiello View Count: 289043
# ['9769596', 'John Riccitiello', 289043]
# Processing file... 976970
# Tibetan Mastiff
# Tilte: Tibetan Mastiff View Count: 5313423
# ['976970', 'Tibetan Mastiff', 5313423]
# Processing file... 9771922
# Paul Mounet
# Tilte: Paul Mounet View Count: 197311
# ['9771922', 'Paul Mounet', 197311]
# Processing file... 9773333
# Peter Brookesmith
# Tilte: Peter Brookesmith View Count: 8796
# ['9773333', 'Peter Brookesmith', 8796]
# Processing file... 97771
# Family tree of the Greek gods
# Tilte: Family tree of the Greek gods View Count: 1406361
# ['97771', 'Family tree of the Greek gods', 1406361]
# Processing file... 978203
# Flag of India
# Tilte: Flag of India View Count: 8837749
# ['978203', 'Flag of India', 8837749]
# Processing file... 979165
# Guy Fawkes Night
# Tilte: Guy Fawkes Night View Count: 6672575
# ['979165', 'Guy Fawkes Night', 6672575]
# Processing file... 979320
# Gippsland Grammar School
# Tilte: Gippsland Grammar School View Count: 18875
# ['979320', 'Gippsland Grammar School', 18875]
# Processing file... 9809619
# PlayStation Home
# Tilte: PlayStation Home View Count: 411539
# ['9809619', 'PlayStation Home', 411539]
# Processing file... 9810476
# Zombie
# Tilte: Zombie View Count: 4936666
# ['9810476', 'Zombie', 4936666]
# Processing file... 9814346
# Alex Pierson
# Tilte: Alex Pierson View Count: 47240
# ['9814346', 'Alex Pierson', 47240]
# Processing file... 98176
# Ancient Egyptian concept of the soul
# Tilte: Ancient Egyptian concept of the soul View Count: 586611
# ['98176', 'Ancient Egyptian concept of the soul', 586611]
# Processing file... 982180
# Robin Hood (1973 film)
# Tilte: Robin Hood (1973 film) View Count: 2170317
# ['982180', 'Robin Hood (1973 film)', 2170317]
# Processing file... 982199
# Peter Pan (1953 film)
# Tilte: Peter Pan (1953 film) View Count: 2637675
# ['982199', 'Peter Pan (1953 film)', 2637675]
# Processing file... 98301
# Joker (comics)
# Tilte: Joker (comics) View Count: 6213317
# ['98301', 'Joker (comics)', 6213317]
# Processing file... 98351
# Elmo
# Tilte: Elmo View Count: 2103370
# ['98351', 'Elmo', 2103370]
# Processing file... 984106
# Antonio Paoli
# Tilte: Antonio Paoli View Count: 47912
# ['984106', 'Antonio Paoli', 47912]
# Processing file... 984639
# Karan Johar
# Tilte: Karan Johar View Count: 10455352
# ['984639', 'Karan Johar', 10455352]
# Processing file... 9846732
# Dale L. Walker
# Tilte: Dale L. Walker View Count: 11913
# ['9846732', 'Dale L. Walker', 11913]
# Processing file... 984827
# Martock
# Tilte: Martock View Count: 56244
# ['984827', 'Martock', 56244]
# Processing file... 9853806
# Kanyakubja Brahmins
# Tilte: Kanyakubja Brahmins View Count: 83205
# ['9853806', 'Kanyakubja Brahmins', 83205]
# Processing file... 985535
# World Tag Team Championship (WWE)
# Tilte: World Tag Team Championship (WWE) View Count: 1372755
# ['985535', 'World Tag Team Championship (WWE)', 1372755]
# Processing file... 98650
# Chartres
# Tilte: Chartres View Count: 519961
# ['98650', 'Chartres', 519961]
# Processing file... 9866040
# List of National Basketball Association single-season scoring leaders
# Tilte: List of National Basketball Association single-season scoring leaders View Count: 203024
# ['9866040', 'List of National Basketball Association single-season scoring leaders', 203024]
# Processing file... 9877706
# Emanuel School
# Tilte: Emanuel School View Count: 206056
# ['9877706', 'Emanuel School', 206056]
# Processing file... 9878372
# Login
# Tilte: Login View Count: 2315889
# ['9878372', 'Login', 2315889]
# Processing file... 988583
# Chitral District
# Tilte: Chitral District View Count: 270260
# ['988583', 'Chitral District', 270260]
# Processing file... 9886374
# List of Epiphone players
# Tilte: List of Epiphone players View Count: 163949
# ['9886374', 'List of Epiphone players', 163949]
# Processing file... 989460
# Sam Katz
# Tilte: Sam Katz View Count: 64182
# ['989460', 'Sam Katz', 64182]
# Processing file... 9896
# Elf
# Tilte: Elf View Count: 2735885
# ['9896', 'Elf', 2735885]
# Processing file... 9896564
# ResellerRatings
# Tilte: ResellerRatings View Count: 37795
# ['9896564', 'ResellerRatings', 37795]
# Processing file... 990501
# Nanyang Polytechnic
# Tilte: Nanyang Polytechnic View Count: 150919
# ['990501', 'Nanyang Polytechnic', 150919]
# Processing file... 9906294
# Johann Sebastian Bach
# Tilte: Johann Sebastian Bach View Count: 8965113
# ['9906294', 'Johann Sebastian Bach', 8965113]
# Processing file... 99063
# Isaac Brock
# Tilte: Isaac Brock View Count: 534747
# ['99063', 'Isaac Brock', 534747]
# Processing file... 990764
# The Wild Thornberrys Movie
# Tilte: The Wild Thornberrys Movie View Count: 501720
# ['990764', 'The Wild Thornberrys Movie', 501720]
# Processing file... 9908504
# Gambling for resurrection
# Tilte: Gambling for resurrection View Count: 17425
# ['9908504', 'Gambling for resurrection', 17425]
# Processing file... 9909905
# Ninja Theory
# Tilte: Ninja Theory View Count: 1105310
# ['9909905', 'Ninja Theory', 1105310]
# Processing file... 9911223
# Flux (software)
# Tilte: Flux (software) View Count: 125450
# ['9911223', 'Flux (software)', 125450]
# Processing file... 991143
# Frank Sinatra, Jr.
# Tilte: Frank Sinatra, Jr. View Count: 2193663
# ['991143', 'Frank Sinatra, Jr.', 2193663]
# Processing file... 991210
# Divisibility rule
# Tilte: Divisibility rule View Count: 2275754
# ['991210', 'Divisibility rule', 2275754]
# Processing file... 9918415
# Matt Sanchez
# Tilte: Matt Sanchez View Count: 79505
# ['9918415', 'Matt Sanchez', 79505]
# Processing file... 991985
# Pitbull (rapper)
# Tilte: Pitbull (rapper) View Count: 10055080
# ['991985', 'Pitbull (rapper)', 10055080]
# Processing file... 992332
# Bob Larson
# Tilte: Bob Larson View Count: 288635
# ['992332', 'Bob Larson', 288635]
# Processing file... 9924355
# Peggle
# Tilte: Peggle View Count: 373055
# ['9924355', 'Peggle', 373055]
# Processing file... 993558
# Treehouse TV
# Tilte: Treehouse TV View Count: 599262
# ['993558', 'Treehouse TV', 599262]
# Processing file... 9935632
# List of tallest buildings in Karachi
# Tilte: List of tallest buildings in Karachi View Count: 158830
# ['9935632', 'List of tallest buildings in Karachi', 158830]
# Processing file... 993655
# Asif Ali Zardari
# Tilte: Asif Ali Zardari View Count: 1921996
# ['993655', 'Asif Ali Zardari', 1921996]
# Processing file... 99372
# Robin (comics)
# Tilte: Robin (comics) View Count: 3444495
# ['99372', 'Robin (comics)', 3444495]
# Processing file... 9940234
# Tomato
# Tilte: Tomato View Count: 7129743
# ['9940234', 'Tomato', 7129743]
# Processing file... 994160
# Samoa Joe
# Tilte: Samoa Joe View Count: 4751987
# ['994160', 'Samoa Joe', 4751987]
# Processing file... 9942
# Erwin Schrödinger
# Tilte: Erwin Schrödinger View Count: 3606232
# ['9942', 'Erwin Schrödinger', 3606232]
# Processing file... 9963622
# I Come in Peace
# Tilte: I Come in Peace View Count: 371659
# ['9963622', 'I Come in Peace', 371659]
# Processing file... 99645
# Homo sapiens
# Tilte: Homo sapiens View Count: 8546322
# ['99645', 'Homo sapiens', 8546322]
# Processing file... 9987564
# A Day to Remember
# Tilte: A Day to Remember View Count: 2334883
# ['9987564', 'A Day to Remember', 2334883]
# Processing file... 9988187
# Twitter
# Tilte: Twitter View Count: 22538387
# ['9988187', 'Twitter', 22538387]

# %%
## Page view counter from 07/01/2015 to 08/06/2021
import pageviewapi
#try:
page_views = pageviewapi.per_article('en.wikipedia', '9/11 conspiracy theories', '20150107', '20210607',
                        access='all-access', agent='all-agents', granularity='daily')
#except ZeroOrDataNotLoadedException as e:
#     print ('ZeroOrDataNotLoadedException error has occured, so setting value of view_counter to NA')
#     view_counter = 'NA'
view_counter = 0
for i in range (0, len(page_views['items'])):
    view_counter += page_views['items'][i]['views']

# %%
filename_list
# Out:
# ['9988187', 'Twitter', 22538387]

# %%
with open(r'hello.csv', 'a', encoding="utf-8") as f:
    writer = csv.writer(f)
    writer.writerow(filename_list)

# %%
import csv
f = open('hello.csv', 'wb')
out = csv.writer(f, delimiter=",")
out.writerow(filename_list)
f.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-357ee4e2ddb0> in <module>
#       2 f = open('hello.csv', 'wb')
#       3 out = csv.writer(f, delimiter=",")
# ----> 4 out.writerow(filename_list)
#       5 f.close()
#
# TypeError: a bytes-like object is required, not 'str'

# %%
import csv

# open the file in the write mode
f = open('hello.csv', 'a')

# create the csv writer
writer = csv.writer(f)

# write a row to the csv file
writer.writerow(filename_list)

# close the file
f.close()
