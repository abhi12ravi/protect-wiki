# %%
import pandas as pd

df = pd.read_json('protectedPageData/25')

df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-5d5ed75fd551> in <module>
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_json('protectedPageData/25')
#       4
#       5 df
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     197                 else:
#     198                     kwargs[new_arg_name] = new_arg_value
# --> 199             return func(*args, **kwargs)
#     200
#     201         return cast(F, wrapper)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\json\_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression, nrows)
#     616         return json_reader
#     617
# --> 618     result = json_reader.read()
#     619     if should_close:
#     620         filepath_or_buffer.close()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\json\_json.py in read(self)
#     753                 obj = self._get_object_parser(self._combine_lines(data))
#     754         else:
# --> 755             obj = self._get_object_parser(self.data)
#     756         self.close()
#     757         return obj
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\json\_json.py in _get_object_parser(self, json)
#     775         obj = None
#     776         if typ == "frame":
# --> 777             obj = FrameParser(json, **kwargs).parse()
#     778
#     779         if typ == "series" or obj is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\json\_json.py in parse(self)
#     884
#     885         else:
# --> 886             self._parse_no_numpy()
#     887
#     888         if self.obj is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\json\_json.py in _parse_no_numpy(self)
#    1117         if orient == "columns":
#    1118             self.obj = DataFrame(
# -> 1119                 loads(json, precise_float=self.precise_float), dtype=None
#    1120             )
#    1121         elif orient == "split":
#
# ValueError: Expected object or value

# %%
import json
#data_file = 'protectedPageData/25'
#data = json.load('protectedPageData/25') 

with open('../protectedPageData/25') as data_file:    
    data = json.load(data_file)

# %%
data

# %%
from pandas import json_normalize
json_normalize(data)

# %%
def flatten_json(y):
    out = {}

    def flatten(x, name=''):
        if type(x) is dict:
            for a in x:
                flatten(x[a], name + a + '_')
        elif type(x) is list:
            i = 0
            for a in x:
                flatten(a, name + str(i) + '_')
                i += 1
        else:
            out[name[:-1]] = x

    flatten(y)
    return out

# %%
flat = flatten_json(data_file)
flat
#json_normalize(flat)

# %%
type(flat)

# %%
# Python program to read
# json file
  
  
import json
  
# Opening JSON file
f = open('../protectedPageData/25',)
  
# returns JSON object as 
# a dictionary
data = json.load(f)
  
# Iterating through the json
# list
for i in data:
    print(i)
  
# Closing file
f.close()

# %% [markdown]
# #### Getting URL from Wikipedia pageid
#
# #The pageid is the MediaWiki's internal article ID. You can use the action API's info property to get the full URL from pageid:
#
# https://en.wikipedia.org/w/api.php?action=query&prop=info&pageids=18630637&inprop=url

# %%
import os, csv

f=open("experiments/depp_dataset.csv",'r+')
w=csv.writer(f)
print(w)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-4364059864d9> in <module>
#       1 import os, csv
#       2
# ----> 3 f=open("experiments/depp_dataset.csv",'r+')
#       4 w=csv.writer(f)
#       5 print(w)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'experiments/depp_dataset.csv'

# %%
pip install git+https://github.com/Commonists/pageview-api.git
# Out:
# Collecting git+https://github.com/Commonists/pageview-api.git
#   Cloning https://github.com/Commonists/pageview-api.git to c:\users\abhi\appdata\local\temp\pip-req-build-r7m0s2rm
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from pageviewapi==0.4.0) (2.24.0)
# Requirement already satisfied: attrdict in c:\programdata\anaconda3\lib\site-packages (from pageviewapi==0.4.0) (2.0.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests->pageviewapi==0.4.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests->pageviewapi==0.4.0) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests->pageviewapi==0.4.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests->pageviewapi==0.4.0) (2020.6.20)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from attrdict->pageviewapi==0.4.0) (1.15.0)
# Building wheels for collected packages: pageviewapi
#   Building wheel for pageviewapi (setup.py): started
#   Building wheel for pageviewapi (setup.py): finished with status 'done'
#   Created wheel for pageviewapi: filename=pageviewapi-0.4.0-py3-none-any.whl size=5302 sha256=1101243844bd4c843e9b1155152a3a074721a49a4bdcde1ddc3955519d7f9dde
#   Stored in directory: C:\Users\Abhi\AppData\Local\Temp\pip-ephem-wheel-cache-l3doh6w6\wheels\e8\3a\ac\a1a47ff2f5621ea13ecac16035f07c2c35ee2509404d828171
# Successfully built pageviewapi
# Installing collected packages: pageviewapi
#   Attempting uninstall: pageviewapi
#     Found existing installation: pageviewapi Undefined
#     Uninstalling pageviewapi-Undefined:
#       Successfully uninstalled pageviewapi-Undefined
# Successfully installed pageviewapi-0.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
## Page view counter from 07/01/2015 to 08/06/2021
import pageviewapi
page_views = pageviewapi.per_article('en.wikipedia', 'Autism', '20150107', '20210607',
                        access='all-access', agent='all-agents', granularity='daily')

view_counter = 0
for i in range (0, len(page_views['items'])):
    view_counter += page_views['items'][i]['views']

# %%
view_counter
# Out:
# 12307544

# %%
f=open("consolidated_data.csv",'a+')
w=csv.writer(f)
for path, dirs, files in os.walk("C:/Users/Amber/Creator"):
    for filename in files:
        w.writerow([filename])

# %%
#Write page id to output file
import csv   
import os, csv
import json



for path, dirs, files in os.walk('.\protectedPageData'):
    for filename in files:
        if (filename.startswith('.')):
            continue
        else:
            ##Add filename to the depp_dataset.csv file
            print ('Processing file...',filename)
            with open (path + "/" + filename,"r") as f:
                data = json.load(f)
            title = data['query']['pages'][filename]['title']
            print(title)
            
            protection = data['query']['pages']['protection']
            print(protection)
                       
#             filename_list = [filename, title]
#             print (filename_list)
#             with open(r'hello.csv', 'a', encoding="utf-8") as f:
#                 writer = csv.writer(f)
#                 writer.writerow(filename_list)
# Out:
# Processing file... 100062
# Super Mario 64
# ['100062', 'Super Mario 64']
# Processing file... 1001251
# Robert Spencer (author)
# ['1001251', 'Robert Spencer (author)']
# Processing file... 100127
# Florence Nightingale
# ['100127', 'Florence Nightingale']
# Processing file... 10012799
# Barstow Harvey House
# ['10012799', 'Barstow Harvey House']
# Processing file... 1001666
# List of Dragon Ball characters
# ['1001666', 'List of Dragon Ball characters']
# Processing file... 1001707
# Jaffa Cakes
# ['1001707', 'Jaffa Cakes']
# Processing file... 100196
# Tim Westwood
# ['100196', 'Tim Westwood']
# Processing file... 10024
# MDMA
# ['10024', 'MDMA']
# Processing file... 10039332
# Consol Energy Center
# ['10039332', 'Consol Energy Center']
# Processing file... 1004706
# Dysarthria
# ['1004706', 'Dysarthria']
# Processing file... 100627
# Emo
# ['100627', 'Emo']
# Processing file... 10079827
# Max Blumenthal
# ['10079827', 'Max Blumenthal']
# Processing file... 1008436
# Eustace Mullins
# ['1008436', 'Eustace Mullins']
# Processing file... 10086685
# Chris Malkin
# ['10086685', 'Chris Malkin']
# Processing file... 10089424
# Kearnan Myall
# ['10089424', 'Kearnan Myall']
# Processing file... 1009259
# Macy's Thanksgiving Day Parade
# ['1009259', "Macy's Thanksgiving Day Parade"]
# Processing file... 10099763
# Green Hills Engineering College
# ['10099763', 'Green Hills Engineering College']
# Processing file... 10101151
# IQ and Global Inequality
# ['10101151', 'IQ and Global Inequality']
# Processing file... 10106
# Earthquake
# ['10106', 'Earthquake']
# Processing file... 10111390
# Guild Wars 2
# ['10111390', 'Guild Wars 2']
# Processing file... 10128
# Elizabeth I of England
# ['10128', 'Elizabeth I of England']
# Processing file... 1014
# Alcohol
# ['1014', 'Alcohol']
# Processing file... 10157131
# Diego Costa
# ['10157131', 'Diego Costa']
# Processing file... 10160866
# List of Canadian inventions
# ['10160866', 'List of Canadian inventions']
# Processing file... 101679
# VRML
# ['101679', 'VRML']
# Processing file... 10172009
# Kulraj Randhawa
# ['10172009', 'Kulraj Randhawa']
# Processing file... 1017610
# Dido (disambiguation)
# ['1017610', 'Dido (disambiguation)']
# Processing file... 1018018
# Burzynski Clinic
# ['1018018', 'Burzynski Clinic']
# Processing file... 101942
# Child labour
# ['101942', 'Child labour']
# Processing file... 101970
# Tinnitus
# ['101970', 'Tinnitus']
# Processing file... 10200539
# Premier Basketball League
# ['10200539', 'Premier Basketball League']
# Processing file... 1021390
# Sebastián Vizcaíno
# ['1021390', 'Sebastián Vizcaíno']
# Processing file... 102210
# Arthur (TV series)
# ['102210', 'Arthur (TV series)']
# Processing file... 1022192
# Nokia 3310
# ['1022192', 'Nokia 3310']
# Processing file... 1024181
# Carlos Tevez
# ['1024181', 'Carlos Tevez']
# Processing file... 102490
# Dell
# ['102490', 'Dell']
# Processing file... 10255667
# The Biggest Loser Australia (season 1)
# ['10255667', 'The Biggest Loser Australia (season 1)']
# Processing file... 10256222
# The Biggest Loser Australia (season 2)
# ['10256222', 'The Biggest Loser Australia (season 2)']
# Processing file... 102567
# John Forbes Nash, Jr.
# ['102567', 'John Forbes Nash, Jr.']
# Processing file... 102690
# Adam Sandler
# ['102690', 'Adam Sandler']
# Processing file... 1027216
# Confraternity of Christian Doctrine
# ['1027216', 'Confraternity of Christian Doctrine']
# Processing file... 102724
# Kyrgyz people
# ['102724', 'Kyrgyz people']
# Processing file... 102745
# Abigail Adams
# ['102745', 'Abigail Adams']
# Processing file... 10276064
# Bill Nye
# ['10276064', 'Bill Nye']
# Processing file... 1027957
# Early Christianity
# ['1027957', 'Early Christianity']
# Processing file... 10284103
# House of Merode
# ['10284103', 'House of Merode']
# Processing file... 1028560
# Creighton Preparatory School
# ['1028560', 'Creighton Preparatory School']
# Processing file... 10291466
# Laura Marano
# ['10291466', 'Laura Marano']
# Processing file... 10292532
# ICarly
# ['10292532', 'ICarly']
# Processing file... 10303
# Evaporation
# ['10303', 'Evaporation']
# Processing file... 10304105
# Machete (film)
# ['10304105', 'Machete (film)']
# Processing file... 1030599
# Black History Month
# ['1030599', 'Black History Month']
# Processing file... 1030713
# Gabe Newell
# ['1030713', 'Gabe Newell']
# Processing file... 1031793
# Didier Drogba
# ['1031793', 'Didier Drogba']
# Processing file... 1033826
# Professional wrestling attacks
# ['1033826', 'Professional wrestling attacks']
# Processing file... 1033852
# Political views of Adolf Hitler
# ['1033852', 'Political views of Adolf Hitler']
# Processing file... 1033897
# Death of Adolf Hitler
# ['1033897', 'Death of Adolf Hitler']
# Processing file... 1033898
# Jim Norton (Irish actor)
# ['1033898', 'Jim Norton (Irish actor)']
# Processing file... 1034769
# Ugly
# ['1034769', 'Ugly']
# Processing file... 103695
# Master race
# ['103695', 'Master race']
# Processing file... 10374465
# Jordan Rhodes
# ['10374465', 'Jordan Rhodes']
# Processing file... 1038
# Aarhus
# ['1038', 'Aarhus']
# Processing file... 1038594
# Ameesha Patel
# ['1038594', 'Ameesha Patel']
# Processing file... 10391001
# Lil Wayne albums discography
# ['10391001', 'Lil Wayne albums discography']
# Processing file... 103930
# Soleil Moon Frye
# ['103930', 'Soleil Moon Frye']
# Processing file... 1039393
# Andrewsarchus
# ['1039393', 'Andrewsarchus']
# Processing file... 10396793
# The Holocaust
# ['10396793', 'The Holocaust']
# Processing file... 10403956
# Robert Garside
# ['10403956', 'Robert Garside']
# Processing file... 10404818
# Hindutash
# ['10404818', 'Hindutash']
# Processing file... 10407205
# Days of Our Lives cast members
# ['10407205', 'Days of Our Lives cast members']
# Processing file... 10410626
# John Adams
# ['10410626', 'John Adams']
# Processing file... 1041577
# Mark Henry
# ['1041577', 'Mark Henry']
# Processing file... 10419775
# Surana, Haryana
# ['10419775', 'Surana, Haryana']
# Processing file... 10422721
# Pacific Northwest tree octopus
# ['10422721', 'Pacific Northwest tree octopus']
# Processing file... 10442845
# Travel website
# ['10442845', 'Travel website']
# Processing file... 104444
# Dietary supplement
# ['104444', 'Dietary supplement']
# Processing file... 10445381
# Calvin Goddard (ballistics)
# ['10445381', 'Calvin Goddard (ballistics)']
# Processing file... 10449970
# List of TriStar Pictures films
# ['10449970', 'List of TriStar Pictures films']
# Processing file... 10468424
# Blah
# ['10468424', 'Blah']
# Processing file... 1047310
# Crosspool
# ['1047310', 'Crosspool']
# Processing file... 1047835
# Way of the Dragon
# ['1047835', 'Way of the Dragon']
# Processing file... 1047970
# Avenged Sevenfold
# ['1047970', 'Avenged Sevenfold']
# Processing file... 10483209
# Skilled Group
# ['10483209', 'Skilled Group']
# Processing file... 10485669
# Claire Holt
# ['10485669', 'Claire Holt']
# Processing file... 10494172
# Russell Kane
# ['10494172', 'Russell Kane']
# Processing file... 1050479
# BloodRayne 2
# ['1050479', 'BloodRayne 2']
# Processing file... 10509730
# Alec Butler
# ['10509730', 'Alec Butler']
# Processing file... 10515516
# Pooja Gandhi
# ['10515516', 'Pooja Gandhi']
# Processing file... 105219
# Cancer
# ['105219', 'Cancer']
# Processing file... 105390
# Pheromone
# ['105390', 'Pheromone']
# Processing file... 1056193
# Wendy Williams
# ['1056193', 'Wendy Williams']
# Processing file... 1056208
# Jure Francetić
# ['1056208', 'Jure Francetić']
# Processing file... 1056214
# Ljubo Miloš
# ['1056214', 'Ljubo Miloš']
# Processing file... 10567534
# Blake Griffin
# ['10567534', 'Blake Griffin']
# Processing file... 10568
# Association football
# ['10568', 'Association football']
# Processing file... 1057414
# Traumatic brain injury
# ['1057414', 'Traumatic brain injury']
# Processing file... 10579795
# Olga Fedori
# ['10579795', 'Olga Fedori']
# Processing file... 1058843
# Loge
# ['1058843', 'Loge']
# Processing file... 105922
# King David Hotel bombing
# ['105922', 'King David Hotel bombing']
# Processing file... 10595985
# Phil Nibbelink
# ['10595985', 'Phil Nibbelink']
# Processing file... 1059962
# KVIE
# ['1059962', 'KVIE']
# Processing file... 10605960
# Non-penetrative sex
# ['10605960', 'Non-penetrative sex']
# Processing file... 1061021
# List of secret police organizations
# ['1061021', 'List of secret police organizations']
# Processing file... 10624594
# Krypton
# ['10624594', 'Krypton']
# Processing file... 10636232
# The Pussycat Dolls
# ['10636232', 'The Pussycat Dolls']
# Processing file... 10646
# Food
# ['10646', 'Food']
# Processing file... 1066018
# Philip J. Kaplan
# ['1066018', 'Philip J. Kaplan']
# Processing file... 10667484
# Ilion Animation Studios
# ['10667484', 'Ilion Animation Studios']
# Processing file... 1068143
# The Young Turks
# ['1068143', 'The Young Turks']
# Processing file... 10682197
# List of Waterloo Road characters
# ['10682197', 'List of Waterloo Road characters']
# Processing file... 10693894
# Suicide Silence
# ['10693894', 'Suicide Silence']
# Processing file... 1070152
# Mugger crocodile
# ['1070152', 'Mugger crocodile']
# Processing file... 10711867
# Signal Mountain Middle High School
# ['10711867', 'Signal Mountain Middle High School']
# Processing file... 10721157
# Shirley Phelps-Roper
# ['10721157', 'Shirley Phelps-Roper']
# Processing file... 1075887
# John Key
# ['1075887', 'John Key']
# Processing file... 10771083
# Phan Đình Phùng
# ['10771083', 'Phan Đình Phùng']
# Processing file... 1077137
# 9/11 conspiracy theories
# ['1077137', '9/11 conspiracy theories']
# Processing file... 10772350
# History
# ['10772350', 'History']
# Processing file... 1078
# Antisemitism
# ['1078', 'Antisemitism']
# Processing file... 1078003
# Herbert Sandler
# ['1078003', 'Herbert Sandler']
# Processing file... 1078340
# Immortal Technique
# ['1078340', 'Immortal Technique']
# Processing file... 1079866
# Mantle (geology)
# ['1079866', 'Mantle (geology)']
# Processing file... 1081183
# Andrew Bolt
# ['1081183', 'Andrew Bolt']
# Processing file... 10816091
# BloodRayne (franchise)
# ['10816091', 'BloodRayne (franchise)']
# Processing file... 1081624
# Rise Against
# ['1081624', 'Rise Against']
# Processing file... 1082198
# Nicky Cruz
# ['1082198', 'Nicky Cruz']
# Processing file... 10823
# Frédéric Chopin
# ['10823', 'Frédéric Chopin']
# Processing file... 1082583
# Interstate Highways in Alaska
# ['1082583', 'Interstate Highways in Alaska']
# Processing file... 10841641
# Antonio Arnaiz-Villena
# ['10841641', 'Antonio Arnaiz-Villena']
# Processing file... 10843
# Fruit
# ['10843', 'Fruit']
# Processing file... 1084540
# Ian Somerhalder
# ['1084540', 'Ian Somerhalder']
# Processing file... 10851639
# List of male performers in gay porn films
# ['10851639', 'List of male performers in gay porn films']
# Processing file... 10884089
# List of The New Adventures of Winnie the Pooh episodes
# ['10884089', 'List of The New Adventures of Winnie the Pooh episodes']
# Processing file... 10891776
# Call of Duty 4: Modern Warfare
# ['10891776', 'Call of Duty 4: Modern Warfare']
# Processing file... 108956
# Washington, D.C.
# ['108956', 'Washington, D.C.']
# Processing file... 10906185
# Gurjar
# ['10906185', 'Gurjar']
# Processing file... 109179
# Bell, Florida
# ['109179', 'Bell, Florida']
# Processing file... 10919134
# Jozy Altidore
# ['10919134', 'Jozy Altidore']
# Processing file... 1092923
# Google
# ['1092923', 'Google']
# Processing file... 10951
# Fahrenheit 451
# ['10951', 'Fahrenheit 451']
# Processing file... 1095706
# Jesus
# ['1095706', 'Jesus']
# Processing file... 10958
# Fossil
# ['10958', 'Fossil']
# Processing file... 10960729
# Mike Harper
# ['10960729', 'Mike Harper']
# Processing file... 10964586
# Tottington High School
# ['10964586', 'Tottington High School']
# Processing file... 10972664
# Young Money Entertainment
# ['10972664', 'Young Money Entertainment']
# Processing file... 10979
# Franklin D. Roosevelt
# ['10979', 'Franklin D. Roosevelt']
# Processing file... 1098645
# Djedefre
# ['1098645', 'Djedefre']
# Processing file... 10999148
# Pierce the Veil
# ['10999148', 'Pierce the Veil']
# Processing file... 1100953
# Khachkar
# ['1100953', 'Khachkar']
# Processing file... 1101067
# KAPAP
# ['1101067', 'KAPAP']
# Processing file... 11014515
# List of ethnic slurs
# ['11014515', 'List of ethnic slurs']
# Processing file... 11015252
# Vladimir Lenin
# ['11015252', 'Vladimir Lenin']
# Processing file... 1102136
# Sambandar
# ['1102136', 'Sambandar']
# Processing file... 1102585
# New Brunswick general election, 1987
# ['1102585', 'New Brunswick general election, 1987']
# Processing file... 11026242
# Traumatic insemination
# ['11026242', 'Traumatic insemination']
# Processing file... 11030872
# God Made Me Funky
# ['11030872', 'God Made Me Funky']
# Processing file... 11033
# Frederick Douglass
# ['11033', 'Frederick Douglass']
# Processing file... 11038318
# Methamphetamine
# ['11038318', 'Methamphetamine']
# Processing file... 1103839
# List of Freemasons
# ['1103839', 'List of Freemasons']
# Processing file... 11039790
# Animal
# ['11039790', 'Animal']
# Processing file... 1104035
# Boob
# ['1104035', 'Boob']
# Processing file... 11042
# Fat
# ['11042', 'Fat']
# Processing file... 1104310
# James L. Dolan
# ['1104310', 'James L. Dolan']
# Processing file... 11044005
# Satellite Spies
# ['11044005', 'Satellite Spies']
# Processing file... 1105029
# Nair
# ['1105029', 'Nair']
# Processing file... 11053801
# Maz Jobrani
# ['11053801', 'Maz Jobrani']
# Processing file... 11054586
# North View Secondary School
# ['11054586', 'North View Secondary School']
# Processing file... 1105480
# Mushroomhead
# ['1105480', 'Mushroomhead']
# Processing file... 11058016
# Mohammad Asghar
# ['11058016', 'Mohammad Asghar']
# Processing file... 11059
# Five Pillars of Islam
# ['11059', 'Five Pillars of Islam']
# Processing file... 11059398
# Adult diaper
# ['11059398', 'Adult diaper']
# Processing file... 1106026
# Beth Ostrosky Stern
# ['1106026', 'Beth Ostrosky Stern']
# Processing file... 11062
# Friction
# ['11062', 'Friction']
# Processing file... 11069849
# Disappearance of Madeleine McCann
# ['11069849', 'Disappearance of Madeleine McCann']
# Processing file... 11079079
# Mongolian barbecue
# ['11079079', 'Mongolian barbecue']
# Processing file... 1108159
# Carcharodontosaurus
# ['1108159', 'Carcharodontosaurus']
# Processing file... 11089416
# Test
# ['11089416', 'Test']
# Processing file... 1109104
# Ray Comfort
# ['1109104', 'Ray Comfort']
# Processing file... 11091078
# Dragon Ball
# ['11091078', 'Dragon Ball']
# Processing file... 1109945
# Turkish Naval Forces
# ['1109945', 'Turkish Naval Forces']
# Processing file... 11100573
# Nguyen Tu Quang
# ['11100573', 'Nguyen Tu Quang']
# Processing file... 11115779
# George Runner
# ['11115779', 'George Runner']
# Processing file... 11121
# Fox News Channel
# ['11121', 'Fox News Channel']
# Processing file... 11123648
# Canterbury University (Seychelles)
# ['11123648', 'Canterbury University (Seychelles)']
# Processing file... 11125639
# Turkey
# ['11125639', 'Turkey']
# Processing file... 11127
# Federal Bureau of Investigation
# ['11127', 'Federal Bureau of Investigation']
# Processing file... 11137057
# BlueWare
# ['11137057', 'BlueWare']
# Processing file... 1113854
# .ru
# ['1113854', '.ru']
# Processing file... 11145
# Fire
# ['11145', 'Fire']
# Processing file... 1114570
# John O'Shea
# ['1114570', "John O'Shea"]
# Processing file... 11146900
# Barney in Outer Space
# ['11146900', 'Barney in Outer Space']
# Processing file... 1114732
# Palestine (region)
# ['1114732', 'Palestine (region)']
# Processing file... 1116006
# Histeria!
# ['1116006', 'Histeria!']
# Processing file... 1116229
# Genesis creation narrative
# ['1116229', 'Genesis creation narrative']
# Processing file... 1116804
# Guard dog
# ['1116804', 'Guard dog']
# Processing file... 1117328
# Pickaxe
# ['1117328', 'Pickaxe']
# Processing file... 11177519
# Bajót
# ['11177519', 'Bajót']
# Processing file... 1117939
# Fernando Torres
# ['1117939', 'Fernando Torres']
# Processing file... 1118379
# Online shopping
# ['1118379', 'Online shopping']
# Processing file... 11185
# Feminism
# ['11185', 'Feminism']
# Processing file... 11185534
# Babu Antony
# ['11185534', 'Babu Antony']
# Processing file... 11188
# French Revolution
# ['11188', 'French Revolution']
# Processing file... 1118915
# Sheeple
# ['1118915', 'Sheeple']
# Processing file... 1119701
# Physical medicine and rehabilitation
# ['1119701', 'Physical medicine and rehabilitation']
# Processing file... 11206371
# List of Animals of Farthing Wood characters
# ['11206371', 'List of Animals of Farthing Wood characters']
# Processing file... 11217925
# Paris Hilton
# ['11217925', 'Paris Hilton']
# Processing file... 11223317
# Prince Devitt
# ['11223317', 'Prince Devitt']
# Processing file... 11223633
# Aiglon College
# ['11223633', 'Aiglon College']
# Processing file... 11227
# Freemasonry
# ['11227', 'Freemasonry']
# Processing file... 112274
# The Blitz
# ['112274', 'The Blitz']
# Processing file... 1123327
# 1998 San Marino Grand Prix
# ['1123327', '1998 San Marino Grand Prix']
# Processing file... 1123369
# Historiography of the fall of the Western Roman Empire
# ['1123369', 'Historiography of the fall of the Western Roman Empire']
# Processing file... 11236
# Fart
# ['11236', 'Fart']
# Processing file... 11237896
# Kalya
# ['11237896', 'Kalya']
# Processing file... 11240
# Flatulence
# ['11240', 'Flatulence']
# Processing file... 11247682
# The Devil Wears Prada (band)
# ['11247682', 'The Devil Wears Prada (band)']
# Processing file... 11250
# Premier League
# ['11250', 'Premier League']
# Processing file... 11258
# Fellatio
# ['11258', 'Fellatio']
# Processing file... 11260
# Relax (song)
# ['11260', 'Relax (song)']
# Processing file... 11260577
# Ann Romney
# ['11260577', 'Ann Romney']
# Processing file... 11263766
# Diary of a Wimpy Kid
# ['11263766', 'Diary of a Wimpy Kid']
# Processing file... 1126490
# Yard of ale
# ['1126490', 'Yard of ale']
# Processing file... 1126578
# Ciara
# ['1126578', 'Ciara']
# Processing file... 1127442
# Mohammed Burhanuddin
# ['1127442', 'Mohammed Burhanuddin']
# Processing file... 11276293
# Gargamel
# ['11276293', 'Gargamel']
# Processing file... 11286472
# Renee Alway
# ['11286472', 'Renee Alway']
# Processing file... 11288250
# Martin Hirsch
# ['11288250', 'Martin Hirsch']
# Processing file... 11291
# Floccinaucinihilipilification
# ['11291', 'Floccinaucinihilipilification']
# Processing file... 1129182
# Leonardo Araújo
# ['1129182', 'Leonardo Araújo']
# Processing file... 1129697
# Paper plane
# ['1129697', 'Paper plane']
# Processing file... 11299
# Fox
# ['11299', 'Fox']
# Processing file... 1130104
# New Brunswick general election, 1982
# ['1130104', 'New Brunswick general election, 1982']
# Processing file... 113055
# Temperament
# ['113055', 'Temperament']
# Processing file... 1130636
# Master Chief (Halo)
# ['1130636', 'Master Chief (Halo)']
# Processing file... 11315
# Friends
# ['11315', 'Friends']
# Processing file... 113180
# Pussy
# ['113180', 'Pussy']
# Processing file... 11330163
# List of dubstep musicians
# ['11330163', 'List of dubstep musicians']
# Processing file... 11345507
# List of Tak and the Power of Juju episodes
# ['11345507', 'List of Tak and the Power of Juju episodes']
# Processing file... 11347320
# Saint Thomas More High School (Milwaukee)
# ['11347320', 'Saint Thomas More High School (Milwaukee)']
# Processing file... 113525
# Dick
# ['113525', 'Dick']
# Processing file... 11366634
# Katie Hopkins
# ['11366634', 'Katie Hopkins']
# Processing file... 1136832
# Duran Duran discography
# ['1136832', 'Duran Duran discography']
# Processing file... 11370
# FIFA World Cup
# ['11370', 'FIFA World Cup']
# Processing file... 11371144
# WRFF
# ['11371144', 'WRFF']
# Processing file... 113728
# Geothermal energy
# ['113728', 'Geothermal energy']
# Processing file... 113746
# Sean Penn
# ['113746', 'Sean Penn']
# Processing file... 11392263
# Sacramento County Jail
# ['11392263', 'Sacramento County Jail']
# Processing file... 11403316
# Compressed sensing
# ['11403316', 'Compressed sensing']
# Processing file... 11408
# Female genital mutilation
# ['11408', 'Female genital mutilation']
# Processing file... 11411461
# Ola Toivonen
# ['11411461', 'Ola Toivonen']
# Processing file... 1141314
# California Miramar University
# ['1141314', 'California Miramar University']
# Processing file... 1141494
# Salif Diao
# ['1141494', 'Salif Diao']
# Processing file... 11415141
# Masturbation
# ['11415141', 'Masturbation']
# Processing file... 1142195
# Onogurs
# ['1142195', 'Onogurs']
# Processing file... 1143036
# Chelmsley Wood
# ['1143036', 'Chelmsley Wood']
# Processing file... 1143659
# Ruby Bridges
# ['1143659', 'Ruby Bridges']
# Processing file... 1143923
# Honolulu University
# ['1143923', 'Honolulu University']
# Processing file... 11447
# Flag of the United States
# ['11447', 'Flag of the United States']
# Processing file... 11461
# Francis Crick
# ['11461', 'Francis Crick']
# Processing file... 11470826
# Jake T. Austin
# ['11470826', 'Jake T. Austin']
# Processing file... 11473533
# Adam and Eve
# ['11473533', 'Adam and Eve']
# Processing file... 11481790
# Nancy Grace
# ['11481790', 'Nancy Grace']
# Processing file... 11485528
# Dan O'Halloran
# ['11485528', "Dan O'Halloran"]
# Processing file... 11492
# Foot
# ['11492', 'Foot']
# Processing file... 11495370
# Pershing Map
# ['11495370', 'Pershing Map']
# Processing file... 11504
# Fandom
# ['11504', 'Fandom']
# Processing file... 1150748
# Bhagat Singh
# ['1150748', 'Bhagat Singh']
# Processing file... 11508
# Francis Drake
# ['11508', 'Francis Drake']
# Processing file... 11511282
# YouPorn
# ['11511282', 'YouPorn']
# Processing file... 11521084
# Cassandra Clare
# ['11521084', 'Cassandra Clare']
# Processing file... 11546879
# Google Street View
# ['11546879', 'Google Street View']
# Processing file... 11548323
# List of gay, lesbian or bisexual people: C
# ['11548323', 'List of gay, lesbian or bisexual people: C']
# Processing file... 11554502
# Lester Coleman
# ['11554502', 'Lester Coleman']
# Processing file... 11556927
# Mediacorp HD5
# ['11556927', 'Mediacorp HD5']
# Processing file... 11557106
# Batman in film
# ['11557106', 'Batman in film']
# Processing file... 11567096
# Murdoch Mysteries
# ['11567096', 'Murdoch Mysteries']
# Processing file... 11567670
# List of The Cosby Show characters
# ['11567670', 'List of The Cosby Show characters']
# Processing file... 1157014
# Pauly Shore
# ['1157014', 'Pauly Shore']
# Processing file... 11578887
# General Hospital cast members
# ['11578887', 'General Hospital cast members']
# Processing file... 1157910
# Jimmy Conrad
# ['1157910', 'Jimmy Conrad']
# Processing file... 11593017
# Burn Notice
# ['11593017', 'Burn Notice']
# Processing file... 1160865
# Samy Vellu
# ['1160865', 'Samy Vellu']
# Processing file... 11619883
# Blumpkin
# ['11619883', 'Blumpkin']
# Processing file... 1162481
# Modi'in Illit
# ['1162481', "Modi'in Illit"]
# Processing file... 1162486
# Giv'at Ze'ev
# ['1162486', "Giv'at Ze'ev"]
# Processing file... 11631288
# Abilene High School (Texas)
# ['11631288', 'Abilene High School (Texas)']
# Processing file... 11638
# Francis of Assisi
# ['11638', 'Francis of Assisi']
# Processing file... 1164274
# Claremont Graduate University
# ['1164274', 'Claremont Graduate University']
# Processing file... 11650319
# Xiaxue
# ['11650319', 'Xiaxue']
# Processing file... 11663591
# The Contractor (2007 film)
# ['11663591', 'The Contractor (2007 film)']
# Processing file... 11665
# Filtration
# ['11665', 'Filtration']
# Processing file... 1168295
# Merneptah
# ['1168295', 'Merneptah']
# Processing file... 11700559
# List of scientists opposing the mainstream scientific assessment of global warming
# ['11700559', 'List of scientists opposing the mainstream scientific assessment of global warming']
# Processing file... 11712287
# Riaz Ahmed Gohar Shahi
# ['11712287', 'Riaz Ahmed Gohar Shahi']
# Processing file... 1172299
# Damon Dash
# ['1172299', 'Damon Dash']
# Processing file... 1174
# Aphrodite
# ['1174', 'Aphrodite']
# Processing file... 1174295
# Civil Disobedience (Thoreau)
# ['1174295', 'Civil Disobedience (Thoreau)']
# Processing file... 11747574
# Nicole Alexander
# ['11747574', 'Nicole Alexander']
# Processing file... 1174943
# David Hager
# ['1174943', 'David Hager']
# Processing file... 11749910
# Cheese
# ['11749910', 'Cheese']
# Processing file... 1175987
# List of Nobel laureates
# ['1175987', 'List of Nobel laureates']
# Processing file... 11766333
# Online quiz
# ['11766333', 'Online quiz']
# Processing file... 11768984
# Surveen Chawla
# ['11768984', 'Surveen Chawla']
# Processing file... 11776556
# Ripe Digital Entertainment
# ['11776556', 'Ripe Digital Entertainment']
# Processing file... 11778948
# Atomic bombings of Hiroshima and Nagasaki
# ['11778948', 'Atomic bombings of Hiroshima and Nagasaki']
# Processing file... 1178
# Afterlife
# ['1178', 'Afterlife']
# Processing file... 11805756
# Greg Plitt
# ['11805756', 'Greg Plitt']
# Processing file... 11808592
# México en la Piel (album)
# ['11808592', 'México en la Piel (album)']
# Processing file... 1181010
# Logan Lerman
# ['1181010', 'Logan Lerman']
# Processing file... 1181487
# Halo 3
# ['1181487', 'Halo 3']
# Processing file... 11815465
# List of Who Wants to Be a Millionaire? top prize winners
# ['11815465', 'List of Who Wants to Be a Millionaire? top prize winners']
# Processing file... 1181646
# War on Drugs
# ['1181646', 'War on Drugs']
# Processing file... 1181663
# Comic book collecting
# ['1181663', 'Comic book collecting']
# Processing file... 11824669
# Amit Singhal
# ['11824669', 'Amit Singhal']
# Processing file... 11826154
# Wang Leehom
# ['11826154', 'Wang Leehom']
# Processing file... 11835861
# Yucaipa High School
# ['11835861', 'Yucaipa High School']
# Processing file... 11846
# Guitar
# ['11846', 'Guitar']
# Processing file... 11850610
# Jeffree Star
# ['11850610', 'Jeffree Star']
# Processing file... 1185646
# Mentuhotep II
# ['1185646', 'Mentuhotep II']
# Processing file... 11857
# George Lucas
# ['11857', 'George Lucas']
# Processing file... 1186115
# Islam in India
# ['1186115', 'Islam in India']
# Processing file... 11862690
# Juno (film)
# ['11862690', 'Juno (film)']
# Processing file... 11867
# Germany
# ['11867', 'Germany']
# Processing file... 11876731
# The Mystery of the Druids
# ['11876731', 'The Mystery of the Druids']
# Processing file... 1187948
# Gary Paulsen
# ['1187948', 'Gary Paulsen']
# Processing file... 11889949
# Rob Dyrdek
# ['11889949', 'Rob Dyrdek']
# Processing file... 1189614
# The Perfect Score
# ['1189614', 'The Perfect Score']
# Processing file... 1190582
# George Gollin
# ['1190582', 'George Gollin']
# Processing file... 11914121
# Rand Paul
# ['11914121', 'Rand Paul']
# Processing file... 1191676
# Geert Wilders
# ['1191676', 'Geert Wilders']
# Processing file... 11921
# Gambling
# ['11921', 'Gambling']
# Processing file... 11926916
# Portland Pride
# ['11926916', 'Portland Pride']
# Processing file... 11932269
# List of management consulting firms
# ['11932269', 'List of management consulting firms']
# Processing file... 11933433
# Daniel A. McGowan
# ['11933433', 'Daniel A. McGowan']
# Processing file... 1193390
# The Order (2001 film)
# ['1193390', 'The Order (2001 film)']
# Processing file... 1195328
# Erotic asphyxiation
# ['1195328', 'Erotic asphyxiation']
# Processing file... 11955
# George H. W. Bush
# ['11955', 'George H. W. Bush']
# Processing file... 1195649
# Michael Klonsky
# ['1195649', 'Michael Klonsky']
# Processing file... 11968
# George Washington
# ['11968', 'George Washington']
# Processing file... 1197010
# Hwang Jang-lee
# ['1197010', 'Hwang Jang-lee']
# Processing file... 1197173
# Joe Pasquale
# ['1197173', 'Joe Pasquale']
# Processing file... 11973
# Generation X
# ['11973', 'Generation X']
# Processing file... 11976936
# Numpty
# ['11976936', 'Numpty']
# Processing file... 11985
# Graffiti
# ['11985', 'Graffiti']
# Processing file... 11986
# Godzilla
# ['11986', 'Godzilla']
# Processing file... 1199328
# English Mastiff
# ['1199328', 'English Mastiff']
# Processing file... 11996885
# Electronic cigarette
# ['11996885', 'Electronic cigarette']
# Processing file... 1200987
# Afghanistan national football team
# ['1200987', 'Afghanistan national football team']
# Processing file... 1203316
# Fred Trump
# ['1203316', 'Fred Trump']
# Processing file... 12035677
# Ahnenpass
# ['12035677', 'Ahnenpass']
# Processing file... 1204033
# Astrid Muñoz
# ['1204033', 'Astrid Muñoz']
# Processing file... 1204377
# MapleStory
# ['1204377', 'MapleStory']
# Processing file... 1204559
# Jewish Voice for Peace
# ['1204559', 'Jewish Voice for Peace']
# Processing file... 1204666
# Cuteness
# ['1204666', 'Cuteness']
# Processing file... 1205872
# Halo (series)
# ['1205872', 'Halo (series)']
# Processing file... 1206861
# Wack Pack
# ['1206861', 'Wack Pack']
# Processing file... 12069270
# A Day in the Park with Barney
# ['12069270', 'A Day in the Park with Barney']
# Processing file... 12079268
# List of Kannada-language poets
# ['12079268', 'List of Kannada-language poets']
# Processing file... 12082612
# Jennings Dog
# ['12082612', 'Jennings Dog']
# Processing file... 12089954
# Wherever We May Roam Tour
# ['12089954', 'Wherever We May Roam Tour']
# Processing file... 1209075
# Melania Trump
# ['1209075', 'Melania Trump']
# Processing file... 12107644
# Owned-and-operated television stations in the United States
# ['12107644', 'Owned-and-operated television stations in the United States']
# Processing file... 12108
# Greece
# ['12108', 'Greece']
# Processing file... 12115130
# List of programmes broadcast by Mediacorp HD5
# ['12115130', 'List of programmes broadcast by Mediacorp HD5']
# Processing file... 12120000
# 27 Club
# ['12120000', '27 Club']
# Processing file... 1212256
# Homeward Bound: The Incredible Journey
# ['1212256', 'Homeward Bound: The Incredible Journey']
# Processing file... 12137890
# Human penis
# ['12137890', 'Human penis']
# Processing file... 12153654
# Elizabeth II
# ['12153654', 'Elizabeth II']
# Processing file... 12155332
# Pioneer Court
# ['12155332', 'Pioneer Court']
# Processing file... 12156241
# Guns N' Roses/Metallica Stadium Tour
# ['12156241', "Guns N' Roses/Metallica Stadium Tour"]
# Processing file... 1216855
# Puerto Rican Campaign
# ['1216855', 'Puerto Rican Campaign']
# Processing file... 12174108
# Jérôme Boateng
# ['12174108', 'Jérôme Boateng']
# Processing file... 12176866
# List of The Wiggles episodes
# ['12176866', 'List of The Wiggles episodes']
# Processing file... 1218122
# Shaun White
# ['1218122', 'Shaun White']
# Processing file... 1220214
# American lion
# ['1220214', 'American lion']
# Processing file... 12209728
# Thom Loverro
# ['12209728', 'Thom Loverro']
# Processing file... 1221227
# The Mountain Goats
# ['1221227', 'The Mountain Goats']
# Processing file... 1221420
# William Greer
# ['1221420', 'William Greer']
# Processing file... 1221476
# Chris Hemsworth
# ['1221476', 'Chris Hemsworth']
# Processing file... 12218249
# Wellington Point State High School
# ['12218249', 'Wellington Point State High School']
# Processing file... 12224
# Great Pyramid of Giza
# ['12224', 'Great Pyramid of Giza']
# Processing file... 12237784
# List of YouTubers
# ['12237784', 'List of YouTubers']
# Processing file... 12240
# Gold
# ['12240', 'Gold']
# Processing file... 12241
# Gallium
# ['12241', 'Gallium']
# Processing file... 12254052
# Smoking
# ['12254052', 'Smoking']
# Processing file... 12255
# G
# ['12255', 'G']
# Processing file... 12257
# Gamma
# ['12257', 'Gamma']
# Processing file... 1226109
# Wayne LaPierre
# ['1226109', 'Wayne LaPierre']
# Processing file... 12274
# Guy de Maupassant
# ['12274', 'Guy de Maupassant']
# Processing file... 12280293
# Law practice management software
# ['12280293', 'Law practice management software']
# Processing file... 1229373
# Maki (political party)
# ['1229373', 'Maki (political party)']
# Processing file... 1229550
# Olympiacos F.C.
# ['1229550', 'Olympiacos F.C.']
# Processing file... 12296559
# Dana Ullman
# ['12296559', 'Dana Ullman']
# Processing file... 12304499
# Code2000
# ['12304499', 'Code2000']
# Processing file... 12305742
# Shahidul Islam
# ['12305742', 'Shahidul Islam']
# Processing file... 12310814
# Carly Rae Jepsen
# ['12310814', 'Carly Rae Jepsen']
# Processing file... 1232575
# Suicide methods
# ['1232575', 'Suicide methods']
# Processing file... 12330092
# Girls' Generation
# ['12330092', "Girls' Generation"]
# Processing file... 1233146
# Shamrock Rovers F.C.
# ['1233146', 'Shamrock Rovers F.C.']
# Processing file... 12333673
# Stuart Howe
# ['12333673', 'Stuart Howe']
# Processing file... 12336
# Gladiator
# ['12336', 'Gladiator']
# Processing file... 12339
# Genetically modified organism
# ['12339', 'Genetically modified organism']
# Processing file... 12339704
# For The Win (Internet slang)
# ['12339704', 'For The Win (Internet slang)']
# Processing file... 12345059
# Maan Al-Sanea
# ['12345059', 'Maan Al-Sanea']
# Processing file... 12346158
# Smosh
# ['12346158', 'Smosh']
# Processing file... 12350316
# Tim Donaghy
# ['12350316', 'Tim Donaghy']
# Processing file... 1236087
# Qutb Shahi dynasty
# ['1236087', 'Qutb Shahi dynasty']
# Processing file... 1236320
# Jenna Haze
# ['1236320', 'Jenna Haze']
# Processing file... 12379529
# Srbosjek
# ['12379529', 'Srbosjek']
# Processing file... 12384
# Gettysburg Address
# ['12384', 'Gettysburg Address']
# Processing file... 1238462
# Jamaica Defence Force
# ['1238462', 'Jamaica Defence Force']
# Processing file... 12386
# Golden ratio
# ['12386', 'Golden ratio']
# Processing file... 12395
# Greenhouse effect
# ['12395', 'Greenhouse effect']
# Processing file... 1239591
# Edit
# ['1239591', 'Edit']
# Processing file... 1241274
# Ramesses VI
# ['1241274', 'Ramesses VI']
# Processing file... 1241280
# Ramesses VII
# ['1241280', 'Ramesses VII']
# Processing file... 12414587
# Camp Rock
# ['12414587', 'Camp Rock']
# Processing file... 12420911
# Saima Noor
# ['12420911', 'Saima Noor']
# Processing file... 1243134
# Bioidentical hormone replacement therapy
# ['1243134', 'Bioidentical hormone replacement therapy']
# Processing file... 12436
# Grape
# ['12436', 'Grape']
# Processing file... 12438675
# Jenny Brockie
# ['12438675', 'Jenny Brockie']
# Processing file... 12446
# Germanic peoples
# ['12446', 'Germanic peoples']
# Processing file... 1245311
# Finasteride
# ['1245311', 'Finasteride']
# Processing file... 12460
# Green
# ['12460', 'Green']
# Processing file... 1246649
# Stephen Hillenburg
# ['1246649', 'Stephen Hillenburg']
# Processing file... 1247225
# Peter Stollery
# ['1247225', 'Peter Stollery']
# Processing file... 12474403
# Climate change denial
# ['12474403', 'Climate change denial']
# Processing file... 12482493
# J.C. Intal
# ['12482493', 'J.C. Intal']
# Processing file... 1248557
# Bianca Jagger
# ['1248557', 'Bianca Jagger']
# Processing file... 12495
# Grover Cleveland
# ['12495', 'Grover Cleveland']
# Processing file... 12497236
# Fazura
# ['12497236', 'Fazura']
# Processing file... 12499554
# Soulja Boy
# ['12499554', 'Soulja Boy']
# Processing file... 1250419
# Cummingtonite
# ['1250419', 'Cummingtonite']
# Processing file... 1251041
# Michael Wong (actor)
# ['1251041', 'Michael Wong (actor)']
# Processing file... 1251635
# Graceland University
# ['1251635', 'Graceland University']
# Processing file... 12520860
# Demi Lovato
# ['12520860', 'Demi Lovato']
# Processing file... 12523627
# List of awards and nominations received by Justin Timberlake
# ['12523627', 'List of awards and nominations received by Justin Timberlake']
# Processing file... 12523803
# List of reggaeton musicians
# ['12523803', 'List of reggaeton musicians']
# Processing file... 125248
# Charles, Prince of Wales
# ['125248', 'Charles, Prince of Wales']
# Processing file... 125279
# List of metropolitan areas by population
# ['125279', 'List of metropolitan areas by population']
# Processing file... 125293
# Copper
# ['125293', 'Copper']
# Processing file... 1253516
# Booty
# ['1253516', 'Booty']
# Processing file... 12545190
# List of Turkish Americans
# ['12545190', 'List of Turkish Americans']
# Processing file... 12546
# Gorilla
# ['12546', 'Gorilla']
# Processing file... 12554531
# List of gay, lesbian or bisexual people: Ba–Bh
# ['12554531', 'List of gay, lesbian or bisexual people: Ba–Bh']
# Processing file... 1255986
# Hamilton University
# ['1255986', 'Hamilton University']
# Processing file... 12561015
# 4chan
# ['12561015', '4chan']
# Processing file... 12562
# Gregor Mendel
# ['12562', 'Gregor Mendel']
# Processing file... 12581
# Glass
# ['12581', 'Glass']
# Processing file... 12582331
# Timeline of Crayola
# ['12582331', 'Timeline of Crayola']
# Processing file... 1258292
# Rick Aviles
# ['1258292', 'Rick Aviles']
# Processing file... 1259693
# Camel toe
# ['1259693', 'Camel toe']
# Processing file... 12605712
# Banahaw Broadcasting Corporation
# ['12605712', 'Banahaw Broadcasting Corporation']
# Processing file... 12610483
# Android (operating system)
# ['12610483', 'Android (operating system)']
# Processing file... 12612514
# Miley Cyrus discography
# ['12612514', 'Miley Cyrus discography']
# Processing file... 1263046
# Clipping path
# ['1263046', 'Clipping path']
# Processing file... 1263467
# The North Face
# ['1263467', 'The North Face']
# Processing file... 12635211
# Biggest Loser Jeetega
# ['12635211', 'Biggest Loser Jeetega']
# Processing file... 12638427
# Koorawatha
# ['12638427', 'Koorawatha']
# Processing file... 1264636
# Al McDonald
# ['1264636', 'Al McDonald']
# Processing file... 12655104
# Superior High School (Montana)
# ['12655104', 'Superior High School (Montana)']
# Processing file... 12663
# Green Bay Packers
# ['12663', 'Green Bay Packers']
# Processing file... 12677898
# Terms for Syriac Christians
# ['12677898', 'Terms for Syriac Christians']
# Processing file... 12678767
# The Land Before Time XIII: The Wisdom of Friends
# ['12678767', 'The Land Before Time XIII: The Wisdom of Friends']
# Processing file... 1268027
# Maximus Inc.
# ['1268027', 'Maximus Inc.']
# Processing file... 12684530
# Jennifer Lawrence
# ['12684530', 'Jennifer Lawrence']
# Processing file... 1269138
# Street Fighter (1994 film)
# ['1269138', 'Street Fighter (1994 film)']
# Processing file... 12701
# Greenwich Mean Time
# ['12701', 'Greenwich Mean Time']
# Processing file... 1270649
# Mike Lupica
# ['1270649', 'Mike Lupica']
# Processing file... 12707
# Guy Fawkes
# ['12707', 'Guy Fawkes']
# Processing file... 12713
# Giant panda
# ['12713', 'Giant panda']
# Processing file... 12714038
# Edward Bodkin
# ['12714038', 'Edward Bodkin']
# Processing file... 12717
# Giraffe
# ['12717', 'Giraffe']
# Processing file... 1272002
# Pool (cue sports)
# ['1272002', 'Pool (cue sports)']
# Processing file... 12729700
# Ranvir Shorey
# ['12729700', 'Ranvir Shorey']
# Processing file... 1273
# Augustus
# ['1273', 'Augustus']
# Processing file... 1273220
# Killer Instinct 2
# ['1273220', 'Killer Instinct 2']
# Processing file... 1274780
# Emu War
# ['1274780', 'Emu War']
# Processing file... 127575
# New Rochelle, New York
# ['127575', 'New Rochelle, New York']
# Processing file... 12759502
# List of gay, lesbian or bisexual people: W–Z
# ['12759502', 'List of gay, lesbian or bisexual people: W–Z']
# Processing file... 1277918
# Charlie and the Chocolate Factory (film)
# ['1277918', 'Charlie and the Chocolate Factory (film)']
# Processing file... 12787
# Geoffrey Chaucer
# ['12787', 'Geoffrey Chaucer']
# Processing file... 1279880
# Rationing in the United Kingdom
# ['1279880', 'Rationing in the United Kingdom']
# Processing file... 12799449
# Debate on traditional and simplified Chinese characters
# ['12799449', 'Debate on traditional and simplified Chinese characters']
# Processing file... 12804
# Grigori Rasputin
# ['12804', 'Grigori Rasputin']
# Processing file... 12818656
# Shiner (band)
# ['12818656', 'Shiner (band)']
# Processing file... 12820978
# The Real World: Hollywood
# ['12820978', 'The Real World: Hollywood']
# Processing file... 1282180
# Barelvi
# ['1282180', 'Barelvi']
# Processing file... 12830243
# Battle of Chamkaur (1704)
# ['12830243', 'Battle of Chamkaur (1704)']
# Processing file... 1283127
# Hairdresser
# ['1283127', 'Hairdresser']
# Processing file... 1284267
# Aaron Rodgers
# ['1284267', 'Aaron Rodgers']
# Processing file... 12847142
# Tennant (surname)
# ['12847142', 'Tennant (surname)']
# Processing file... 1286500
# King Edward VI Aston School
# ['1286500', 'King Edward VI Aston School']
# Processing file... 1287136
# Shahid Malik
# ['1287136', 'Shahid Malik']
# Processing file... 1288339
# Kyle Massey
# ['1288339', 'Kyle Massey']
# Processing file... 12902671
# Ralph Drollinger
# ['12902671', 'Ralph Drollinger']
# Processing file... 1290366
# Amir Khan (boxer)
# ['1290366', 'Amir Khan (boxer)']
# Processing file... 1291598
# List of best-selling music artists
# ['1291598', 'List of best-selling music artists']
# Processing file... 1291858
# Criticism of the Federal Reserve
# ['1291858', 'Criticism of the Federal Reserve']
# Processing file... 1291991
# Sandbox
# ['1291991', 'Sandbox']
# Processing file... 12931396
# Dennis Oppenheim
# ['12931396', 'Dennis Oppenheim']
# Processing file... 1295901
# Neil Lennon
# ['1295901', 'Neil Lennon']
# Processing file... 12964178
# Midnight Sun (novel)
# ['12964178', 'Midnight Sun (novel)']
# Processing file... 12964276
# Lorde
# ['12964276', 'Lorde']
# Processing file... 1297124
# Kaká
# ['1297124', 'Kaká']
# Processing file... 12981266
# Zodiac Killer in popular culture
# ['12981266', 'Zodiac Killer in popular culture']
# Processing file... 12981647
# Super Smash Bros. Brawl
# ['12981647', 'Super Smash Bros. Brawl']
# Processing file... 1298357
# Audley Harrison
# ['1298357', 'Audley Harrison']
# Processing file... 1298638
# Raja Raja Chola I
# ['1298638', 'Raja Raja Chola I']
# Processing file... 12992431
# KidsCo
# ['12992431', 'KidsCo']
# Processing file... 12997
# George Washington Carver
# ['12997', 'George Washington Carver']
# Processing file... 1300462
# Bob Enyart
# ['1300462', 'Bob Enyart']
# Processing file... 13011369
# Michael Tobias
# ['13011369', 'Michael Tobias']
# Processing file... 13016380
# Ushakov Island
# ['13016380', 'Ushakov Island']
# Processing file... 13029061
# Same-sex marriage in Iowa
# ['13029061', 'Same-sex marriage in Iowa']
# Processing file... 13030
# Gary Busey
# ['13030', 'Gary Busey']
# Processing file... 13035457
# Paul Gordon (musician)
# ['13035457', 'Paul Gordon (musician)']
# Processing file... 1303679
# Samuel Eto'o
# ['1303679', "Samuel Eto'o"]
# Processing file... 13039867
# Twilight (novel series)
# ['13039867', 'Twilight (novel series)']
# Processing file... 13041163
# Adele
# ['13041163', 'Adele']
# Processing file... 1304415
# Max Gerson
# ['1304415', 'Max Gerson']
# Processing file... 13048148
# Maajid Nawaz
# ['13048148', 'Maajid Nawaz']
# Processing file... 1305348
# Video blog
# ['1305348', 'Video blog']
# Processing file... 13059378
# The Biggest Loser (season 4)
# ['13059378', 'The Biggest Loser (season 4)']
# Processing file... 13060731
# Gerard Way
# ['13060731', 'Gerard Way']
# Processing file... 1306351
# Jason Acuña
# ['1306351', 'Jason Acuña']
# Processing file... 13070785
# SM Southmall
# ['13070785', 'SM Southmall']
# Processing file... 13076
# Gordon Brown
# ['13076', 'Gordon Brown']
# Processing file... 13097064
# Harold Pinter bibliography
# ['13097064', 'Harold Pinter bibliography']
# Processing file... 13099901
# Davidson High School (New South Wales)
# ['13099901', 'Davidson High School (New South Wales)']
# Processing file... 13106745
# Tubber, County Clare
# ['13106745', 'Tubber, County Clare']
# Processing file... 1310890
# EBaum's World
# ['1310890', "EBaum's World"]
# Processing file... 13110135
# Fuckwit
# ['13110135', 'Fuckwit']
# Processing file... 13118744
# Scientology
# ['13118744', 'Scientology']
# Processing file... 13120635
# Oghur languages
# ['13120635', 'Oghur languages']
# Processing file... 1316732
# List of Billboard Hot 100 number-one singles of 2005
# ['1316732', 'List of Billboard Hot 100 number-one singles of 2005']
# Processing file... 1317098
# Brandon Novak
# ['1317098', 'Brandon Novak']
# Processing file... 1317701
# Rachel Maddow
# ['1317701', 'Rachel Maddow']
# Processing file... 13187026
# List of iCarly episodes
# ['13187026', 'List of iCarly episodes']
# Processing file... 13192
# Hacking
# ['13192', 'Hacking']
# Processing file... 13199916
# Taylor Lautner
# ['13199916', 'Taylor Lautner']
# Processing file... 1321151
# List of films that most frequently use the word "fuck"
# ['1321151', 'List of films that most frequently use the word "fuck"']
# Processing file... 1321503
# Ben Cousins
# ['1321503', 'Ben Cousins']
# Processing file... 1321703
# Jeph Loeb
# ['1321703', 'Jeph Loeb']
# Processing file... 13225
# Hades
# ['13225', 'Hades']
# Processing file... 13226577
# List of gay, lesbian or bisexual people: Sa–Sc
# ['13226577', 'List of gay, lesbian or bisexual people: Sa–Sc']
# Processing file... 132354
# Savage
# ['132354', 'Savage']
# Processing file... 1324767
# Royal Rife
# ['1324767', 'Royal Rife']
# Processing file... 13253481
# Alex Jones
# ['13253481', 'Alex Jones']
# Processing file... 13255
# Hydrogen
# ['13255', 'Hydrogen']
# Processing file... 13256
# Helium
# ['13256', 'Helium']
# Processing file... 1326371
# Gregg Williams
# ['1326371', 'Gregg Williams']
# Processing file... 13265
# Hitler (disambiguation)
# ['13265', 'Hitler (disambiguation)']
# Processing file... 13266004
# Gervinho
# ['13266004', 'Gervinho']
# Processing file... 1326645
# Chemical change
# ['1326645', 'Chemical change']
# Processing file... 13270
# Hawaii
# ['13270', 'Hawaii']
# Processing file... 13275
# Hungary
# ['13275', 'Hungary']
# Processing file... 13275423
# Yolo
# ['13275423', 'Yolo']
# Processing file... 13279542
# Ethnic groups in Europe
# ['13279542', 'Ethnic groups in Europe']
# Processing file... 1329090
# Mustafa Kemal Atatürk
# ['1329090', 'Mustafa Kemal Atatürk']
# Processing file... 13295790
# Saadat Ali Khan II
# ['13295790', 'Saadat Ali Khan II']
# Processing file... 1331018
# Alfred Wegener
# ['1331018', 'Alfred Wegener']
# Processing file... 133202
# Junkie
# ['133202', 'Junkie']
# Processing file... 133249
# Madeleine Albright
# ['133249', 'Madeleine Albright']
# Processing file... 13331280
# Jim Parsons
# ['13331280', 'Jim Parsons']
# Processing file... 1336449
# Joseph Farah
# ['1336449', 'Joseph Farah']
# Processing file... 13371
# Henry Ford
# ['13371', 'Henry Ford']
# Processing file... 13383154
# Javier Hernández
# ['13383154', 'Javier Hernández']
# Processing file... 13391779
# Seedbox
# ['13391779', 'Seedbox']
# Processing file... 13394
# Honduras
# ['13394', 'Honduras']
# Processing file... 1339436
# Scott Walker
# ['1339436', 'Scott Walker']
# Processing file... 13395562
# Abigail Breslin
# ['13395562', 'Abigail Breslin']
# Processing file... 13404
# Hong Kong
# ['13404', 'Hong Kong']
# Processing file... 13418508
# List of Airbus A380 orders and deliveries
# ['13418508', 'List of Airbus A380 orders and deliveries']
# Processing file... 13424905
# List of programs broadcast by USA Network
# ['13424905', 'List of programs broadcast by USA Network']
# Processing file... 134258
# Serfdom
# ['134258', 'Serfdom']
# Processing file... 1342873
# Vijay (actor)
# ['1342873', 'Vijay (actor)']
# Processing file... 13435050
# List of aircraft of the Malaysian Armed Forces
# ['13435050', 'List of aircraft of the Malaysian Armed Forces']
# Processing file... 13436
# Heinrich Himmler
# ['13436', 'Heinrich Himmler']
# Processing file... 134463
# Society Hill, South Carolina
# ['134463', 'Society Hill, South Carolina']
# Processing file... 134534
# Myrtle Beach, South Carolina
# ['134534', 'Myrtle Beach, South Carolina']
# Processing file... 13455931
# List of gay, lesbian or bisexual people: Sj–Sz
# ['13455931', 'List of gay, lesbian or bisexual people: Sj–Sz']
# Processing file... 13456803
# List of player salaries in the NHL
# ['13456803', 'List of player salaries in the NHL']
# Processing file... 1346406
# Mark Coleman
# ['1346406', 'Mark Coleman']
# Processing file... 1348590
# The Protector (1985 film)
# ['1348590', 'The Protector (1985 film)']
# Processing file... 1348866
# SunTrust Banks
# ['1348866', 'SunTrust Banks']
# Processing file... 13495433
# Varun Sandesh
# ['13495433', 'Varun Sandesh']
# Processing file... 13505067
# Victorious
# ['13505067', 'Victorious']
# Processing file... 1350677
# Camisole
# ['1350677', 'Camisole']
# Processing file... 1350710
# Eye of Ra
# ['1350710', 'Eye of Ra']
# Processing file... 1351301
# Rolie Polie Olie
# ['1351301', 'Rolie Polie Olie']
# Processing file... 1352814
# Johnny Weir
# ['1352814', 'Johnny Weir']
# Processing file... 1353497
# Shia LaBeouf
# ['1353497', 'Shia LaBeouf']
# Processing file... 13543
# Hinduism
# ['13543', 'Hinduism']
# Processing file... 1354405
# Nimrod Fortress
# ['1354405', 'Nimrod Fortress']
# Processing file... 1354872
# Dick Strawbridge
# ['1354872', 'Dick Strawbridge']
# Processing file... 13566216
# Jon Kennedy
# ['13566216', 'Jon Kennedy']
# Processing file... 1357307
# Christy
# ['1357307', 'Christy']
# Processing file... 13575276
# David N. Stamos
# ['13575276', 'David N. Stamos']
# Processing file... 13581081
# George Rae
# ['13581081', 'George Rae']
# Processing file... 13582438
# 2004 French–Ivorian clashes
# ['13582438', '2004 French–Ivorian clashes']
# Processing file... 13589741
# List of radio stations in Metro Manila
# ['13589741', 'List of radio stations in Metro Manila']
# Processing file... 13590
# House
# ['13590', 'House']
# Processing file... 1360461
# Mark Ellis
# ['1360461', 'Mark Ellis']
# Processing file... 136116
# Newbie
# ['136116', 'Newbie']
# Processing file... 13613264
# Lisa Ann
# ['13613264', 'Lisa Ann']
# Processing file... 13618375
# Jorge Andrés Martínez
# ['13618375', 'Jorge Andrés Martínez']
# Processing file... 13619028
# Nat Wolff
# ['13619028', 'Nat Wolff']
# Processing file... 13623554
# Che Guevara
# ['13623554', 'Che Guevara']
# Processing file... 13628305
# Us Girls (Philippine TV program)
# ['13628305', 'Us Girls (Philippine TV program)']
# Processing file... 13629643
# Danville Public Library (Danville, Illinois)
# ['13629643', 'Danville Public Library (Danville, Illinois)']
# Processing file... 13645
# Horse
# ['13645', 'Horse']
# Processing file... 13652052
# List of gay, lesbian or bisexual people: D–E
# ['13652052', 'List of gay, lesbian or bisexual people: D–E']
# Processing file... 13664092
# Subpar
# ['13664092', 'Subpar']
# Processing file... 13673345
# Car
# ['13673345', 'Car']
# Processing file... 13676233
# Black sheep
# ['13676233', 'Black sheep']
# Processing file... 13677
# Hindu
# ['13677', 'Hindu']
# Processing file... 13690575
# Solar power
# ['13690575', 'Solar power']
# Processing file... 13692
# History of the Internet
# ['13692', 'History of the Internet']
# Processing file... 13692155
# Philosophy
# ['13692155', 'Philosophy']
# Processing file... 1369965
# Breaking Benjamin
# ['1369965', 'Breaking Benjamin']
# Processing file... 1371138
# The Fox and the Hound
# ['1371138', 'The Fox and the Hound']
# Processing file... 137115
# Francis, Utah
# ['137115', 'Francis, Utah']
# Processing file... 13712570
# ...
# Processing file... 90714
# Interstate 57
# ['90714', 'Interstate 57']
# Processing file... 90722
# Interstate 79
# ['90722', 'Interstate 79']
# Processing file... 907766
# Albanian Air Force
# ['907766', 'Albanian Air Force']
# Processing file... 9078945
# Alyssa
# ['9078945', 'Alyssa']
# Processing file... 90796
# Pie
# ['90796', 'Pie']
# Processing file... 9085298
# C. K. McClatchy High School
# ['9085298', 'C. K. McClatchy High School']
# Processing file... 9085775
# South Park Mexican
# ['9085775', 'South Park Mexican']
# Processing file... 9087364
# Islamic State of Iraq and the Levant
# ['9087364', 'Islamic State of Iraq and the Levant']
# Processing file... 908749
# Avatar (disambiguation)
# ['908749', 'Avatar (disambiguation)']
# Processing file... 909036
# Elon Musk
# ['909036', 'Elon Musk']
# Processing file... 910272
# Cupcake
# ['910272', 'Cupcake']
# Processing file... 9110768
# Alice Parker
# ['9110768', 'Alice Parker']
# Processing file... 911606
# Oktay Sinanoğlu
# ['911606', 'Oktay Sinanoğlu']
# Processing file... 9119240
# United States Bill of Rights
# ['9119240', 'United States Bill of Rights']
# Processing file... 912530
# Loriga
# ['912530', 'Loriga']
# Processing file... 9127632
# Biology
# ['9127632', 'Biology']
# Processing file... 9135416
# Barney's Magical Musical Adventure
# ['9135416', "Barney's Magical Musical Adventure"]
# Processing file... 913746
# Kwame Brown
# ['913746', 'Kwame Brown']
# Processing file... 913777
# Seti II
# ['913777', 'Seti II']
# Processing file... 913788
# Ramesses X
# ['913788', 'Ramesses X']
# Processing file... 913833
# Ramesses XI
# ['913833', 'Ramesses XI']
# Processing file... 913887
# Ramesses V
# ['913887', 'Ramesses V']
# Processing file... 914237
# List of Indian film actors
# ['914237', 'List of Indian film actors']
# Processing file... 915493
# Robert
# ['915493', 'Robert']
# Processing file... 9157604
# Alex Wolff
# ['9157604', 'Alex Wolff']
# Processing file... 9159481
# Barney Live in New York City
# ['9159481', 'Barney Live in New York City']
# Processing file... 916099
# Manny Pacquiao
# ['916099', 'Manny Pacquiao']
# Processing file... 918389
# Pindari
# ['918389', 'Pindari']
# Processing file... 92013
# Interstate 43
# ['92013', 'Interstate 43']
# Processing file... 92023
# Interstate 44
# ['92023', 'Interstate 44']
# Processing file... 92027
# Interstate 45
# ['92027', 'Interstate 45']
# Processing file... 92031
# Interstate 49
# ['92031', 'Interstate 49']
# Processing file... 920613
# Cars (film)
# ['920613', 'Cars (film)']
# Processing file... 92090
# Interstate 59
# ['92090', 'Interstate 59']
# Processing file... 9209651
# Communism
# ['9209651', 'Communism']
# Processing file... 9210500
# Eva Braun
# ['9210500', 'Eva Braun']
# Processing file... 92121
# Interstate 91
# ['92121', 'Interstate 91']
# Processing file... 92122
# Interstate 93
# ['92122', 'Interstate 93']
# Processing file... 9213332
# Adventure Time
# ['9213332', 'Adventure Time']
# Processing file... 9216310
# List of films broadcast by Nickelodeon
# ['9216310', 'List of films broadcast by Nickelodeon']
# Processing file... 9223
# Economics
# ['9223', 'Economics']
# Processing file... 9225709
# Cameroon Air Force
# ['9225709', 'Cameroon Air Force']
# Processing file... 922586
# List of rivers by length
# ['922586', 'List of rivers by length']
# Processing file... 9228
# Earth
# ['9228', 'Earth']
# Processing file... 9232
# Eiffel Tower
# ['9232', 'Eiffel Tower']
# Processing file... 9232180
# Perdizes (district of São Paulo)
# ['9232180', 'Perdizes (district of São Paulo)']
# Processing file... 9232321
# Randy Jackson
# ['9232321', 'Randy Jackson']
# Processing file... 9233381
# Ryan Seacrest
# ['9233381', 'Ryan Seacrest']
# Processing file... 9236
# Evolution
# ['9236', 'Evolution']
# Processing file... 9239
# Europe
# ['9239', 'Europe']
# Processing file... 92398
# Streptococcal pharyngitis
# ['92398', 'Streptococcal pharyngitis']
# Processing file... 9241345
# Esther Vergeer
# ['9241345', 'Esther Vergeer']
# Processing file... 924166
# LGBT rights by country or territory
# ['924166', 'LGBT rights by country or territory']
# Processing file... 92421
# Interstate 64
# ['92421', 'Interstate 64']
# Processing file... 92427
# Interstate 65
# ['92427', 'Interstate 65']
# Processing file... 92432
# Interstate 66
# ['92432', 'Interstate 66']
# Processing file... 924662
# Tsakhiagiin Elbegdorj
# ['924662', 'Tsakhiagiin Elbegdorj']
# Processing file... 9252
# Education
# ['9252', 'Education']
# Processing file... 9253
# Encyclopedia
# ['9253', 'Encyclopedia']
# Processing file... 9257
# Enzyme
# ['9257', 'Enzyme']
# Processing file... 926531
# Chav
# ['926531', 'Chav']
# Processing file... 9268239
# Israel Folau
# ['9268239', 'Israel Folau']
# Processing file... 92693
# Common cold
# ['92693', 'Common cold']
# Processing file... 9271515
# Bella Thorne
# ['9271515', 'Bella Thorne']
# Processing file... 9279
# Elephant
# ['9279', 'Elephant']
# Processing file... 927951
# Arjang
# ['927951', 'Arjang']
# Processing file... 9282173
# Israel
# ['9282173', 'Israel']
# Processing file... 928278
# Wilbur
# ['928278', 'Wilbur']
# Processing file... 9285896
# Tony Särkkä
# ['9285896', 'Tony Särkkä']
# Processing file... 9287211
# Hilary Duff
# ['9287211', 'Hilary Duff']
# Processing file... 9288
# Elvis Presley
# ['9288', 'Elvis Presley']
# Processing file... 929
# Alpha
# ['929', 'Alpha']
# Processing file... 9291648
# Francis Turner (engineer)
# ['9291648', 'Francis Turner (engineer)']
# Processing file... 930552
# 4Licensing Corporation
# ['930552', '4Licensing Corporation']
# Processing file... 93076
# Interstate 77
# ['93076', 'Interstate 77']
# Processing file... 9311172
# Drug
# ['9311172', 'Drug']
# Processing file... 9311462
# Ethnic groups in Afghanistan
# ['9311462', 'Ethnic groups in Afghanistan']
# Processing file... 931216
# My Chemical Romance
# ['931216', 'My Chemical Romance']
# Processing file... 931370
# Tropical rainforest
# ['931370', 'Tropical rainforest']
# Processing file... 93149
# Rashtriya Swayamsevak Sangh
# ['93149', 'Rashtriya Swayamsevak Sangh']
# Processing file... 9316
# England
# ['9316', 'England']
# Processing file... 9317
# European Union
# ['9317', 'European Union']
# Processing file... 931888
# Press kit
# ['931888', 'Press kit']
# Processing file... 9322
# English
# ['9322', 'English']
# Processing file... 9322682
# Karabakh
# ['9322682', 'Karabakh']
# Processing file... 9325
# Easter
# ['9325', 'Easter']
# Processing file... 932529
# List of amendments to the United States Constitution
# ['932529', 'List of amendments to the United States Constitution']
# Processing file... 9331
# Euclid
# ['9331', 'Euclid']
# Processing file... 9334
# Ecuador
# ['9334', 'Ecuador']
# Processing file... 93361
# Faux pas
# ['93361', 'Faux pas']
# Processing file... 9356
# El Salvador
# ['9356', 'El Salvador']
# Processing file... 93576
# Interstate 69
# ['93576', 'Interstate 69']
# Processing file... 93577
# Interstate 71
# ['93577', 'Interstate 71']
# Processing file... 93580
# Interstate 72
# ['93580', 'Interstate 72']
# Processing file... 93586
# Interstate 73
# ['93586', 'Interstate 73']
# Processing file... 93589
# Interstate 74
# ['93589', 'Interstate 74']
# Processing file... 93791
# Roseanne Barr
# ['93791', 'Roseanne Barr']
# Processing file... 9379281
# Andrew Thomas (American politician)
# ['9379281', 'Andrew Thomas (American politician)']
# Processing file... 938202
# Markus Buchart
# ['938202', 'Markus Buchart']
# Processing file... 93824
# Interstate 82
# ['93824', 'Interstate 82']
# Processing file... 93828
# Interstate 85
# ['93828', 'Interstate 85']
# Processing file... 93830
# Interstate 87
# ['93830', 'Interstate 87']
# Processing file... 93832
# Interstate 89
# ['93832', 'Interstate 89']
# Processing file... 939263
# Red Storm Entertainment
# ['939263', 'Red Storm Entertainment']
# Processing file... 939583
# Amy Winehouse
# ['939583', 'Amy Winehouse']
# Processing file... 9405039
# Sajeeb Wazed
# ['9405039', 'Sajeeb Wazed']
# Processing file... 941270
# Giganotosaurus
# ['941270', 'Giganotosaurus']
# Processing file... 9428
# Ernest Hemingway
# ['9428', 'Ernest Hemingway']
# Processing file... 94289
# Sally Ride
# ['94289', 'Sally Ride']
# Processing file... 9430058
# Sami Khedira
# ['9430058', 'Sami Khedira']
# Processing file... 9432075
# Guitar Hero
# ['9432075', 'Guitar Hero']
# Processing file... 9445849
# Gok Wan
# ['9445849', 'Gok Wan']
# Processing file... 9450836
# Thornton High School (Colorado)
# ['9450836', 'Thornton High School (Colorado)']
# Processing file... 9457470
# Edward Cullen
# ['9457470', 'Edward Cullen']
# Processing file... 9467
# Longest word in English
# ['9467', 'Longest word in English']
# Processing file... 9489004
# Jimtown High School (Elkhart, Indiana)
# ['9489004', 'Jimtown High School (Elkhart, Indiana)']
# Processing file... 9504983
# Fenzi
# ['9504983', 'Fenzi']
# Processing file... 9532
# Electromagnetism
# ['9532', 'Electromagnetism']
# Processing file... 9545969
# Ilana Mercer
# ['9545969', 'Ilana Mercer']
# Processing file... 9549
# Edgar Allan Poe
# ['9549', 'Edgar Allan Poe']
# Processing file... 9550
# Electricity
# ['9550', 'Electricity']
# Processing file... 9554131
# List of members of the Irish Republican Army
# ['9554131', 'List of members of the Irish Republican Army']
# Processing file... 95618
# John Vincent Atanasoff
# ['95618', 'John Vincent Atanasoff']
# Processing file... 956210
# Michigan J. Frog
# ['956210', 'Michigan J. Frog']
# Processing file... 956689
# Kura–Araxes culture
# ['956689', 'Kura–Araxes culture']
# Processing file... 9571601
# Dumbass
# ['9571601', 'Dumbass']
# Processing file... 957276
# Raveena Tandon
# ['957276', 'Raveena Tandon']
# Processing file... 957684
# Cesc Fàbregas
# ['957684', 'Cesc Fàbregas']
# Processing file... 9578734
# Go-go boot
# ['9578734', 'Go-go boot']
# Processing file... 9584577
# McAlester News-Capital
# ['9584577', 'McAlester News-Capital']
# Processing file... 9587
# Euthanasia
# ['9587', 'Euthanasia']
# Processing file... 958866
# Tony Attwood
# ['958866', 'Tony Attwood']
# Processing file... 9603
# Ernest Rutherford
# ['9603', 'Ernest Rutherford']
# Processing file... 961110
# Ashlyn Gere
# ['961110', 'Ashlyn Gere']
# Processing file... 96149
# Slipknot (band)
# ['96149', 'Slipknot (band)']
# Processing file... 9630
# Ecology
# ['9630', 'Ecology']
# Processing file... 963152
# Spaniards
# ['963152', 'Spaniards']
# Processing file... 9636145
# Gregory Paul Martin
# ['9636145', 'Gregory Paul Martin']
# Processing file... 964077
# Lamar S. Smith
# ['964077', 'Lamar S. Smith']
# Processing file... 9644294
# List of Ice Age characters
# ['9644294', 'List of Ice Age characters']
# Processing file... 9649
# Energy
# ['9649', 'Energy']
# Processing file... 964985
# List of city nicknames in the United States
# ['964985', 'List of city nicknames in the United States']
# Processing file... 96603
# Memphis, Egypt
# ['96603', 'Memphis, Egypt']
# Processing file... 966195
# Erzurum
# ['966195', 'Erzurum']
# Processing file... 966465
# Paul Steed
# ['966465', 'Paul Steed']
# Processing file... 96652
# Seahorse
# ['96652', 'Seahorse']
# Processing file... 9666124
# Raai Laxmi
# ['9666124', 'Raai Laxmi']
# Processing file... 967176
# Eye of Horus
# ['967176', 'Eye of Horus']
# Processing file... 9674182
# Glenn Grothman
# ['9674182', 'Glenn Grothman']
# Processing file... 9675071
# Ezhava
# ['9675071', 'Ezhava']
# Processing file... 9679918
# Norwegian Police Service
# ['9679918', 'Norwegian Police Service']
# Processing file... 970386
# The SpongeBob SquarePants Movie
# ['970386', 'The SpongeBob SquarePants Movie']
# Processing file... 97044
# Khepri
# ['97044', 'Khepri']
# Processing file... 97046
# Atum
# ['97046', 'Atum']
# Processing file... 97096
# Nu (mythology)
# ['97096', 'Nu (mythology)']
# Processing file... 97125
# Ptah
# ['97125', 'Ptah']
# Processing file... 9717
# Excalibur
# ['9717', 'Excalibur']
# Processing file... 97187
# Ennead
# ['97187', 'Ennead']
# Processing file... 971896
# Frank Wu (artist)
# ['971896', 'Frank Wu (artist)']
# Processing file... 972036
# Evan Solomon
# ['972036', 'Evan Solomon']
# Processing file... 97236
# Maat
# ['97236', 'Maat']
# Processing file... 972591
# Delta FM
# ['972591', 'Delta FM']
# Processing file... 972683
# Kyle
# ['972683', 'Kyle']
# Processing file... 9729299
# Jonas Brothers
# ['9729299', 'Jonas Brothers']
# Processing file... 97317
# Hathor
# ['97317', 'Hathor']
# Processing file... 9732
# Eli Whitney
# ['9732', 'Eli Whitney']
# Processing file... 97404
# Cluj-Napoca
# ['97404', 'Cluj-Napoca']
# Processing file... 9754606
# Dingleberry
# ['9754606', 'Dingleberry']
# Processing file... 9762025
# Laurel Springs School
# ['9762025', 'Laurel Springs School']
# Processing file... 9764
# Emma Goldman
# ['9764', 'Emma Goldman']
# Processing file... 9769596
# John Riccitiello
# ['9769596', 'John Riccitiello']
# Processing file... 976970
# Tibetan Mastiff
# ['976970', 'Tibetan Mastiff']
# Processing file... 9771922
# Paul Mounet
# ['9771922', 'Paul Mounet']
# Processing file... 9773333
# Peter Brookesmith
# ['9773333', 'Peter Brookesmith']
# Processing file... 97771
# Family tree of the Greek gods
# ['97771', 'Family tree of the Greek gods']
# Processing file... 978203
# Flag of India
# ['978203', 'Flag of India']
# Processing file... 979165
# Guy Fawkes Night
# ['979165', 'Guy Fawkes Night']
# Processing file... 979320
# Gippsland Grammar School
# ['979320', 'Gippsland Grammar School']
# Processing file... 9809619
# PlayStation Home
# ['9809619', 'PlayStation Home']
# Processing file... 9810476
# Zombie
# ['9810476', 'Zombie']
# Processing file... 9814346
# Alex Pierson
# ['9814346', 'Alex Pierson']
# Processing file... 98176
# Ancient Egyptian concept of the soul
# ['98176', 'Ancient Egyptian concept of the soul']
# Processing file... 982180
# Robin Hood (1973 film)
# ['982180', 'Robin Hood (1973 film)']
# Processing file... 982199
# Peter Pan (1953 film)
# ['982199', 'Peter Pan (1953 film)']
# Processing file... 98301
# Joker (comics)
# ['98301', 'Joker (comics)']
# Processing file... 98351
# Elmo
# ['98351', 'Elmo']
# Processing file... 984106
# Antonio Paoli
# ['984106', 'Antonio Paoli']
# Processing file... 984639
# Karan Johar
# ['984639', 'Karan Johar']
# Processing file... 9846732
# Dale L. Walker
# ['9846732', 'Dale L. Walker']
# Processing file... 984827
# Martock
# ['984827', 'Martock']
# Processing file... 9853806
# Kanyakubja Brahmins
# ['9853806', 'Kanyakubja Brahmins']
# Processing file... 985535
# World Tag Team Championship (WWE)
# ['985535', 'World Tag Team Championship (WWE)']
# Processing file... 98650
# Chartres
# ['98650', 'Chartres']
# Processing file... 9866040
# List of National Basketball Association single-season scoring leaders
# ['9866040', 'List of National Basketball Association single-season scoring leaders']
# Processing file... 9877706
# Emanuel School
# ['9877706', 'Emanuel School']
# Processing file... 9878372
# Login
# ['9878372', 'Login']
# Processing file... 988583
# Chitral District
# ['988583', 'Chitral District']
# Processing file... 9886374
# List of Epiphone players
# ['9886374', 'List of Epiphone players']
# Processing file... 989460
# Sam Katz
# ['989460', 'Sam Katz']
# Processing file... 9896
# Elf
# ['9896', 'Elf']
# Processing file... 9896564
# ResellerRatings
# ['9896564', 'ResellerRatings']
# Processing file... 990501
# Nanyang Polytechnic
# ['990501', 'Nanyang Polytechnic']
# Processing file... 9906294
# Johann Sebastian Bach
# ['9906294', 'Johann Sebastian Bach']
# Processing file... 99063
# Isaac Brock
# ['99063', 'Isaac Brock']
# Processing file... 990764
# The Wild Thornberrys Movie
# ['990764', 'The Wild Thornberrys Movie']
# Processing file... 9908504
# Gambling for resurrection
# ['9908504', 'Gambling for resurrection']
# Processing file... 9909905
# Ninja Theory
# ['9909905', 'Ninja Theory']
# Processing file... 9911223
# Flux (software)
# ['9911223', 'Flux (software)']
# Processing file... 991143
# Frank Sinatra, Jr.
# ['991143', 'Frank Sinatra, Jr.']
# Processing file... 991210
# Divisibility rule
# ['991210', 'Divisibility rule']
# Processing file... 9918415
# Matt Sanchez
# ['9918415', 'Matt Sanchez']
# Processing file... 991985
# Pitbull (rapper)
# ['991985', 'Pitbull (rapper)']
# Processing file... 992332
# Bob Larson
# ['992332', 'Bob Larson']
# Processing file... 9924355
# Peggle
# ['9924355', 'Peggle']
# Processing file... 993558
# Treehouse TV
# ['993558', 'Treehouse TV']
# Processing file... 9935632
# List of tallest buildings in Karachi
# ['9935632', 'List of tallest buildings in Karachi']
# Processing file... 993655
# Asif Ali Zardari
# ['993655', 'Asif Ali Zardari']
# Processing file... 99372
# Robin (comics)
# ['99372', 'Robin (comics)']
# Processing file... 9940234
# Tomato
# ['9940234', 'Tomato']
# Processing file... 994160
# Samoa Joe
# ['994160', 'Samoa Joe']
# Processing file... 9942
# Erwin Schrödinger
# ['9942', 'Erwin Schrödinger']
# Processing file... 9963622
# I Come in Peace
# ['9963622', 'I Come in Peace']
# Processing file... 99645
# Homo sapiens
# ['99645', 'Homo sapiens']
# Processing file... 9987564
# A Day to Remember
# ['9987564', 'A Day to Remember']
# Processing file... 9988187
# Twitter
# ['9988187', 'Twitter']

# %%
data['query']['pages']['protection']
# Out:
# {'batchcomplete': '',
#  'query': {'logevents': [{'comment': 'Persistent [[WP:Vandalism|vandalism]]',
#     'pageid': 100062,
#     'title': 'Super Mario 64',
#     'timestamp': '2011-04-20T00:55:46Z',
#     'tags': [],
#     'logid': 35707351,
#     'logpage': 100062,
#     'user': 'Andrevan',
#     'action': 'protect',
#     'params': {'description': '[edit=autoconfirmed] (indefinite) [move=autoconfirmed] (indefinite)'},
#     'ns': 0,
#     'type': 'protect'},
#    {'comment': 'inbound nonsense',
#     'pageid': 100062,
#     'title': 'Super Mario 64',
#     'timestamp': '2011-03-18T20:21:14Z',
#     'tags': [],
#     'logid': 35212925,
#     'logpage': 100062,
#     'user': 'Gfoley4',
#     'action': 'protect',
#     'params': {'description': '[edit=autoconfirmed] (expires 20:21, 19 March 2011 (UTC)) [move=autoconfirmed] (expires 20:21, 19 March 2011 (UTC))'},
#     'ns': 0,
#     'type': 'protect'},
#    {'comment': 'Excessive [[WP:VANDALISM|vandalism]]',
#     'pageid': 100062,
#     'title': 'Super Mario 64',
#     'timestamp': '2009-10-20T22:24:07Z',
#     'tags': [],
#     'logid': 25314836,
#     'logpage': 100062,
#     'user': 'Tedder',
#     'action': 'protect',
#     'params': {'description': '[edit=autoconfirmed] (expires 22:24, 23 October 2009 (UTC)) [move=autoconfirmed] (expires 22:24, 23 October 2009 (UTC))'},
#     'ns': 0,
#     'type': 'protect'}],
#   'pages': {'100062': {'lastrevid': 713791609,
#     'pagelanguagedir': 'ltr',
#     'pageid': 100062,
#     'protection': [{'expiry': 'infinity',
#       'type': 'edit',
#       'level': 'autoconfirmed'},
#      {'expiry': 'infinity', 'type': 'move', 'level': 'autoconfirmed'}],
#     'title': 'Super Mario 64',
#     'pagelanguagehtmlcode': 'en',
#     'watchers': 190,
#     'length': 53038,
#     'contentmodel': 'wikitext',
#     'pagelanguage': 'en',
#     'touched': '2016-04-23T15:27:01Z',
#     'ns': 0,
#     'restrictiontypes': ['edit', 'move'],
#     'categories': [{'timestamp': '2010-10-04T17:15:37Z',
#       'ns': 14,
#       'title': 'Category:1996 video games'},
#      {'timestamp': '2010-10-04T17:15:37Z',
#       'ns': 14,
#       'title': 'Category:3D platform games'},
#      {'timestamp': '2013-09-09T20:08:21Z',
#       'ns': 14,
#       'title': 'Category:Album infoboxes lacking a cover'},
#      {'timestamp': '2013-06-20T00:40:07Z',
#       'ns': 14,
#       'title': 'Category:Articles containing Japanese-language text'},
#      {'timestamp': '2015-05-28T02:36:04Z',
#       'ns': 14,
#       'title': 'Category:Articles using Video game reviews template in single platform mode'},
#      {'timestamp': '2012-08-16T01:20:10Z',
#       'ns': 14,
#       'title': 'Category:Articles with hAudio microformats'},
#      {'timestamp': '2011-07-19T10:35:06Z',
#       'ns': 14,
#       'title': 'Category:Featured articles'},
#      {'timestamp': '2010-10-04T17:15:37Z',
#       'ns': 14,
#       'title': 'Category:History of video games'},
#      {'timestamp': '2010-10-04T17:15:37Z',
#       'ns': 14,
#       'title': 'Category:IQue games'},
#      {'timestamp': '2010-10-04T17:15:37Z',
#       'ns': 14,
#       'title': 'Category:Mario Universe games'},
#      {'timestamp': '2010-10-04T17:15:37Z',
#       'ns': 14,
#       'title': 'Category:Mario platform games'},
#      {'timestamp': '2015-04-12T06:33:06Z',
#       'ns': 14,
#       'title': 'Category:Nintendo 64 games'},
#      {'timestamp': '2010-10-04T17:15:37Z',
#       'ns': 14,
#       'title': 'Category:Nintendo 64 platform games'},
#      {'timestamp': '2010-10-04T17:15:37Z',
#       'ns': 14,
#       'title': 'Category:Nintendo Entertainment Analysis and Development games'},
#      {'timestamp': '2013-04-02T19:12:13Z',
#       'ns': 14,
#       'title': 'Category:Single-player-only video games'},
#      {'timestamp': '2012-05-13T10:52:53Z',
#       'ns': 14,
#       'title': 'Category:Use mdy dates from May 2012'},
#      {'timestamp': '2015-10-27T11:45:13Z',
#       'ns': 14,
#       'title': 'Category:Video games composed by Koji Kondo'},
#      {'timestamp': '2016-01-26T22:48:37Z',
#       'ns': 14,
#       'title': 'Category:Video games directed by Shigeru Miyamoto'},
#      {'timestamp': '2010-10-04T17:15:37Z',
#       'ns': 14,
#       'title': 'Category:Virtual Console games'},
#      {'timestamp': '2015-04-02T16:17:37Z',
#       'ns': 14,
#       'title': 'Category:Virtual Console games for Wii U'},
#      {'timestamp': '2015-05-19T21:10:12Z',
#       'ns': 14,
#       'title': 'Category:Wikipedia articles with GND identifiers'},
#      {'timestamp': '2011-04-20T19:10:48Z',
#       'ns': 14,
#       'title': 'Category:Wikipedia indefinitely semi-protected pages'}],
#     'revisions': [{'comment': 'Protected Super Mario 64: Persistent [[WP:Vandalism|vandalism]] ([edit=autoconfirmed] (indefinite) [move=autoconfirmed] (indefinite))',
#       'tags': [],
#       'timestamp': '2011-04-20T00:55:46Z',
#       'revid': 424948393,
#       'user': 'Andrevan',
#       'parentid': 424948355,
#       'minor': '',
#       'size': 41824},
#      {'comment': '[[Help:Reverting|Reverted]] edits by [[Special:Contributions/174.57.208.202|174.57.208.202]] ([[User talk:174.57.208.202|talk]]) to last version by SUPER DREW 64',
#       'tags': [],
#       'timestamp': '2011-04-20T00:55:23Z',
#       'revid': 424948355,
#       'user': 'Andrevan',
#       'parentid': 424940337,
#       'minor': '',
#       'size': 41824},
#      {'comment': 'i named a famous glitch in the game',
#       'tags': [],
#       'timestamp': '2011-04-19T23:47:10Z',
#       'revid': 424940337,
#       'anon': '',
#       'user': '174.57.208.202',
#       'parentid': 424939303,
#       'size': 43053},
#      {'comment': 'i have added a fun fact that im sure many people did not know, i named the factual place in history of what place super mario 64 is in for best video games.',
#       'tags': [],
#       'timestamp': '2011-04-19T23:39:14Z',
#       'revid': 424939303,
#       'anon': '',
#       'user': '174.57.208.202',
#       'parentid': 424768757,
#       'size': 42481},
#      {'comment': '',
#       'tags': ['Section blanking'],
#       'timestamp': '2011-04-18T23:31:26Z',
#       'revid': 424768757,
#       'user': 'SUPER DREW 64',
#       'parentid': 424768646,
#       'size': 41824},
#      {'comment': "making artical of luigi's new game",
#       'tags': [],
#       'timestamp': '2011-04-18T23:30:33Z',
#       'revid': 424768646,
#       'user': 'SUPER DREW 64',
#       'parentid': 424767968,
#       'size': 41870},
#      {'comment': 'Undid revision 424767808 by [[Special:Contributions/SUPER DREW 64|SUPER DREW 64]] ([[User talk:SUPER DREW 64|talk]]) Nobody cares',
#       'tags': [],
#       'timestamp': '2011-04-18T23:25:16Z',
#       'revid': 424767968,
#       'user': 'Blake',
#       'parentid': 424767808,
#       'size': 41824},
#      {'comment': 'THIS IS ABOUT THE NEW ROM SUPER LUIGI 64',
#       'tags': [],
#       'timestamp': '2011-04-18T23:23:57Z',
#       'revid': 424767808,
#       'user': 'SUPER DREW 64',
#       'parentid': 424763398,
#       'size': 42064},
#      {'comment': 'Reverted to revision 423468663 by Fæ; This is not appropriate. ([[WP:TW|TW]])',
#       'tags': [],
#       'timestamp': '2011-04-18T22:50:02Z',
#       'revid': 424763398,
#       'user': 'Lord Psyko Jo',
#       'parentid': 424763194,
#       'size': 41824},
#      {'comment': '/* Super Luigi 64 (ROM) */',
#       'tags': [],
#       'timestamp': '2011-04-18T22:48:31Z',
#       'revid': 424763194,
#       'anon': '',
#       'user': '72.221.71.250',
#       'parentid': 424763089,
#       'size': 42433},
#      {'comment': '/* Super Luigi 64 (ROM) */',
#       'tags': [],
#       'timestamp': '2011-04-18T22:47:38Z',
#       'revid': 424763089,
#       'anon': '',
#       'user': '72.221.71.250',
#       'parentid': 424762941,
#       'size': 42431},
#      {'comment': 'Have added a thing of my new rom that I will be released called Super Luigi 64',
#       'tags': [],
#       'timestamp': '2011-04-18T22:46:36Z',
#       'revid': 424762941,
#       'anon': '',
#       'user': '72.221.71.250',
#       'parentid': 423468663,
#       'size': 42437},
#      {'comment': 'Reverted edits by [[Special:Contributions/Ebin1212|Ebin1212]] to last version by Lord Psyko Jo ([[User:Ale_jrb/Scripts/igloo|GLOO]])',
#       'tags': [],
#       'timestamp': '2011-04-11T06:21:18Z',
#       'revid': 423468663,
#       'user': 'Fæ',
#       'parentid': 423468632,
#       'minor': '',
#       'size': 41824},
#      {'comment': '',
#       'tags': [],
#       'timestamp': '2011-04-11T06:20:51Z',
#       'revid': 423468632,
#       'user': 'Ebin1212',
#       'parentid': 422865867,
#       'size': 40585},
#      {'comment': 'Reverted to revision 422725232 by ThomasO1989; "Several" is better here because it includes bonus stages, hub areas, etc. ([[WP:TW|TW]])',
#       'tags': [],
#       'timestamp': '2011-04-07T14:46:37Z',
#       'revid': 422865867,
#       'user': 'Lord Psyko Jo',
#       'parentid': 422863485,
#       'size': 41824},
#      {'comment': '/* Gameplay */',
#       'tags': [],
#       'timestamp': '2011-04-07T14:28:15Z',
#       'revid': 422863485,
#       'anon': '',
#       'user': '72.204.250.130',
#       'parentid': 422725232,
#       'size': 41824},
#      {'comment': 'rv source?',
#       'tags': [],
#       'timestamp': '2011-04-06T17:40:34Z',
#       'revid': 422725232,
#       'user': 'ThomasO1989',
#       'parentid': 422724117,
#       'size': 41824},
#      {'comment': '/* Remakes and sequels */',
#       'tags': [],
#       'timestamp': '2011-04-06T17:32:56Z',
#       'revid': 422724117,
#       'user': 'Axon64',
#       'parentid': 422724006,
#       'size': 41953},
#      {'comment': '/* Remakes and sequels */',
#       'tags': [],
#       'timestamp': '2011-04-06T17:32:13Z',
#       'revid': 422724006,
#       'user': 'Axon64',
#       'parentid': 422382335,
#       'size': 41952},
#      {'comment': '/* Development */',
#       'tags': [],
#       'timestamp': '2011-04-04T20:44:07Z',
#       'revid': 422382335,
#       'user': 'MarioLOA',
#       'parentid': 421879632,
#       'size': 41824},
#      {'comment': '[[Help:Reverting|Reverted]] edits by [[Special:Contributions/97.114.39.91|97.114.39.91]] ([[User talk:97.114.39.91|talk]]) to last version by WikitanvirBot',
#       'tags': [],
#       'timestamp': '2011-04-01T20:54:04Z',
#       'revid': 421879632,
#       'user': 'Andrevan',
#       'parentid': 421873900,
#       'minor': '',
#       'size': 41734},
#      {'comment': '',
#       'tags': [],
#       'timestamp': '2011-04-01T20:17:25Z',
#       'revid': 421873900,
#       'anon': '',
#       'user': '97.114.39.91',
#       'parentid': 421873678,
#       'size': 41940},
#      {'comment': '',
#       'tags': [],
#       'timestamp': '2011-04-01T20:15:44Z',
#       'revid': 421873678,
#       'anon': '',
#       'user': '97.114.39.91',
#       'parentid': 421732779,
#       'size': 41940},
#      {'comment': 'r2.7.1) (robot Removing: [[be:Super Mario 64]]',
#       'tags': [],
#       'timestamp': '2011-03-31T23:32:47Z',
#       'revid': 421732779,
#       'user': 'WikitanvirBot',
#       'parentid': 421513670,
#       'minor': '',
#       'size': 41734},
#      {'comment': 'r2.7.1) (robot Adding: [[be:Super Mario 64]]',
#       'tags': [],
#       'timestamp': '2011-03-30T17:30:58Z',
#       'revid': 421513670,
#       'user': 'Luckas-bot',
#       'parentid': 419516278,
#       'minor': '',
#       'size': 41756},
#      {'comment': 'Revert to revision 418962821 dated 2011-03-15 15:10:47 by ThomasO1989 using [[:en:Wikipedia:Tools/Navigation_popups|popups]]',
#       'tags': [],
#       'timestamp': '2011-03-18T20:21:55Z',
#       'revid': 419516278,
#       'user': 'Gfoley4',
#       'parentid': 419516167,
#       'size': 41734},
#      {'comment': 'Protected Super Mario 64: inbound nonsense  ([edit=autoconfirmed] (expires 20:21, 19 March 2011 (UTC)) [move=autoconfirmed] (expires 20:21, 19 March 2011 (UTC)))',
#       'tags': [],
#       'timestamp': '2011-03-18T20:21:14Z',
#       'revid': 419516167,
#       'user': 'Gfoley4',
#       'parentid': 419516148,
#       'minor': '',
#       'size': 41734}]}}},
#  'startTimeCollected': '2011-04-20T00:55:46Z',
#  'endTimeCollected': '2011-03-18T20:21:14Z'}

# %%
type(filename)
# Out:
# str

# %%
f
# Out:
# <_io.TextIOWrapper name='depp_dataset.csv' mode='r+' encoding='cp1252'>

# %%
# importing the pandas library
import pandas as pd
  
# reading the csv file
df = pd.read_csv("AllDetails.csv")
  
# updating the column value/data
df.loc[5, 'Name'] = 'SHIV CHANDRA'
  
# writing into the file
df.to_csv("AllDetails.csv", index=False)
  
print(df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-cac29482a039> in <module>
#       3
#       4 # reading the csv file
# ----> 5 df = pd.read_csv("AllDetails.csv")
#       6
#       7 # updating the column value/data
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     944             self.options["has_index_names"] = kwds["has_index_names"]
#     945
# --> 946         self._make_engine(self.engine)
#     947
#     948     def close(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1176     def _make_engine(self, engine="c"):
#    1177         if engine == "c":
# -> 1178             self._engine = CParserWrapper(self.f, **self.options)
#    1179         else:
#    1180             if engine == "python":
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    2006         kwds["usecols"] = self.usecols
#    2007
# -> 2008         self._reader = parsers.TextReader(src, **kwds)
#    2009         self.unnamed_cols = self._reader.unnamed_cols
#    2010
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'AllDetails.csv'

# %%
import csv
with open(r'hello.csv', 'a', encoding="utf-8") as f:
                writer = csv.writer(f)
                writer.writerow(['0','1'])
